# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import string
import json

# %% [markdown]
# ## 1. Corpus Loading and Preprocessing

# %%
# Load the Reuters corpus categorized under "livestock"
import nltk
nltk.download('reuters')
from nltk.corpus import reuters 
category_livestock = reuters.fileids("livestock")
corpus = [reuters.words(fid) for fid in category_livestock]
print(corpus)
# Out:
# [nltk_data] Downloading package reuters to
# [nltk_data]     C:\Users\A443696\AppData\Roaming\nltk_data...
# [nltk_data]   Package reuters is already up-to-date!
# [['JAPAN', 'MINISTRY', 'SAYS', 'OPEN', 'FARM', 'TRADE', ...], ['USDA', 'TO', 'PROPOSE', 'FOREIGN', 'MEAT', ...], ['U', '.', 'S', '.', 'MEAT', ',', 'POULTRY', ...], ['MEXICAN', 'CATTLE', 'IMPORTS', 'TO', 'BE', 'BRANDED', ...], ['ARGENTINE', 'CATTLE', 'MARKET', 'REPORT', 'ABOUT', ...], ['HOG', 'AND', 'CATTLE', 'SLAUGHTER', 'GUESSTIMATES', ...], ['EASTERN', 'DISTRIBUTIVE', 'BEEF', 'TRADE', 'WEEKLY', ...], ['DISEASE', 'PUTS', 'ZIMBABWE', 'BEEF', 'EXPORTS', ...], ['CCC', 'GUARANTEES', 'TO', 'IRAQ', 'SWITCHED', '--', ...], ['U', '.', 'S', '.', 'DOLLAR', 'LOSSES', 'PROPEL', ...], ['U', '.', 'S', '.', 'FEEDER', 'STEER', 'PRICE', 'The', ...], ['HOG', 'AND', 'CATTLE', 'SLAUGHTER', 'GUESSTIMATES', ...], ['CCC', 'ACCEPTS', 'BONUS', 'ON', 'CATTLE', 'TO', ...], ['SWIFT', 'TO', 'SELL', 'SOUTH', 'DAKOTA', 'PORK', ...], ['SWIFT', '&', 'lt', ';', 'SFTPF', '>', 'TO', 'SELL', ...], ['EC', 'MEAT', 'DIRECTIVE', 'DEADLINE', 'SEEN', ...], ['JAPAN', '1986', '/', '87', 'COMPOUND', 'FEED', ...], ['INDONESIA', '/', 'TURKEY', 'ELIGIBLE', 'FOR', ...], ['U', '.', 'S', '.', 'REFUSES', 'PARTS', 'OF', 'TWO', ...], ['CANADA', 'THREATENS', 'BAN', 'ON', 'DANISH', ...], ['U', '.', 'S', '.', 'TAKES', 'TOUGH', 'STAND', 'ON', ...], ['EC', 'AGREES', 'TRADE', 'DEAL', 'WITH', 'ARGENTINA', ...], ['WEST', 'VIRGINIA', 'FREE', 'OF', 'TWO', 'MAJOR', ...], ['STUDY', 'SAYS', 'PORK', 'LEANER', 'THAN', 'USDA', ...], ['FRANCE', 'WILL', 'FIGHT', 'EC', 'FARM', 'PROPOSALS', ...], ['ZIMBABWE', 'CONFIRMS', 'HOOF', '-', 'AND', '-', ...], ['Ia', '-', 'So', 'Minn', 'direct', 'hogs', ...], ['BELGIAN', 'MINISTER', 'SEES', 'NEW', 'ACCORD', 'ON', ...], ['HOG', 'REPORT', 'SHOWS', 'MORE', 'HOGS', 'ON', ...], ['U', '.', 'S', '.', 'TALLOW', 'PRODUCTION', 'AND', ...], ['U', '.', 'S', '.', 'LARD', 'CONSUMPTION', 'IN', ...], ['CHINESE', 'PORK', 'OUTPUT', 'SEEN', 'LOWER', '--', ...], ['ESTIMATED', 'U', '.', 'S', '.', 'POULTRY', ...], ['USDA', 'REPORT', 'ON', 'CATTLE', 'SLAUGHTER', ',', ...], ['U', '.', 'S', '.', 'HOUSE', 'PANEL', 'EXTENDS', ...], ['EXOTIC', 'NEWCASTLE', 'DISEASE', 'IN', 'MD', '/', ...], ['JAPAN', '/', 'U', '.', 'S', '.', 'AGRICULTURE', ...], ['U', '.', 'S', '.', 'MEAT', 'PROCESSORS', 'ASK', ...], ['JAPAN', "'", 'S', 'LIPC', 'TO', 'BUY', 'BEEF', 'ON', ...], ['JAPAN', "'", 'S', 'LIPC', 'TO', 'BUY', 'BEEF', 'ON', ...], ['USDA', 'PROPOSES', 'NAME', 'CHANGES', 'IN', 'BEEF', ...], ['MANDATORY', 'PRODUCTION', 'CONTROLS', 'DEBATED', ...], ['PORK', 'CHECKOFF', 'REFUNDS', 'LESS', 'THAN', ...], ['U', '.', 'S', '.', 'IMMIGRATION', 'RULES', 'SPARK', ...], ['IRAQ', 'CCC', 'CREDIT', 'GUARANTEES', 'SWITCHED', ...], ['EC', 'SOURCES', 'DETAIL', 'NEW', 'FARM', 'SOCIAL', ...], ['MORE', 'PRESSURE', 'URGED', 'FOR', 'ASIA', 'TO', ...], ['U', '.', 'K', '.', 'GRAIN', '/', 'POTATO', 'FUTURES', ...], ['ANTIBIOTICS', 'IN', 'FEED', 'AID', 'DEADLY', ...], ['NPPC', 'DELEGATES', 'APPROVE', 'DISEASE', 'AND', ...], ['CUBAN', 'CATTLE', 'THREATENED', 'BY', 'DROUGHT', ...], ['PORK', 'DELEGATES', 'VOTE', 'ON', 'FARM', 'BILL', ...], ['MEATPACKERS', 'REJECT', 'OCCIDENTAL', '&', 'lt', ';', ...], ['HOG', 'AND', 'CATTLE', 'SLAUGHTER', 'GUESSTIMATES', ...], ['U', '.', 'K', '.', 'OFFICIALS', 'STUDY', ...], ['USDA', 'TO', 'CONDUCT', 'SURVEY', 'FOR', 'AVIAN', ...], ['AMERICAN', 'PORK', 'CONGRESS', 'TO', 'BE', ...], ['AUSTRALIAN', 'BEEF', 'OUTPUT', 'DECLINES', 'IN', ...], ['HOG', 'AND', 'CATTLE', 'SLAUGHTER', 'GUESSTIMATES', ...], ['U', '.', 'K', '.', 'AGRICULTURAL', 'FUTURES', ...], ['LMFE', 'TO', 'CONCENTRATE', 'ON', 'CASH', 'SETTLED', ...], ['MEATPACKERS', 'STRIKE', 'MORRELL', 'SIOUX', 'CITY', ...], ['CCC', 'ACCEPTS', 'EXPORT', 'BONUS', 'DAIRY', ...], ['CCC', 'EXPORT', 'BONUS', 'DAIRY', 'CATTLE', 'FOR', ...], ['HOG', 'AND', 'CATTLE', 'SLAUGHTER', 'GUESSTIMATES', ...], ['ARGENTINE', 'MEAT', 'EXPORTS', 'LOWER', 'IN', '1986', ...], ['ARGENTINE', 'MEAT', 'EXPORTS', 'HIGHER', 'IN', 'JAN', ...], ['AUSTRALIA', 'EXPECTS', 'RISE', 'IN', 'MEAT', ...], ['HOG', 'AND', 'CATTLE', 'SLAUGHTER', 'GUESSTIMATES', ...], ['HEALTH', 'EXPERTS', 'URG ...

# %%
# Preprocess the corpus, filter out non-alpha tokens, convert to lowercase, and remove punctuation and digits
def preprocess_corpus(corpus):
    table = str.maketrans('', '', string.punctuation + string.digits)
    return [[word.lower().translate(table) for word in doc if word.isalpha()] for doc in corpus]

corpus = preprocess_corpus(corpus)
corpus
# Out:
# [['japan',
#   'ministry',
#   'says',
#   'open',
#   'farm',
#   'trade',
#   'would',
#   'hit',
#   'u',
#   's',
#   'japan',
#   's',
#   'agriculture',
#   'ministry',
#   'angered',
#   'by',
#   'u',
#   's',
#   'demands',
#   'that',
#   'japan',
#   'open',
#   'its',
#   'farm',
#   'products',
#   'market',
#   'will',
#   'tell',
#   'u',
#   's',
#   'officials',
#   'at',
#   'talks',
#   'later',
#   'this',
#   'month',
#   'that',
#   'liberalisation',
#   'would',
#   'harm',
#   'existing',
#   'u',
#   's',
#   'farm',
#   'exports',
#   'to',
#   'japan',
#   'a',
#   'senior',
#   'ministry',
#   'official',
#   'said',
#   'imports',
#   'from',
#   'the',
#   'u',
#   's',
#   'would',
#   'drop',
#   'due',
#   'to',
#   'active',
#   'sales',
#   'drives',
#   'by',
#   'other',
#   'suppliers',
#   'the',
#   'official',
#   'who',
#   'declined',
#   'to',
#   'be',
#   'named',
#   'said',
#   'japan',
#   'is',
#   'the',
#   'largest',
#   'customer',
#   'for',
#   'u',
#   's',
#   'farm',
#   'products',
#   'and',
#   'it',
#   'is',
#   'not',
#   'reasonable',
#   'for',
#   'the',
#   'u',
#   's',
#   'to',
#   'demand',
#   'japan',
#   'liberalise',
#   'its',
#   'farm',
#   'import',
#   'market',
#   'he',
#   'said',
#   'agriculture',
#   'minister',
#   'mutsuki',
#   'kato',
#   'has',
#   'said',
#   'if',
#   'the',
#   'u',
#   's',
#   'insists',
#   'japan',
#   'open',
#   'its',
#   'protected',
#   'rice',
#   'market',
#   'it',
#   'will',
#   'also',
#   'open',
#   'its',
#   'wheat',
#   'market',
#   'where',
#   'volume',
#   'and',
#   'origin',
#   'are',
#   'regulated',
#   'to',
#   'protect',
#   'local',
#   'farmers',
#   'australia',
#   'and',
#   'canada',
#   'could',
#   'then',
#   'increase',
#   'their',
#   'wheat',
#   'exports',
#   'as',
#   'they',
#   'are',
#   'more',
#   'competitive',
#   'than',
#   'the',
#   'u',
#   's',
#   'he',
#   'said',
#   'end',
#   'users',
#   'would',
#   'also',
#   'buy',
#   'other',
#   'origins',
#   'grain',
#   'traders',
#   'said',
#   'u',
#   's',
#   'agriculture',
#   'secretary',
#   'richard',
#   'lyng',
#   'who',
#   'is',
#   'due',
#   'to',
#   'visit',
#   'japan',
#   'for',
#   'talks',
#   'between',
#   'april',
#   'has',
#   'said',
#   'he',
#   'will',
#   'ask',
#   'japan',
#   'to',
#   'offer',
#   'a',
#   'share',
#   'of',
#   'its',
#   'rice',
#   'market',
#   'to',
#   'u',
#   's',
#   'suppliers',
#   'and',
#   'remove',
#   'quotas',
#   'on',
#   'u',
#   's',
#   'beef',
#   'and',
#   'citrus',
#   'imports',
#   'other',
#   'countries',
#   'are',
#   'already',
#   'cutting',
#   'into',
#   'the',
#   'u',
#   's',
#   'market',
#   'share',
#   'here',
#   'australia',
#   'the',
#   'largest',
#   'beef',
#   'supplier',
#   'to',
#   'japan',
#   'has',
#   'been',
#   'trying',
#   'to',
#   'boost',
#   'exports',
#   'prior',
#   'to',
#   'the',
#   'expiry',
#   'of',
#   'a',
#   'four',
#   'year',
#   'beef',
#   'accord',
#   'next',
#   'march',
#   'imports',
#   'of',
#   'u',
#   's',
#   'corn',
#   'have',
#   'fallen',
#   'due',
#   'to',
#   'increased',
#   'sales',
#   'from',
#   'china',
#   'and',
#   'south',
#   'america',
#   'while',
#   'japanese',
#   'soybean',
#   'imports',
#   'from',
#   'brazil',
#   'are',
#   'expected',
#   'to',
#   'rise',
#   'sharply',
#   'this',
#   'year',
#   'although',
#   'the',
#   'u',
#   's',
#   'will',
#   'remain',
#   'the',
#   'largest',
#   'supplier',
#   'u',
#   's',
#   'feedgrain',
#   'sales',
#   'will',
#   'also',
#   'drop',
#   'if',
#   'japan',
#   'opens',
#   'up',
#   'its',
#   'beef',
#   'imports',
#   'since',
#   'japan',
#   'depends',
#   'almost',
#   'entirely',
#   'on',
#   'feedgrain',
#   'imports',
#   'mainly',
#   'from',
#   'the',
#   'u',
#   's',
#   'japanese',
#   'officials',
#   'said',
#   'an',
#   'indication',
#   'of',
#   'the',
#   'u',
#   's',
#   'position',
#   'came',
#   'last',
#   'december',
#   'when',
#   'under',
#   'secretary',
#   'of',
#   'agriculture',
#   'daniel',
#   'amstutz',
#   'said',
#   'japan',
#   'has',
#   'the',
#   'potential',
#   'to',
#   'provide',
#   'one',
#   'of',
#   'the',
#   'largest',
#   'boosts',
#   'to',
#   'u',
#   's',
#   'agricultural',
#   'exports',
#   'with',
#   'the',
#   'beef',
#   'market',
#   'alone',
#   'representing',
#   'some',
#   'one',
#   'billion',
#   'dlrs',
#   'in',
#   'new',
#   'business',
#   'the',
#   'u',
#   's',
#   'has',
#   'also',
#   'asked',
#   'the',
#   'general',
#   'agreement',
#   'on',
#   'tariffs',
#   'and',
#   'trade',
#   'to',
#   'investigate',
#   'the',
#   'legality',
#   'of',
#   'japanese',
#   'import',
#   'controls',
#   'on',
#   'other',
#   'farm',
#   'products',
#   'including',
#   'fruit',
#   'juices',
#   'purees',
#   'and',
#   'pulp',
#   'tomato',
#   'juice',
#   'ketchup',
#   'and',
#   'sauce',
#   'peanuts',
#   'prepared',
#   'beef',
#   'products',
#   'and',
#   'miscellaneous',
#   'beans',
#   'to',
#   'help',
#   'calm',
#   'heated',
#   'trade',
#   'relations',
#   'with',
#   'the',
#   'u',
#   's',
#   'japan',
#   's',
#   'top',
#   'business',
#   'group',
#   'keidanren',
#   'has',
#   'urged',
#   'the',
#   'government',
#   'to',
#   'remove',
#   'residual',
#   'import',
#   'restrictions',
#   'on',
#   'agricultural',
#   'products',
#   'but',
#   'agriculture',
#   'minister',
#   'kato',
#   'has',
#   'ruled',
#   'out',
#   'any',
#   'emotional',
#   'reaction',
#   'and',
#   'the',
#   'senior',
#   'ministry',
#   'official',
#   'said',
#   'the',
#   'farm',
#   'issue',
#   'should',
#   'not',
#   'become',
#   'a',
#   'scapegoat',
#   'for',
#   'trade',
#   'pressure',
#   'in',
#   'the',
#   'industrial',
#   'sector',
#   'japan',
#   'is',
#   'the',
#   'largest',
#   'buyer',
#   'of',
#   'u',
#   's',
#   'farm',
#   'products',
#   'and',
#   'these',
#   'issues',
#   'should',
#   'not',
#   'be',
#   'discussed',
#   'on',
#   'the',
#   'same',
#   'table',
#   'the',
#   'official',
#   'said'],
#  ['usda',
#   'to',
#   'propose',
#   'foreign',
#   'meat',
#   'inspection',
#   'rule',
#   'the',
#   'u',
#   's',
#   'agriculture',
#   'department',
#   'is',
#   'preparing',
#   'a',
#   'proposal',
#   'that',
#   'would',
#   'require',
#   'all',
#   'foreign',
#   'meat',
#   'products',
#   'to',
#   'be',
#   'inspected',
#   'at',
#   'their',
#   'point',
#   'of',
#   'arrival',
#   'in',
#   'the',
#   'united',
#   'states',
#   'a',
#   'usda',
#   'official',
#   'said',
#   'donald',
#   'houston',
#   'administrator',
#   'of',
#   'usda',
#   's',
#   'food',
#   'safety',
#   'and',
#   'inspection',
#   'service',
#   'fsis',
#   'told',
#   'a',
#   'house',
#   'agriculture',
#   'subcommittee',
#   'usda',
#   'was',
#   'developing',
#   'a',
#   'proposed',
#   'change',
#   'in',
#   'regulations',
#   'that',
#   'would',
#   'put',
#   'an',
#   'end',
#   'to',
#   'the',
#   'current',
#   'practice',
#   'of',
#   'permitting',
#   'foreign',
#   'meat',
#   'products',
#   'to',
#   'be',
#   'unloaded',
#   'at',
#   'one',
#   'port',
#   'and',
#   'inspected',
#   'at',
#   'another',
#   'port',
#   'houston',
#   'said',
#   'the',
#   'requirement',
#   'would',
#   'be',
#   'phased',
#   'in',
#   'over',
#   'several',
#   'years',
#   'to',
#   'avoid',
#   'disruptions',
#   'and',
#   'economic',
#   'hardship'],
#  ['u',
#   's',
#   'meat',
#   'poultry',
#   'inspection',
#   'called',
#   'faulty',
#   'the',
#   'u',
#   's',
#   'meat',
#   'and',
#   'poultry',
#   'inspection',
#   'programs',
#   'are',
#   'incapable',
#   'of',
#   'protecting',
#   'consumers',
#   'from',
#   'contaminated',
#   'products',
#   'groups',
#   'representing',
#   'inspectors',
#   'and',
#   'consumers',
#   'charged',
#   'the',
#   'whole',
#   'trend',
#   'of',
#   'inspection',
#   'for',
#   'the',
#   'last',
#   'years',
#   'has',
#   'been',
#   'to',
#   'corrupt',
#   'and',
#   'to',
#   'degrade',
#   'the',
#   'system',
#   'where',
#   'today',
#   'the',
#   'public',
#   'is',
#   'at',
#   'constant',
#   'risk',
#   'to',
#   'contaminated',
#   'and',
#   'adulterated',
#   'meat',
#   'kenneth',
#   'blaylock',
#   'president',
#   'of',
#   'the',
#   'american',
#   'federation',
#   'of',
#   'government',
#   'employees',
#   'told',
#   'a',
#   'house',
#   'agriculture',
#   'subcommittee',
#   'the',
#   'american',
#   'consumer',
#   'has',
#   'little',
#   'reason',
#   'to',
#   'feel',
#   'confident',
#   'about',
#   'the',
#   'safety',
#   'of',
#   'meat',
#   'and',
#   'poultry',
#   'being',
#   'offered',
#   'to',
#   'him',
#   'today',
#   'said',
#   'rodney',
#   'leonard',
#   'executive',
#   'director',
#   'of',
#   'the',
#   'community',
#   'nutrition',
#   'institute',
#   'company',
#   'management',
#   'is',
#   'less',
#   'concerned',
#   'about',
#   'the',
#   'risk',
#   'to',
#   'health',
#   'than',
#   'about',
#   'raising',
#   'plant',
#   'output',
#   'and',
#   'company',
#   'profits',
#   'leonard',
#   'told',
#   'a',
#   'hearing',
#   'of',
#   'the',
#   'house',
#   'agriculture',
#   'subcommittee',
#   'on',
#   'livestock',
#   'dairy',
#   'and',
#   'poultry',
#   'kenneth',
#   'morrison',
#   'staff',
#   'associate',
#   'at',
#   'the',
#   'government',
#   'accountability',
#   'project',
#   'said',
#   'inspectors',
#   'consistently',
#   'disclose',
#   'violations',
#   'of',
#   'federal',
#   'law',
#   'demonstrating',
#   'a',
#   'serious',
#   'breakdown',
#   'in',
#   'the',
#   'entire',
#   'inspection',
#   'system',
#   'morrison',
#   'told',
#   'of',
#   'chicken',
#   'fat',
#   'for',
#   'flavoring',
#   'being',
#   'contaminated',
#   'by',
#   'intestines',
#   'dragging',
#   'in',
#   'a',
#   'water',
#   'trough',
#   'used',
#   'to',
#   'flush',
#   'away',
#   'the',
#   'condemned',
#   'product',
#   'fecal',
#   'material',
#   'human',
#   'spit',
#   'chewing',
#   'gum',
#   'and',
#   'paper',
#   'towels',
#   'used',
#   'by',
#   'plant',
#   'employees',
#   'to',
#   'blow',
#   'their',
#   'noses',
#   'donald',
#   'houston',
#   'administrator',
#   'of',
#   'the',
#   'u',
#   's',
#   'agriculture',
#   'department',
#   's',
#   'food',
#   'safety',
#   'and',
#   'inspection',
#   'service',
#   'fsis',
#   'defended',
#   'the',
#   'government',
#   's',
#   'program',
#   'calling',
#   'it',
#   'one',
#   'of',
#   'the',
#   'most',
#   'respected',
#   'public',
#   'health',
#   'programs',
#   'in',
#   'the',
#   'world',
#   'fsis',
#   'inspects',
#   'an',
#   'estimated',
#   'mln',
#   'head',
#   'of',
#   'cattle',
#   'and',
#   'billion',
#   'chicken',
#   'and',
#   'turkeys',
#   'every',
#   'year',
#   'houston',
#   'said',
#   'inspection',
#   'programs',
#   'have',
#   'kept',
#   'pace',
#   'with',
#   'change',
#   'but',
#   'conceded',
#   'that',
#   'the',
#   'danger',
#   'of',
#   'chemical',
#   'residues',
#   'in',
#   'the',
#   'meat',
#   'and',
#   'poultry',
#   'supply',
#   'has',
#   'increased',
#   'he',
#   'also',
#   'said',
#   'that',
#   'although',
#   'he',
#   'was',
#   'confident',
#   'the',
#   'bacterium',
#   'salmonella',
#   'eventually',
#   'could',
#   'be',
#   'eradicated',
#   'it',
#   'would',
#   'take',
#   'time',
#   'and',
#   'much',
#   'money',
#   'to',
#   'contain',
#   'the',
#   'growing',
#   'problem',
#   'salmonella',
#   'which',
#   'in',
#   'extreme',
#   'cases',
#   'can',
#   'cause',
#   'death',
#   'is',
#   'found',
#   'in',
#   'approximately',
#   'pct',
#   'of',
#   'u',
#   's',
#   'broilers',
#   'pct',
#   'of',
#   'raw',
#   'pork',
#   'and',
#   'three',
#   'to',
#   'five',
#   'pct',
#   'of',
#   'raw',
#   'beef',
#   'houston',
#   'said',
#   'the',
#   'number',
#   'of',
#   'reported',
#   'cases',
#   'has',
#   'doubled',
#   'over',
#   'the',
#   'past',
#   'years',
#   'he',
#   'said',
#   'to',
#   'cases',
#   'annually',
#   'we',
#   'certainly',
#   'really',
#   'have',
#   'not',
#   'found',
#   'an',
#   'effective',
#   'means',
#   'of',
#   'turning',
#   'this',
#   'disease',
#   'around',
#   'said',
#   'rep',
#   'james',
#   'olin',
#   'd',
#   'va',
#   'the',
#   'national',
#   'research',
#   'council',
#   'recommended',
#   'in',
#   'that',
#   'fsis',
#   'intensify',
#   'efforts',
#   'to',
#   'develop',
#   'rapid',
#   'diagnostic',
#   'procedures',
#   'for',
#   'detecting',
#   'microoganisms',
#   'but',
#   'the',
#   'meat',
#   'and',
#   'poultry',
#   'industries',
#   'have',
#   'said',
#   'such',
#   'controls',
#   'would',
#   'cost',
#   'too',
#   'much',
#   'hopefully',
#   'we',
#   'will',
#   'not',
#   'overreact',
#   'by',
#   'installing',
#   'unnecessarily',
#   'complicated',
#   'procedures',
#   'that',
#   'may',
#   'become',
#   'obstacles',
#   'to',
#   'the',
#   'real',
#   'goal',
#   'of',
#   'providing',
#   'an',
#   'increasingly',
#   'safer',
#   'more',
#   'nutritious',
#   'and',
#   'economical',
#   'meat',
#   'supply',
#   'for',
#   'consumers',
#   'stanley',
#   'emerling',
#   'executive',
#   'vice',
#   'president',
#   'of',
#   'the',
#   'national',
#   'association',
#   'of',
#   'meat',
#   'purveyors',
#   'said',
#   'blaylock',
#   'speaking',
#   'on',
#   'behalf',
#   'of',
#   'food',
#   'inspectors',
#   'said',
#   'a',
#   'new',
#   'program',
#   'allowing',
#   'elimination',
#   'of',
#   'usda',
#   'inspection',
#   'functions',
#   'at',
#   'certain',
#   'plants',
#   'voids',
#   'the',
#   'law',
#   'in',
#   'letter',
#   'and',
#   'spirit',
#   'and',
#   'must',
#   'be',
#   'repealed',
#   'or',
#   'we',
#   'will',
#   'see',
#   'rising',
#   'consumer',
#   'fraud',
#   'and',
#   'an',
#   'epidemic',
#   'of',
#   'death',
#   'and',
#   'illness',
#   'for',
#   'which',
#   'there',
#   'will',
#   'be',
#   'no',
#   'prevention',
#   'nor',
#   'legal',
#   'recourse',
#   'subcommittee',
#   'chairman',
#   'charles',
#   'stenholm',
#   'd',
#   'tex',
#   'said',
#   'the',
#   'panel',
#   'would',
#   'hold',
#   'a',
#   'hearing',
#   'on',
#   'salmonella',
#   'june'],
#  ['mexican',
#   'cattle',
#   'imports',
#   'to',
#   'be',
#   'branded',
#   'usda',
#   'all',
#   'steers',
#   'imported',
#   'into',
#   'the',
#   'united',
#   'states',
#   'from',
#   'mexico',
#   'must',
#   'now',
#   'be',
#   'branded',
#   'with',
#   'the',
#   'letter',
#   'm',
#   'on',
#   'the',
#   'right',
#   'jaw',
#   'the',
#   'u',
#   's',
#   'agriculture',
#   'department',
#   'said',
#   'in',
#   'its',
#   'world',
#   'production',
#   'and',
#   'trade',
#   'report',
#   'the',
#   'department',
#   'said',
#   'the',
#   'branding',
#   'is',
#   'necessary',
#   'to',
#   'improve',
#   'surveillance',
#   'for',
#   'bovine',
#   'tuberculosis',
#   'because',
#   'it',
#   'provides',
#   'a',
#   'permanent',
#   'way',
#   'to',
#   'identify',
#   'mexican',
#   'steers',
#   'the',
#   'requirement',
#   'is',
#   'not',
#   'expected',
#   'to',
#   'affect',
#   'the',
#   'number',
#   'of',
#   'mexican',
#   'steers',
#   'imported',
#   'into',
#   'the',
#   'united',
#   'states',
#   'and',
#   'the',
#   'brand',
#   'will',
#   'be',
#   'applied',
#   'before',
#   'the',
#   'animals',
#   'arrive',
#   'at',
#   'u',
#   's',
#   'ports',
#   'of',
#   'entry',
#   'last',
#   'november',
#   'the',
#   'mexican',
#   'government',
#   'authorized',
#   'an',
#   'export',
#   'quota',
#   'of',
#   'nearly',
#   'mln',
#   'head',
#   'of',
#   'live',
#   'cattle',
#   'for',
#   'the',
#   'season',
#   'aug',
#   'july',
#   'most',
#   'of',
#   'which',
#   'goes',
#   'to',
#   'the',
#   'united',
#   'states'],
#  ['argentine',
#   'cattle',
#   'market',
#   'report',
#   'about',
#   'head',
#   'of',
#   'cattle',
#   'were',
#   'auctioned',
#   'in',
#   'liniers',
#   'cattle',
#   'market',
#   'against',
#   'on',
#   'wednesday',
#   'and',
#   'last',
#   'thursday',
#   'trade',
#   'sources',
#   'said',
#   'maximun',
#   'prices',
#   'in',
#   'australes',
#   'per',
#   'kilo',
#   'with',
#   'dollar',
#   'equivalent',
#   'in',
#   'brackets',
#   'included',
#   'today',
#   'wednesday',
#   'steers',
#   'over',
#   'kilos',
#   'steers',
#   'to',
#   'kilos',
#   'cows',
#   'for',
#   'canning',
#   'reuter'],
#  ['hog',
#   'and',
#   'cattle',
#   'slaughter',
#   'guesstimates',
#   'chicago',
#   'mercantile',
#   'exchange',
#   'floor',
#   'traders',
#   'and',
#   'commission',
#   'house',
#   'representatives',
#   'are',
#   'guesstimating',
#   'today',
#   's',
#   'hog',
#   'slaughter',
#   'at',
#   'about',
#   'to',
#   'head',
#   'versus',
#   'week',
#   'ago',
#   'and',
#   'a',
#   'year',
#   'ago',
#   'cattle',
#   'slaughter',
#   'is',
#   'guesstimated',
#   'at',
#   'about',
#   'to',
#   'head',
#   'versus',
#   'week',
#   'ago',
#   'and',
#   'a',
#   'year',
#   'ago'],
#  ['eastern',
#   'distributive',
#   'beef',
#   'trade',
#   'weekly',
#   'usda',
#   'demand',
#   'good',
#   'for',
#   'moderate',
#   'supplies',
#   'of',
#   'most',
#   'beef',
#   'cuts',
#   'however',
#   'limited',
#   'interest',
#   'noted',
#   'for',
#   'tenderloins',
#   'flank',
#   'steaks',
#   'yield',
#   'grade',
#   'beef',
#   'cuts',
#   'fabricated',
#   'items',
#   'vacuum',
#   'packed',
#   'lbs',
#   'choice',
#   'round',
#   'cuts',
#   'steady',
#   'up',
#   'round',
#   'part',
#   'bnls',
#   'few',
#   'round',
#   'bnls',
#   'few',
#   'diamond',
#   'cut',
#   'few',
#   'knuckle',
#   'few',
#   'knuckle',
#   'peeled',
#   'few',
#   'top',
#   'inside',
#   'round',
#   'bottom',
#   'gooseneck',
#   'rnd',
#   'more'],
#  ['disease',
#   'puts',
#   'zimbabwe',
#   'beef',
#   'exports',
#   'in',
#   'jeopardy',
#   'zimbabwe',
#   's',
#   'beef',
#   'exports',
#   'to',
#   'the',
#   'european',
#   'community',
#   'ec',
#   'potentially',
#   'worth',
#   'mln',
#   'zimbabwean',
#   'dlrs',
#   'this',
#   'year',
#   'may',
#   'be',
#   'jeopardised',
#   'by',
#   'an',
#   'outbreak',
#   'of',
#   'foot',
#   'and',
#   'mouth',
#   'disease',
#   'in',
#   'southwestern',
#   'matabeleland',
#   'industry',
#   'sources',
#   'said',
#   'the',
#   'country',
#   'has',
#   'temporarily',
#   'suspended',
#   'beef',
#   'exports',
#   'to',
#   'the',
#   'ec',
#   'because',
#   'of',
#   'the',
#   'outbreak',
#   'and',
#   'awaits',
#   'a',
#   'decision',
#   'from',
#   'the',
#   'ec',
#   'veterinary',
#   'committee',
#   'which',
#   'is',
#   'considering',
#   'a',
#   'formal',
#   'ban',
#   'the',
#   'outbreak',
#   'in',
#   'the',
#   'country',
#   's',
#   'main',
#   'ranching',
#   'province',
#   'has',
#   'already',
#   'led',
#   'neighbouring',
#   'beef',
#   'producing',
#   'botswana',
#   'and',
#   'zambia',
#   'to',
#   'bar',
#   'beef',
#   'and',
#   'dairy',
#   'imports',
#   'from',
#   'zimbabwe',
#   'threatening',
#   'the',
#   'dairy',
#   'industry',
#   'with',
#   'a',
#   'loss',
#   'of',
#   'at',
#   'least',
#   'one',
#   'mln',
#   'dlrs',
#   'in',
#   'export',
#   'revenue',
#   'the',
#   'situation',
#   'is',
#   'still',
#   'uncertain',
#   'at',
#   'the',
#   'moment',
#   'normally',
#   'when',
#   'an',
#   'outbreak',
#   'occurs',
#   'there',
#   'is',
#   'an',
#   'automatic',
#   'suspension',
#   'of',
#   'beef',
#   'exports',
#   'one',
#   'industry',
#   'source',
#   'said',
#   'yesterday',
#   'commenting',
#   'on',
#   'ec',
#   'policy',
#   'he',
#   'explained',
#   'depending',
#   'on',
#   'the',
#   'seriousness',
#   'of',
#   'the',
#   'outbreak',
#   'the',
#   'veterinary',
#   'committee',
#   'then',
#   'decides',
#   'on',
#   'three',
#   'options',
#   'allowing',
#   'us',
#   'to',
#   'continue',
#   'exporting',
#   'beef',
#   'from',
#   'disease',
#   'free',
#   'areas',
#   'clamping',
#   'a',
#   'three',
#   'month',
#   'suspension',
#   'on',
#   'exports',
#   'or',
#   'banning',
#   'us',
#   'from',
#   'exporting',
#   'for',
#   'a',
#   'year',
#   'we',
#   'are',
#   'still',
#   'awaiting',
#   'their',
#   'decision',
#   'he',
#   'added',
#   'asking',
#   'not',
#   'to',
#   'be',
#   'identified',
#   'zimbabwe',
#   'was',
#   'granted',
#   'an',
#   'export',
#   'quota',
#   'of',
#   'tonnes',
#   'of',
#   'high',
#   'grade',
#   'beef',
#   'to',
#   'ec',
#   'markets',
#   'in',
#   'after',
#   'the',
#   'country',
#   'had',
#   'spent',
#   'millions',
#   'of',
#   'dollars',
#   'erecting',
#   'disease',
#   'control',
#   'fences',
#   'and',
#   'upgrading',
#   'abattoirs',
#   'to',
#   'meet',
#   'stringent',
#   'ec',
#   'rules',
#   'should',
#   'the',
#   'ec',
#   'ban',
#   'zimbabwean',
#   'exports',
#   'the',
#   'country',
#   'will',
#   'be',
#   'forced',
#   'to',
#   'sell',
#   'its',
#   'beef',
#   'on',
#   'glutted',
#   'world',
#   'beef',
#   'markets',
#   'at',
#   'low',
#   'prices',
#   'the',
#   'source',
#   'said',
#   'projected',
#   'earnings',
#   'from',
#   'beef',
#   'sales',
#   'could',
#   'fall',
#   'about',
#   'mln',
#   'dlrs',
#   'as',
#   'a',
#   'result',
#   'he',
#   'said'],
#  ['ccc',
#   'guarantees',
#   'to',
#   'iraq',
#   'switched',
#   'usda',
#   'the',
#   'commodity',
#   'credit',
#   'corporation',
#   'ccc',
#   'has',
#   'transferred',
#   'mln',
#   'dlrs',
#   'in',
#   'credit',
#   'guarantees',
#   'previously',
#   'earmarked',
#   'for',
#   'sales',
#   'of',
#   'u',
#   's',
#   'hatching',
#   'eggs',
#   'and',
#   'mln',
#   'dlrs',
#   'in',
#   'guarantees',
#   'for',
#   'breeder',
#   'livestock',
#   'to',
#   'increase',
#   'coverage',
#   'on',
#   'sales',
#   'of',
#   'u',
#   's',
#   'protein',
#   'concentrates',
#   'to',
#   'iraq',
#   'the',
#   'u',
#   's',
#   'agriculture',
#   'department',
#   'said',
#   'the',
#   'action',
#   'was',
#   'taken',
#   'at',
#   'the',
#   'request',
#   'of',
#   'iraq',
#   's',
#   'state',
#   'trade',
#   'organization',
#   'for',
#   'grains',
#   'and',
#   'foodstuffs',
#   'and',
#   'reduces',
#   'the',
#   'line',
#   'for',
#   'hatching',
#   'eggs',
#   'to',
#   'zero',
#   'and',
#   'the',
#   'line',
#   'for',
#   'breeder',
#   'livestock',
#   'from',
#   'mln',
#   'dlrs',
#   'to',
#   'mln',
#   'dlrs',
#   'the',
#   'department',
#   'said',
#   'the',
#   'guarantee',
#   'line',
#   'for',
#   'sales',
#   'of',
#   'protein',
#   'concentrates',
#   'has',
#   'been',
#   'increased',
#   'from',
#   'mln',
#   'dlrs',
#   'to',
#   'mln',
#   'dlrs',
#   'it',
#   'said'],
#  ['u',
#   's',
#   'dollar',
#   'losses',
#   'propel',
#   'broad',
#   'commodity',
#   'gains',
#   'commodities',
#   'from',
#   'gold',
#   'to',
#   'grains',
#   'to',
#   'cotton',
#   'posted',
#   'solid',
#   'gains',
#   'in',
#   'a',
#   'flurry',
#   'of',
#   'buying',
#   'today',
#   'as',
#   'losses',
#   'in',
#   'the',
#   'u',
#   's',
#   'dollar',
#   'and',
#   'rising',
#   'interest',
#   'rates',
#   'kindled',
#   'fears',
#   'of',
#   'inflation',
#   'and',
#   'economic',
#   'instability',
#   'gains',
#   'were',
#   'most',
#   'pronounced',
#   'on',
#   'the',
#   'commodity',
#   'exchange',
#   'in',
#   'new',
#   'york',
#   'where',
#   'gold',
#   'jumped',
#   'dlrs',
#   'and',
#   'closed',
#   'at',
#   'dlrs',
#   'a',
#   'troy',
#   'ounce',
#   'and',
#   'silver',
#   'cents',
#   'to',
#   'dlrs',
#   'a',
#   'troy',
#   'ounce',
#   'a',
#   'key',
#   'factor',
#   'behind',
#   'the',
#   'advance',
#   'was',
#   'anticipation',
#   'that',
#   'inflation',
#   'will',
#   'be',
#   'the',
#   'only',
#   'way',
#   'for',
#   'the',
#   'major',
#   'industrial',
#   'nations',
#   'to',
#   'halt',
#   'the',
#   'slide',
#   'in',
#   'the',
#   'value',
#   'of',
#   'the',
#   'u',
#   's',
#   'dollar',
#   'said',
#   'steve',
#   'chronowitz',
#   'director',
#   'of',
#   'commodity',
#   'research',
#   'with',
#   'smith',
#   'barney',
#   'harris',
#   'upham',
#   'and',
#   'co',
#   'in',
#   'new',
#   'york',
#   'the',
#   'dollar',
#   'tumbled',
#   'one',
#   'day',
#   'after',
#   'top',
#   'finance',
#   'officials',
#   'from',
#   'the',
#   'seven',
#   'largest',
#   'industrial',
#   'nations',
#   'reaffirmed',
#   'their',
#   'commitment',
#   'to',
#   'support',
#   'its',
#   'value',
#   'and',
#   'despite',
#   'reports',
#   'of',
#   'intervention',
#   'by',
#   'the',
#   'u',
#   's',
#   'federal',
#   'reserve',
#   'bank',
#   'traders',
#   'said',
#   'traders',
#   'said',
#   'it',
#   'appears',
#   'that',
#   'the',
#   'industrial',
#   'nations',
#   'known',
#   'as',
#   'the',
#   'group',
#   'of',
#   'seven',
#   'lack',
#   'the',
#   'ability',
#   'to',
#   'change',
#   'the',
#   'long',
#   'term',
#   'direction',
#   'of',
#   'the',
#   'currency',
#   'markets',
#   'maybe',
#   'they',
#   'have',
#   'some',
#   'ideas',
#   'or',
#   'plans',
#   'said',
#   'chronowitz',
#   'if',
#   'they',
#   'do',
#   'it',
#   's',
#   'not',
#   'evident',
#   'it',
#   'looks',
#   'like',
#   'there',
#   's',
#   'no',
#   'cure',
#   'but',
#   'to',
#   'let',
#   'the',
#   'free',
#   'market',
#   'take',
#   'values',
#   'to',
#   'where',
#   'they',
#   'should',
#   'be',
#   'one',
#   'way',
#   'or',
#   'another',
#   'we',
#   'will',
#   'force',
#   'our',
#   'major',
#   'trading',
#   'partners',
#   'to',
#   'stimulate',
#   'their',
#   'economies',
#   'as',
#   'a',
#   'measure',
#   'to',
#   'correct',
#   'the',
#   'mounting',
#   'u',
#   's',
#   'trade',
#   'deficit',
#   'chronowitz',
#   'said',
#   'i',
#   'think',
#   'the',
#   'markets',
#   'believe',
#   'and',
#   'have',
#   'believed',
#   'for',
#   'a',
#   'long',
#   'time',
#   'that',
#   'the',
#   'only',
#   'recourse',
#   'is',
#   'to',
#   'reflate',
#   'at',
#   'some',
#   'point',
#   'it',
#   's',
#   'going',
#   'to',
#   'be',
#   'a',
#   'long',
#   'and',
#   'tedious',
#   'process',
#   'but',
#   'that',
#   's',
#   'what',
#   's',
#   'happening',
#   'he',
#   'said',
#   'the',
#   'falling',
#   'value',
#   'of',
#   'the',
#   'dollar',
#   'makes',
#   'u',
#   's',
#   'commodities',
#   'cheaper',
#   'for',
#   'foreign',
#   'buyers',
#   'stimulating',
#   'demand',
#   'at',
#   'the',
#   'same',
#   'time',
#   'traders',
#   'who',
#   'are',
#   'holding',
#   'stocks',
#   'and',
#   'bonds',
#   'saw',
#   'the',
#   'value',
#   'of',
#   'their',
#   'investments',
#   'falling',
#   'and',
#   'many',
#   'are',
#   'turning',
#   'to',
#   'commodities',
#   'such',
#   'as',
#   'precious',
#   'metals',
#   'as',
#   'a',
#   'hedge',
#   'said',
#   'marty',
#   'mcneill',
#   'a',
#   'metals',
#   'analyst',
#   'in',
#   'new',
#   'york',
#   'with',
#   'the',
#   'trading',
#   'house',
#   'of',
#   'dominick',
#   'and',
#   'dominick',
#   'the',
#   'reaction',
#   'in',
#   'the',
#   'metal',
#   'markets',
#   'reverberated',
#   'throughout',
#   'the',
#   'commodities',
#   'markets',
#   'as',
#   'grains',
#   'livestock',
#   'and',
#   'cotton',
#   'posted',
#   'broad',
#   'gains',
#   'traders',
#   'at',
#   'the',
#   'chicago',
#   'board',
#   'of',
#   'trade',
#   'said',
#   'attention',
#   'in',
#   'the',
#   'grain',
#   'markets',
#   'has',
#   'shifted',
#   'from',
#   'concern',
#   'about',
#   'burdensome',
#   'supplies',
#   'to',
#   'the',
#   'outlook',
#   'that',
#   'a',
#   'lower',
#   'dollar',
#   'will',
#   'stimulate',
#   'export',
#   'demand',
#   'after',
#   'the',
#   'close',
#   'of',
#   'trading',
#   'the',
#   'agriculture',
#   'department',
#   'raised',
#   'its',
#   'estimate',
#   'for',
#   'grain',
#   'imports',
#   'by',
#   'the',
#   'soviet',
#   'union',
#   'by',
#   'two',
#   'mln',
#   'tonnes',
#   'from',
#   'the',
#   'month',
#   'earlier',
#   'report',
#   'live',
#   'hogs',
#   'and',
#   'frozen',
#   'pork',
#   'bellies',
#   'posted',
#   'sharp',
#   'gains',
#   'on',
#   'the',
#   'chicago',
#   'mercantile',
#   'exchange',
#   'while',
#   'live',
#   'cattle',
#   'were',
#   'moderately',
#   'higher',
#   'analysts',
#   'said',
#   'several',
#   'factors',
#   'boosted',
#   'hog',
#   'prices',
#   'they',
#   'said',
#   'hogs',
#   'haven',
#   't',
#   'been',
#   'making',
#   'the',
#   'weight',
#   'gains',
#   'that',
#   'are',
#   'normal',
#   'at',
#   'this',
#   'time',
#   'of',
#   'year',
#   'and',
#   'farmers',
#   'have',
#   'been',
#   'too',
#   'busy',
#   'with',
#   'field',
#   'work',
#   'to',
#   'market',
#   'animals'],
#  ['u',
#   's',
#   'feeder',
#   'steer',
#   'price',
#   'the',
#   'u',
#   's',
#   'feeder',
#   'steer',
#   'price',
#   'or',
#   'usfsp',
#   'as',
#   'posted',
#   'by',
#   'the',
#   'cme',
#   'is',
#   'calculated',
#   'by',
#   'cattle',
#   'fax',
#   'and',
#   'represents',
#   'the',
#   'price',
#   'used',
#   'for',
#   'cash',
#   'settlement',
#   'of',
#   'the',
#   'cme',
#   'feeder',
#   'cattle',
#   'contract',
#   'the',
#   'usfsp',
#   'is',
#   'a',
#   'seven',
#   'calendar',
#   'day',
#   'average',
#   'of',
#   'feeder',
#   'steer',
#   'prices',
#   'from',
#   'states',
#   'based',
#   'on',
#   'auction',
#   'and',
#   'direct',
#   'country',
#   'sales',
#   'for',
#   'feeder',
#   'steers',
#   'that',
#   'weigh',
#   'between',
#   'and',
#   'lbs',
#   'and',
#   'are',
#   'estimated',
#   'to',
#   'grade',
#   'between',
#   'and',
#   'pct',
#   'choice',
#   'when',
#   'fed',
#   'to',
#   'slaughter',
#   'weight',
#   'april',
#   'previous',
#   'quote'],
#  ['hog',
#   'and',
#   'cattle',
#   'slaughter',
#   'guesstimates',
#   'chicago',
#   'mercantile',
#   'exchange',
#   'floor',
#   'traders',
#   'and',
#   'commission',
#   'house',
#   'representatives',
#   'are',
#   'guesstimating',
#   'today',
#   's',
#   'hog',
#   'slaughter',
#   'at',
#   'about',
#   'to',
#   'head',
#   'versus',
#   'week',
#   'ago',
#   'and',
#   'a',
#   'year',
#   'ago',
#   'cattle',
#   'slaughter',
#   'is',
#   'guesstimated',
#   'at',
#   'about',
#   'to',
#   'head',
#   'versus',
#   'week',
#   'ago',
#   'and',
#   'a',
#   'year',
#   'ago'],
#  ['ccc',
#   'accepts',
#   'bonus',
#   'on',
#   'cattle',
#   'to',
#   'canary',
#   'islands',
#   'the',
#   'commodity',
#   'credit',
#   'corporation',
#   'ccc',
#   'has',
#   'accepted',
#   'a',
#   'bid',
#   'for',
#   'an',
#   'export',
#   'bonus',
#   'to',
#   'cover',
#   'the',
#   'sale',
#   'of',
#   'head',
#   'of',
#   'dairy',
#   'cattle',
#   'to',
#   'the',
#   'canary',
#   'islands',
#   'the',
#   'u',
#   's',
#   'agriculture',
#   'department',
#   'said',
#   'the',
#   'cattle',
#   'are',
#   'for',
#   'delivery',
#   'may',
#   'october',
#   'it',
#   'said',
#   'the',
#   'bonus',
#   'was',
#   'dlrs',
#   'per',
#   'head',
#   'and',
#   'was',
#   'made',
#   'to',
#   'holstein',
#   'friesian',
#   'inc',
#   'and',
#   'will',
#   'be',
#   'paid',
#   'in',
#   'the',
#   'form',
#   'of',
#   'commodities',
#   'from',
#   'the',
#   'ccc',
#   'inventory',
#   'an',
#   'additional',
#   'headed',
#   'of',
#   'dairy',
#   'cattle',
#   'for',
#   'still',
#   'available',
#   'to',
#   'the',
#   'canary',
#   'islands',
#   'under',
#   'the',
#   'export',
#   'enhancement',
#   'program',
#   'initiative',
#   'announced',
#   'july',
#   'it',
#   'said'],
#  ['swift',
#   'to',
#   'sell',
#   'south',
#   'dakota',
#   'pork',
#   'plant',
#   'swift',
#   'independent',
#   'packing',
#   'co',
#   'said',
#   'it',
#   'agreed',
#   'in',
#   'principle',
#   'to',
#   'sell',
#   'its',
#   'huron',
#   'south',
#   'dakota',
#   'pork',
#   'plant',
#   'to',
#   'huron',
#   'dressed',
#   'beef',
#   'for',
#   'undisclosed',
#   'terms',
#   'completion',
#   'of',
#   'the',
#   'proposed',
#   'transaction',
#   'is',
#   'subject',
#   'to',
#   'huron',
#   's',
#   'ability',
#   'to',
#   'hire',
#   'an',
#   'experienced',
#   'work',
#   'force',
#   'at',
#   'competitive',
#   'rates',
#   'and',
#   'receive',
#   'government',
#   'approval',
#   'of',
#   'the',
#   'purchase',
#   'and',
#   'operation',
#   'of',
#   'the',
#   'plant',
#   'swift',
#   'said'],
#  ['swift',
#   'lt',
#   'sftpf',
#   'to',
#   'sell',
#   'south',
#   'dakota',
#   'pork',
#   'plant',
#   'swift',
#   'independent',
#   'packing',
#   'co',
#   'said',
#   'it',
#   'agreed',
#   'in',
#   'principle',
#   'to',
#   'sell',
#   'its',
#   'huron',
#   'south',
#   'dakota',
#   'pork',
#   'plant',
#   'to',
#   'huron',
#   'dressed',
#   'beef',
#   'for',
#   'undisclosed',
#   'terms',
#   'completion',
#   'of',
#   'the',
#   'proposed',
#   'transaction',
#   'is',
#   'subject',
#   'to',
#   'huron',
#   's',
#   'ability',
#   'to',
#   'hire',
#   'an',
#   'experienced',
#   'work',
#   'force',
#   'at',
#   'competitive',
#   'rates',
#   'and',
#   'receive',
#   'government',
#   'approval',
#   'of',
#   'the',
#   'purchase',
#   'and',
#   'operation',
#   'of',
#   'the',
#   'plant',
#   'swift',
#   'said'],
#  ['ec',
#   'meat',
#   'directive',
#   'deadline',
#   'seen',
#   'flexible',
#   'u',
#   's',
#   'officials',
#   'said',
#   'they',
#   'held',
#   'out',
#   'little',
#   'hope',
#   'the',
#   'european',
#   'community',
#   'ec',
#   'would',
#   'withdraw',
#   'a',
#   'controversial',
#   'meat',
#   'inspection',
#   'requirement',
#   'due',
#   'to',
#   'go',
#   'into',
#   'effect',
#   'april',
#   'and',
#   'which',
#   'u',
#   's',
#   'meat',
#   'producers',
#   'claim',
#   'will',
#   'cut',
#   'off',
#   'their',
#   'exports',
#   'but',
#   'the',
#   'officials',
#   'said',
#   'they',
#   'expect',
#   'the',
#   'ec',
#   'to',
#   'allow',
#   'u',
#   's',
#   'plants',
#   'to',
#   'continue',
#   'shipping',
#   'meat',
#   'through',
#   'the',
#   'end',
#   'of',
#   'the',
#   'year',
#   'provided',
#   'they',
#   'submit',
#   'a',
#   'plant',
#   'improvement',
#   'program',
#   'with',
#   'the',
#   'u',
#   's',
#   'agriculture',
#   'department',
#   'the',
#   'ec',
#   's',
#   'so',
#   'called',
#   'third',
#   'country',
#   'meat',
#   'directive',
#   'will',
#   'require',
#   'foreign',
#   'meat',
#   'processing',
#   'plants',
#   'to',
#   'comply',
#   'fully',
#   'with',
#   'ec',
#   'inspection',
#   'standards',
#   'beginning',
#   'april',
#   'the',
#   'u',
#   's',
#   'meat',
#   'industry',
#   'has',
#   'prepared',
#   'a',
#   'petition',
#   'requesting',
#   'the',
#   'reagan',
#   'administration',
#   'to',
#   'retaliate',
#   'against',
#   'the',
#   'ec',
#   'rule',
#   'at',
#   'issue',
#   'are',
#   'u',
#   's',
#   'meat',
#   'exports',
#   'to',
#   'the',
#   'ec',
#   'valued',
#   'at',
#   'mln',
#   'dlrs',
#   'in',
#   'the',
#   'ec',
#   'rule',
#   'would',
#   'require',
#   'all',
#   'u',
#   's',
#   'plants',
#   'to',
#   'make',
#   'changes',
#   'in',
#   'their',
#   'inspection',
#   'methods',
#   'ranging',
#   'from',
#   'veterinary',
#   'staffing',
#   'to',
#   'use',
#   'of',
#   'wood',
#   'last',
#   'december',
#   'the',
#   'ec',
#   'determined',
#   'that',
#   'only',
#   'one',
#   'u',
#   's',
#   'cattle',
#   'one',
#   'hog',
#   'and',
#   'one',
#   'sheep',
#   'slaughtering',
#   'facility',
#   'could',
#   'be',
#   'approved',
#   'without',
#   'further',
#   'review',
#   'usda',
#   'would',
#   'have',
#   'to',
#   'certify',
#   'that',
#   'the',
#   'plants',
#   'had',
#   'corrected',
#   'the',
#   'deficiencies',
#   'all',
#   'remaining',
#   'plants',
#   'with',
#   'a',
#   'history',
#   'or',
#   'potential',
#   'of',
#   'shipping',
#   'to',
#   'the',
#   'ec',
#   'totaling',
#   'nearly',
#   'would',
#   'require',
#   'more',
#   'significant',
#   'changes',
#   'in',
#   'plant',
#   'constructions',
#   'or',
#   'procedures',
#   'before',
#   'further',
#   'ec',
#   'review',
#   'robert',
#   'hibbert',
#   'general',
#   'counsel',
#   'for',
#   'the',
#   'american',
#   'meat',
#   'institute',
#   'said',
#   'the',
#   'meat',
#   'industry',
#   'expected',
#   'to',
#   'submit',
#   'a',
#   'formal',
#   'trade',
#   'retaliation',
#   'petition',
#   'by',
#   'april',
#   'an',
#   'interagency',
#   'committee',
#   'is',
#   'reviewing',
#   'the',
#   'industry',
#   's',
#   'draft',
#   'petition',
#   'an',
#   'official',
#   'at',
#   'the',
#   'u',
#   's',
#   'trade',
#   'representative',
#   's',
#   'office',
#   'said',
#   'u',
#   's',
#   'officials',
#   'continued',
#   'to',
#   'press',
#   'the',
#   'ec',
#   'to',
#   'withdraw',
#   'the',
#   'rule',
#   'but',
#   'that',
#   'the',
#   'chances',
#   'of',
#   'that',
#   'are',
#   'not',
#   'too',
#   'good',
#   'at',
#   'this',
#   'time',
#   'however',
#   'there',
#   'is',
#   'the',
#   'expectation',
#   'in',
#   'u',
#   's',
#   'government',
#   'and',
#   'meat',
#   'industry',
#   'circles',
#   'that',
#   'the',
#   'ec',
#   'will',
#   'continue',
#   'to',
#   'allow',
#   'shipments',
#   'at',
#   'least',
#   'through',
#   'the',
#   'end',
#   'of',
#   'the',
#   'calendar',
#   'year',
#   'from',
#   'u',
#   's',
#   'plants',
#   'that',
#   'submit',
#   'to',
#   'usda',
#   'a',
#   'plan',
#   'on',
#   'how',
#   'they',
#   'will',
#   'bring',
#   'their',
#   'operations',
#   'into',
#   'conformity',
#   'with',
#   'the',
#   'ec',
#   'regulation',
#   'the',
#   'ustr',
#   'official',
#   'said'],
#  ['japan',
#   'compound',
#   'feed',
#   'output',
#   'up',
#   'pct',
#   'japanese',
#   'compound',
#   'feed',
#   'output',
#   'rose',
#   'pct',
#   'to',
#   'mln',
#   'tonnes',
#   'in',
#   'ended',
#   'march',
#   'from',
#   'mln',
#   'a',
#   'year',
#   'earlier',
#   'the',
#   'agriculture',
#   'ministry',
#   'said',
#   'the',
#   'marginal',
#   'rise',
#   'reflected',
#   'slight',
#   'growth',
#   'in',
#   'demand',
#   'for',
#   'poultry',
#   'raising',
#   'and',
#   'a',
#   'moderate',
#   'increase',
#   'in',
#   'demand',
#   'for',
#   'beef',
#   'cattle',
#   'raising',
#   'ministry',
#   'officials',
#   'said',
#   'compound',
#   'feed',
#   'sales',
#   'totalled',
#   'mln',
#   'tonnes',
#   'in',
#   'against',
#   'mln',
#   'a',
#   'year',
#   'ago',
#   'while',
#   'end',
#   'march',
#   'stocks',
#   'were',
#   'tonnes',
#   'against',
#   'corn',
#   'use',
#   'in',
#   'feed',
#   'output',
#   'in',
#   'rose',
#   'to',
#   'mln',
#   'tonnes',
#   'from',
#   'mln',
#   'a',
#   'year',
#   'earlier',
#   'due',
#   'to',
#   'low',
#   'import',
#   'prices',
#   'the',
#   'officials',
#   'said',
#   'corn',
#   'imports',
#   'rose',
#   'because',
#   'the',
#   'world',
#   'surplus',
#   'and',
#   'the',
#   'yen',
#   's',
#   'strength',
#   'against',
#   'the',
#   'dollar',
#   'reduced',
#   'chicago',
#   'prices',
#   'the',
#   'corn',
#   'compounding',
#   'ratio',
#   'rose',
#   'to',
#   'pct',
#   'in',
#   'from',
#   'pct',
#   'a',
#   'year',
#   'earlier',
#   'sorghum',
#   'use',
#   'rose',
#   'marginally',
#   'to',
#   'mln',
#   'tonnes',
#   'in',
#   'from',
#   'mln',
#   'but',
#   'the',
#   'compounding',
#   'ratio',
#   'fell',
#   'to',
#   'pct',
#   'from',
#   'pct',
#   'because',
#   'of',
#   'greater',
#   'corn',
#   'use',
#   'higher',
#   'import',
#   'prices',
#   'due',
#   'to',
#   'poor',
#   'harvests',
#   'last',
#   'year',
#   'in',
#   'major',
#   'producing',
#   'nations',
#   'such',
#   'as',
#   'argentina',
#   'made',
#   'feed',
#   'makers',
#   'reluctant',
#   'to',
#   'use',
#   'sorghum',
#   'soybean',
#   'meal',
#   'use',
#   'fell',
#   'to',
#   'mln',
#   'tonnes',
#   'from',
#   'mln',
#   'and',
#   'the',
#   'compounding',
#   'ratio',
#   'declined',
#   'to',
#   'pct',
#   'from',
#   'pct',
#   'the',
#   'drop',
#   'in',
#   'soybean',
#   'meal',
#   'consumption',
#   'resulted',
#   'from',
#   'increased',
#   'use',
#   'of',
#   'cheaper',
#   'rapeseed',
#   'meal',
#   'the',
#   'officials',
#   'said',
#   'rapeseed',
#   'consumption',
#   'in',
#   'was',
#   'tonnes',
#   'against',
#   'a',
#   'year',
#   'earlier',
#   'the',
#   'compounding',
#   'ratio',
#   'rose',
#   'to',
#   'pct',
#   'from',
#   'pct'],
#  ['indonesia',
#   'turkey',
#   'eligible',
#   'for',
#   'cattle',
#   'under',
#   'eep',
#   'u',
#   's',
#   'exporters',
#   'will',
#   'be',
#   'able',
#   'to',
#   'sell',
#   'head',
#   'of',
#   'dairy',
#   'cattle',
#   'to',
#   'indonesia',
#   'and',
#   'head',
#   'to',
#   'turkey',
#   'under',
#   'the',
#   'export',
#   'enhancement',
#   'program',
#   'the',
#   'u',
#   's',
#   'agriculture',
#   'department',
#   'said',
#   'the',
#   'export',
#   'sales',
#   'will',
#   'be',
#   'subsidized',
#   'with',
#   'commodities',
#   'from',
#   'the',
#   'inventory',
#   'of',
#   'the',
#   'commodity',
#   'credit',
#   'corporation',
#   'ccc',
#   'the',
#   'department',
#   'said',
#   'indonesia',
#   'and',
#   'turkey',
#   'already',
#   'have',
#   'purchased',
#   'and',
#   'head',
#   'of',
#   'dairy',
#   'cattle',
#   'respectively',
#   'under',
#   'the',
#   'program',
#   'details',
#   'of',
#   'the',
#   'program',
#   'and',
#   'an',
#   'invitation',
#   'for',
#   'offers',
#   'from',
#   'exporters',
#   'will',
#   'be',
#   'issued',
#   'in',
#   'the',
#   'near',
#   'future',
#   'it',
#   'said'],
#  ['u',
#   's',
#   'refuses',
#   'parts',
#   'of',
#   'two',
#   'australia',
#   'beef',
#   'cargoes',
#   'u',
#   's',
#   'agriculture',
#   'department',
#   'inspectors',
#   'have',
#   'refused',
#   'entry',
#   'to',
#   'parts',
#   'of',
#   'two',
#   'lots',
#   'of',
#   'australian',
#   'beef',
#   'because',
#   'of',
#   'pesticide',
#   'residues',
#   'a',
#   'spokeswoman',
#   'for',
#   'the',
#   'department',
#   'said',
#   'she',
#   'said',
#   'usda',
#   'has',
#   'notified',
#   'australia',
#   'which',
#   'assured',
#   'it',
#   'that',
#   'stricter',
#   'controls',
#   'would',
#   'be',
#   'implemented',
#   'the',
#   'australian',
#   'government',
#   'had',
#   'already',
#   'imposed',
#   'residue',
#   'controls',
#   'and',
#   'it',
#   'is',
#   'believed',
#   'the',
#   'meat',
#   'with',
#   'the',
#   'presticide',
#   'residues',
#   'was',
#   'already',
#   'in',
#   'the',
#   'pipeline',
#   'before',
#   'the',
#   'controls',
#   'were',
#   'put',
#   'in',
#   'place',
#   'the',
#   'spokeswoman',
#   'said',
#   'there',
#   'have',
#   'been',
#   'five',
#   'other',
#   'cases',
#   'of',
#   'australian',
#   'meat',
#   'which',
#   'had',
#   'residue',
#   'levels',
#   'above',
#   'u',
#   's',
#   'allowable',
#   'limits',
#   'this',
#   'year',
#   'she',
#   'said'],
#  ['canada',
#   'threatens',
#   'ban',
#   'on',
#   'danish',
#   'pigmeat',
#   'imports',
#   'canada',
#   'has',
#   'threatened',
#   'to',
#   'stop',
#   'imports',
#   'of',
#   'danish',
#   'pigmeat',
#   'from',
#   'july',
#   'after',
#   'canadian',
#   'veterinary',
#   'inspectors',
#   'approved',
#   'only',
#   'two',
#   'of',
#   'slaughterhouses',
#   'a',
#   'danish',
#   'agriculture',
#   'ministry',
#   'official',
#   'told',
#   'reuters',
#   'the',
#   'canadians',
#   'postponed',
#   'the',
#   'original',
#   'july',
#   'deadline',
#   'at',
#   'the',
#   'request',
#   'of',
#   'the',
#   'european',
#   'commission',
#   'which',
#   'denmark',
#   'approached',
#   'for',
#   'support',
#   'danish',
#   'foreign',
#   'minister',
#   'uffe',
#   'ellemann',
#   'jensen',
#   'said',
#   'in',
#   'an',
#   'interview',
#   'with',
#   'the',
#   'daily',
#   'berlingske',
#   'tidende',
#   'denmark',
#   'will',
#   'not',
#   'accept',
#   'a',
#   'ban',
#   'on',
#   'danish',
#   'meat',
#   'exports',
#   'and',
#   'i',
#   'am',
#   'sure',
#   'we',
#   'can',
#   'reach',
#   'an',
#   'understanding',
#   'with',
#   'the',
#   'canadians',
#   'with',
#   'the',
#   'help',
#   'of',
#   'the',
#   'ec',
#   'danish',
#   'pigmeat',
#   'exports',
#   'to',
#   'canada',
#   'were',
#   'worth',
#   'mln',
#   'crowns',
#   'in',
#   'while',
#   'canadian',
#   'exports',
#   'to',
#   'the',
#   'european',
#   'community',
#   'totalled',
#   'about',
#   'billion',
#   'u',
#   's',
#   'dlrs',
#   'some',
#   'danish',
#   'slaughterhouse',
#   'officials',
#   'expressed',
#   'suspicion',
#   'that',
#   'the',
#   'canadian',
#   'action',
#   'was',
#   'in',
#   'response',
#   'to',
#   'tightening',
#   'up',
#   'by',
#   'ec',
#   'veterinary',
#   'inspectors',
#   'on',
#   'canadian',
#   'food',
#   'exports',
#   'to',
#   'the',
#   'ec',
#   'but',
#   'an',
#   'official',
#   'at',
#   'the',
#   'canadian',
#   'embassy',
#   'in',
#   'copenhagen',
#   'said',
#   'the',
#   'inspection',
#   'of',
#   'danish',
#   'slaughterhouses',
#   'was',
#   'based',
#   'on',
#   'ec',
#   'regulations',
#   'canadian',
#   'officials',
#   'are',
#   'very',
#   'concerned',
#   'about',
#   'the',
#   'trade',
#   'implications',
#   'we',
#   'are',
#   'holding',
#   'active',
#   'discussions',
#   'with',
#   'the',
#   'ec',
#   'and',
#   'bilaterally',
#   'she',
#   'added'],
#  ['u',
#   's',
#   'takes',
#   'tough',
#   'stand',
#   'on',
#   'gatt',
#   'farm',
#   'issues',
#   'the',
#   'united',
#   'states',
#   'is',
#   'prepared',
#   'to',
#   'pull',
#   'out',
#   'all',
#   'the',
#   'stops',
#   'to',
#   'defend',
#   'its',
#   'agricultural',
#   'trade',
#   'rights',
#   'under',
#   'the',
#   'general',
#   'agreement',
#   'on',
#   'tariffs',
#   'and',
#   'trade',
#   'gatt',
#   'u',
#   's',
#   'ambassador',
#   'to',
#   'gatt',
#   'michael',
#   'samuels',
#   'said',
#   'those',
#   'rights',
#   'are',
#   'now',
#   'being',
#   'challenged',
#   'by',
#   'the',
#   'european',
#   'community',
#   's',
#   'ec',
#   'agricultural',
#   'support',
#   'policies',
#   'he',
#   'told',
#   'a',
#   'conference',
#   'sponsored',
#   'by',
#   'the',
#   'american',
#   'soybean',
#   'association',
#   'he',
#   'reiterated',
#   'washington',
#   's',
#   'firm',
#   'intention',
#   'to',
#   'retaliate',
#   'if',
#   'the',
#   'ec',
#   'goes',
#   'ahead',
#   'and',
#   'bans',
#   'imports',
#   'of',
#   'hormone',
#   'fed',
#   'beef',
#   'without',
#   'the',
#   'issue',
#   'being',
#   'investigated',
#   'by',
#   'a',
#   'gatt',
#   'special',
#   'committee',
#   'the',
#   'u',
#   's',
#   'claims',
#   'the',
#   'ec',
#   'directive',
#   'due',
#   'to',
#   'come',
#   'into',
#   'effect',
#   'on',
#   'january',
#   'threatens',
#   'to',
#   'cut',
#   'mln',
#   'dlrs',
#   'worth',
#   'of',
#   'u',
#   's',
#   'meat',
#   'shipments',
#   'into',
#   'the',
#   'ec',
#   'the',
#   'u',
#   's',
#   'also',
#   'will',
#   'oppose',
#   'all',
#   'ec',
#   'efforts',
#   'to',
#   'impair',
#   'u',
#   's',
#   'trade',
#   'via',
#   'the',
#   'ec',
#   'oilseeds',
#   'regime',
#   'which',
#   'supports',
#   'ec',
#   'oilseed',
#   'prices',
#   'over',
#   'the',
#   'current',
#   'market',
#   'level',
#   'and',
#   'which',
#   'may',
#   'be',
#   'extended',
#   'to',
#   'include',
#   'a',
#   'hotly',
#   'disputed',
#   'oils',
#   'and',
#   'fats',
#   'tax',
#   'samuels',
#   'said',
#   'reduction',
#   'of',
#   'trade',
#   'distorting',
#   'world',
#   'agricultural',
#   'subsidies',
#   'an',
#   'aim',
#   'of',
#   'most',
#   'key',
#   'participants',
#   'in',
#   'gatt',
#   'multilateral',
#   'trade',
#   'negotiations',
#   'is',
#   'meaningless',
#   'if',
#   'import',
#   'barriers',
#   'continue',
#   'to',
#   'be',
#   'erected',
#   'samuels',
#   'said',
#   'samuels',
#   'called',
#   'the',
#   'u',
#   's',
#   'plan',
#   'to',
#   'eliminate',
#   'world',
#   'farm',
#   'subsidies',
#   'by',
#   'the',
#   'year',
#   'proposed',
#   'at',
#   'gatt',
#   'in',
#   'july',
#   'visionary',
#   'and',
#   'very',
#   'serious',
#   'the',
#   'ec',
#   'and',
#   'japan',
#   'have',
#   'said',
#   'it',
#   'is',
#   'unrealistic',
#   'the',
#   'ec',
#   'commission',
#   'this',
#   'month',
#   'announced',
#   'its',
#   'draft',
#   'proposal',
#   'on',
#   'farm',
#   'trade',
#   'reform',
#   'expected',
#   'to',
#   'be',
#   'tabled',
#   'at',
#   'gatt',
#   'formally',
#   'next',
#   'week',
#   'the',
#   'ec',
#   'scheme',
#   'involves',
#   'emergency',
#   'measures',
#   'to',
#   'reduce',
#   'tensions',
#   'in',
#   'troubled',
#   'surplus',
#   'sectors',
#   'of',
#   'cereals',
#   'and',
#   'cereals',
#   'substitutes',
#   'dairy',
#   'and',
#   'sugar',
#   'it',
#   'also',
#   'calls',
#   'for',
#   'reduction',
#   'of',
#   'farm',
#   'subsidies',
#   'the',
#   'u',
#   's',
#   'is',
#   'not',
#   'opposed',
#   'to',
#   'short',
#   'term',
#   'measures',
#   'as',
#   'long',
#   'as',
#   'they',
#   'are',
#   'directly',
#   'linked',
#   'to',
#   'long',
#   'term',
#   'commitments',
#   'to',
#   'end',
#   'major',
#   'trade',
#   'distortions',
#   'samuels',
#   'said',
#   'washington',
#   'will',
#   'review',
#   'the',
#   'ec',
#   'proposal',
#   'when',
#   'it',
#   'is',
#   'formally',
#   'submitted',
#   'and',
#   'respond',
#   'to',
#   'it',
#   'officially',
#   'then',
#   'we',
#   'will',
#   'consider',
#   'its',
#   'relation',
#   'to',
#   'the',
#   'punta',
#   'del',
#   'este',
#   'declaration',
#   'to',
#   'correct',
#   'trade',
#   'problems',
#   'and',
#   'expand',
#   'market',
#   'access',
#   'the',
#   'u',
#   's',
#   'ambassador',
#   'said',
#   'the',
#   'u',
#   's',
#   'can',
#   'say',
#   'no',
#   'to',
#   'the',
#   'ec',
#   'proposal',
#   'if',
#   'the',
#   'ec',
#   'ignores',
#   'the',
#   'u',
#   's',
#   'plan',
#   'when',
#   'it',
#   'tables',
#   'its',
#   'own',
#   'proposal',
#   'he',
#   'added',
#   'the',
#   'key',
#   'difference',
#   'between',
#   'the',
#   'two',
#   'approaches',
#   'is',
#   'that',
#   'the',
#   'u',
#   's',
#   'wants',
#   'farm',
#   'subsidies',
#   'eliminated',
#   'while',
#   'the',
#   'ec',
#   'is',
#   'pushing',
#   'only',
#   'for',
#   'a',
#   'reduction',
#   'in',
#   'farm',
#   'suppports',
#   'samuels',
#   'said',
#   'if',
#   'the',
#   'ec',
#   'farm',
#   'budget',
#   'were',
#   'protected',
#   'by',
#   'a',
#   'subsidy',
#   'freeze',
#   'there',
#   'would',
#   'be',
#   'little',
#   'incentive',
#   'for',
#   'the',
#   'community',
#   'to',
#   'work',
#   'to',
#   'correct',
#   'the',
#   'international',
#   'trade',
#   'situation',
#   'he',
#   'added',
#   'samuels',
#   'cited',
#   'the',
#   'animal',
#   'hormones',
#   'complaint',
#   'the',
#   'ec',
#   'oilseeds',
#   'regime',
#   'and',
#   'an',
#   'ec',
#   'regulation',
#   'concerning',
#   'meat',
#   'imports',
#   'to',
#   'third',
#   'countries',
#   'as',
#   'three',
#   'crucial',
#   'barriers',
#   'to',
#   'trade',
#   'which',
#   'the',
#   'u',
#   's',
#   'wants',
#   'to',
#   'see',
#   'resolved',
#   'under',
#   'the',
#   'auspices',
#   'of',
#   'gatt'],
#  ['ec',
#   'agrees',
#   'trade',
#   'deal',
#   'with',
#   'argentina',
#   'the',
#   'european',
#   'community',
#   'ec',
#   'agreed',
#   'a',
#   'trade',
#   'deal',
#   'with',
#   'argentina',
#   'designed',
#   'to',
#   'compensate',
#   'the',
#   'country',
#   'following',
#   'the',
#   'entry',
#   'of',
#   'spain',
#   'and',
#   'portugal',
#   'into',
#   'the',
#   'group',
#   'ec',
#   'officials',
#   'said',
#   'under',
#   'the',
#   'deal',
#   'agreed',
#   'by',
#   'ec',
#   'foreign',
#   'ministers',
#   'argentina',
#   'will',
#   'gain',
#   'additional',
#   'trading',
#   'rights',
#   'on',
#   'a',
#   'series',
#   'of',
#   'products',
#   'including',
#   'meat',
#   'fish',
#   'and',
#   'cereals',
#   'by',
#   'products',
#   'but',
#   'ministers',
#   'failed',
#   'to',
#   'agree',
#   'on',
#   'new',
#   'trade',
#   'deals',
#   'with',
#   'canada',
#   'and',
#   'japan',
#   'and',
#   'are',
#   'due',
#   'to',
#   'study',
#   'these',
#   'again',
#   'the',
#   'officials',
#   'said',
#   'the',
#   'deal',
#   'with',
#   'argentina',
#   'was',
#   'agreed',
#   'by',
#   'a',
#   'majority',
#   'of',
#   'ec',
#   'states',
#   'after',
#   'west',
#   'germany',
#   'withdrew',
#   'objections',
#   'to',
#   'increased',
#   'quotas',
#   'for',
#   'argentina',
#   'on',
#   'high',
#   'quality',
#   'beef',
#   'ireland',
#   'and',
#   'france',
#   'continued',
#   'to',
#   'oppose',
#   'the',
#   'deal',
#   'on',
#   'meat',
#   'saying',
#   'that',
#   'the',
#   'main',
#   'dispute',
#   'was',
#   'over',
#   'sales',
#   'of',
#   'cereals',
#   'substitutes',
#   'but',
#   'they',
#   'were',
#   'outvoted',
#   'by',
#   'the',
#   'other',
#   'states',
#   'the',
#   'officials',
#   'said',
#   'under',
#   'the',
#   'deal',
#   'argentina',
#   'will',
#   'benefit',
#   'from',
#   'improved',
#   'quotas',
#   'on',
#   'exports',
#   'of',
#   'beef',
#   'to',
#   'the',
#   'ec',
#   'in',
#   'particular',
#   'the',
#   'quota',
#   'on',
#   'high',
#   'quality',
#   'hilton',
#   'beef',
#   'will',
#   'be',
#   'raised',
#   'by',
#   'tonnes',
#   'to',
#   'tonnes',
#   'and',
#   'quotas',
#   'on',
#   'frozen',
#   'boneless',
#   'beef',
#   'will',
#   'be',
#   'increased',
#   'by',
#   'tonnes',
#   'to',
#   'tonnes',
#   'argentina',
#   'will',
#   'also',
#   'benefit',
#   'from',
#   'an',
#   'additional',
#   'quota',
#   'of',
#   'tonnes',
#   'of',
#   'frozen',
#   'hake',
#   'fillets',
#   'at',
#   'pct',
#   'duty',
#   'and',
#   'reduced',
#   'levies',
#   'on',
#   'tonnes',
#   'of',
#   'wheat',
#   'bran',
#   'the',
#   'officials',
#   'said',
#   'the',
#   'improved',
#   'trade',
#   'terms',
#   'were',
#   'offered',
#   'after',
#   'argentina',
#   'said',
#   'that',
#   'spain',
#   'and',
#   'portugal',
#   's',
#   'entry',
#   'into',
#   'the',
#   'ec',
#   'affected',
#   'their',
#   'exports',
#   'of',
#   'cereals',
#   'substitutes',
#   'to',
#   'these',
#   'two',
#   'countries',
#   'they',
#   'have',
#   'been',
#   'negotiated',
#   'under',
#   'the',
#   'rules',
#   'of',
#   'gatt',
#   'general',
#   'agreement',
#   'on',
#   'tariffs',
#   'and',
#   'trade',
#   'but',
#   'officials',
#   'said',
#   'ministers',
#   'had',
#   'been',
#   'unable',
#   'to',
#   'resolve',
#   'canadian',
#   'claims',
#   'that',
#   'its',
#   'sales',
#   'of',
#   'certain',
#   'fish',
#   'to',
#   'spain',
#   'had',
#   'been',
#   'affected',
#   'by',
#   'the',
#   'country',
#   's',
#   'ec',
#   'membership',
#   'officials',
#   'said',
#   'the',
#   'ec',
#   'had',
#   'asked',
#   'gatt',
#   'to',
#   'arbitrate',
#   'on',
#   'the',
#   'fish',
#   'dispute',
#   'with',
#   'canada',
#   'ministers',
#   'also',
#   'decided',
#   'to',
#   'continue',
#   'talks',
#   'with',
#   'japan',
#   'the',
#   'ec',
#   'claims',
#   'that',
#   'spain',
#   'and',
#   'portugal',
#   's',
#   'entry',
#   'into',
#   'the',
#   'group',
#   'has',
#   'improved',
#   'trade',
#   'conditions',
#   'for',
#   'japan',
#   'but',
#   'has',
#   'been',
#   'unsatisfied',
#   'with',
#   'japanese',
#   'offers',
#   'of',
#   'compensation',
#   'japan',
#   's',
#   'main',
#   'offers',
#   'were',
#   'to',
#   'improve',
#   'inspection',
#   'systems',
#   'on',
#   'citrus',
# ...
#   'of',
#   'kansas',
#   'a',
#   'flood',
#   'warning',
#   'continues',
#   'today',
#   'for',
#   'eastern',
#   'nebraska',
#   'widespread',
#   'lowland',
#   'and',
#   'small',
#   'stream',
#   'flooding',
#   'is',
#   'expected',
#   'to',
#   'continue',
#   'over',
#   'most',
#   'of',
#   'eastern',
#   'nebraska',
#   'through',
#   'wednesday',
#   'due',
#   'to',
#   'cold',
#   'damp',
#   'and',
#   'windy',
#   'conditions',
#   'livestock',
#   'advisories',
#   'were',
#   'posted',
#   'this',
#   'morning',
#   'across',
#   'central',
#   'and',
#   'southeast',
#   'portions',
#   'of',
#   'south',
#   'dakota',
#   'as',
#   'the',
#   'storm',
#   'moves',
#   'north',
#   'across',
#   'the',
#   'central',
#   'plains',
#   'winter',
#   'storm',
#   'watches',
#   'were',
#   'issued',
#   'over',
#   'south',
#   'central',
#   'south',
#   'dakota',
#   'late',
#   'tonight',
#   'and',
#   'wednesday',
#   'over',
#   'west',
#   'central',
#   'minnesota',
#   'elsewhere',
#   'a',
#   'travelers',
#   'advisory',
#   'remains',
#   'in',
#   'effect',
#   'this',
#   'morning',
#   'over',
#   'northeast',
#   'new',
#   'mexico',
#   'and',
#   'the',
#   'oklahoma',
#   'and',
#   'tecas',
#   'panhandle',
#   'for',
#   'blowing',
#   'snow',
#   'and',
#   'slick',
#   'roadways',
#   'and',
#   'across',
#   'the',
#   'mountains',
#   'and',
#   'deserts',
#   'of',
#   'southern',
#   'california',
#   'for',
#   'strong',
#   'gusty',
#   'winds',
#   'of',
#   'to',
#   'mph',
#   'gale',
#   'warnings',
#   'were',
#   'issued',
#   'for',
#   'today',
#   'along',
#   'the',
#   'central',
#   'california',
#   'coast',
#   'mostly',
#   'clear',
#   'skies',
#   'extended',
#   'from',
#   'the',
#   'great',
#   'lakes',
#   'and',
#   'ohio',
#   'valley',
#   'through',
#   'the',
#   'central',
#   'appalachians',
#   'to',
#   'the',
#   'central',
#   'atlantic',
#   'coast',
#   'and',
#   'new',
#   'england'],
#  ['honduras',
#   'seeks',
#   'vessels',
#   'for',
#   'tallow',
#   'delivery',
#   'honduras',
#   'will',
#   'tender',
#   'march',
#   'under',
#   'for',
#   'u',
#   's',
#   'and',
#   'non',
#   'u',
#   's',
#   'flag',
#   'vessels',
#   'to',
#   'import',
#   'tonnes',
#   'of',
#   'tallow',
#   'in',
#   'bulk',
#   'an',
#   'agent',
#   'for',
#   'the',
#   'country',
#   'said',
#   'the',
#   'agent',
#   'said',
#   'delivery',
#   'includes',
#   'laydays',
#   'of',
#   'april',
#   'offers',
#   'are',
#   'due',
#   'by',
#   'hrs',
#   'est',
#   'march',
#   'and',
#   'will',
#   'remain',
#   'valid',
#   'until',
#   'the',
#   'close',
#   'of',
#   'business',
#   'the',
#   'following',
#   'day',
#   'the',
#   'agent',
#   'said'],
#  ['ec',
#   'cold',
#   'aid',
#   'food',
#   'scheme',
#   'may',
#   'be',
#   'made',
#   'permanent',
#   'emergency',
#   'action',
#   'to',
#   'distribute',
#   'european',
#   'community',
#   'ec',
#   'food',
#   'surpluses',
#   'to',
#   'the',
#   'poor',
#   'has',
#   'proved',
#   'so',
#   'successful',
#   'that',
#   'the',
#   'ec',
#   'executive',
#   'commission',
#   'may',
#   'propose',
#   'a',
#   'permanent',
#   'scheme',
#   'a',
#   'commission',
#   'spokesman',
#   'said',
#   'almost',
#   'tonnes',
#   'of',
#   'food',
#   'was',
#   'taken',
#   'out',
#   'of',
#   'ec',
#   'stores',
#   'between',
#   'january',
#   'when',
#   'agriculture',
#   'ministers',
#   'approved',
#   'the',
#   'scheme',
#   'and',
#   'march',
#   'according',
#   'to',
#   'latest',
#   'commission',
#   'figures',
#   'the',
#   'food',
#   'including',
#   'tonnes',
#   'of',
#   'cereals',
#   'tonnes',
#   'of',
#   'sugar',
#   'tonnes',
#   'of',
#   'beef',
#   'and',
#   'tonnes',
#   'of',
#   'butter',
#   'has',
#   'been',
#   'distributed',
#   'to',
#   'the',
#   'needy',
#   'through',
#   'charities',
#   'the',
#   'present',
#   'scheme',
#   'was',
#   'approved',
#   'as',
#   'an',
#   'emergency',
#   'measure',
#   'to',
#   'help',
#   'poor',
#   'people',
#   'affected',
#   'by',
#   'this',
#   'year',
#   's',
#   'unusually',
#   'cold',
#   'winter',
#   'and',
#   'will',
#   'end',
#   'on',
#   'march',
#   'but',
#   'the',
#   'spokesman',
#   'said',
#   'the',
#   'commission',
#   'will',
#   'consider',
#   'whether',
#   'to',
#   'propose',
#   'it',
#   'be',
#   'replaced',
#   'by',
#   'an',
#   'all',
#   'year',
#   'round',
#   'system',
#   'the',
#   'commission',
#   'estimates',
#   'that',
#   'up',
#   'to',
#   'march',
#   'the',
#   'temporary',
#   'scheme',
#   'cost',
#   'between',
#   'and',
#   'mln',
#   'european',
#   'currency',
#   'units',
#   'mln',
#   'dlrs',
#   'this',
#   'is',
#   'above',
#   'the',
#   'mln',
#   'ecu',
#   'mln',
#   'dlr',
#   'ceiling',
#   'originally',
#   'envisaged',
#   'by',
#   'the',
#   'ministers',
#   'however',
#   'commission',
#   'sources',
#   'said',
#   'the',
#   'real',
#   'cost',
#   'was',
#   'small',
#   'if',
#   'account',
#   'is',
#   'taken',
#   'of',
#   'the',
#   'expense',
#   'of',
#   'keeping',
#   'food',
#   'in',
#   'store',
#   'until',
#   'its',
#   'quality',
#   'and',
#   'value',
#   'deteriorates',
#   'on',
#   'the',
#   'other',
#   'hand',
#   'the',
#   'impact',
#   'of',
#   'the',
#   'temporary',
#   'scheme',
#   'on',
#   'ec',
#   'food',
#   'surpluses',
#   'has',
#   'been',
#   'slight',
#   'ec',
#   'surplus',
#   'food',
#   'stocks',
#   'at',
#   'january',
#   'included',
#   'mln',
#   'tonnes',
#   'of',
#   'butter',
#   'tonnes',
#   'of',
#   'beef',
#   'and',
#   'over',
#   'mln',
#   'tonnes',
#   'of',
#   'cereals'],
#  ['u',
#   's',
#   'senators',
#   'seek',
#   'to',
#   'expand',
#   'usda',
#   'export',
#   'bonus',
#   'leading',
#   'u',
#   's',
#   'farm',
#   'state',
#   'senators',
#   'are',
#   'seeking',
#   'to',
#   'insert',
#   'into',
#   'the',
#   'senate',
#   's',
#   'omnibus',
#   'trade',
#   'bill',
#   'a',
#   'provision',
#   'that',
#   'would',
#   'broaden',
#   'eligibility',
#   'requirements',
#   'under',
#   'the',
#   'u',
#   's',
#   'agriculture',
#   'department',
#   's',
#   'export',
#   'enhancement',
#   'program',
#   'eep',
#   'to',
#   'include',
#   'traditional',
#   'buyers',
#   'of',
#   'u',
#   's',
#   'farm',
#   'products',
#   'including',
#   'the',
#   'soviet',
#   'union',
#   'senate',
#   'staff',
#   'said',
#   'under',
#   'existing',
#   'criteria',
#   'usda',
#   'can',
#   'offer',
#   'eep',
#   'subsidies',
#   'to',
#   'recoup',
#   'export',
#   'markets',
#   'lost',
#   'to',
#   'competing',
#   'nations',
#   'unfair',
#   'trading',
#   'practices',
#   'senate',
#   'agriculture',
#   'committee',
#   'chairman',
#   'patrick',
#   'leahy',
#   'd',
#   'vt',
#   'is',
#   'leading',
#   'a',
#   'group',
#   'of',
#   'farm',
#   'state',
#   'senators',
#   'in',
#   'an',
#   'effort',
#   'to',
#   'broaden',
#   'the',
#   'criteria',
#   'in',
#   'such',
#   'a',
#   'way',
#   'as',
#   'to',
#   'enable',
#   'moscow',
#   'to',
#   'be',
#   'eligible',
#   'for',
#   'the',
#   'subsidies',
#   'sources',
#   'said',
#   'the',
#   'senators',
#   'including',
#   'senate',
#   'finance',
#   'committee',
#   'chairman',
#   'lloyd',
#   'bentsen',
#   'd',
#   'tex',
#   'max',
#   'baucus',
#   'd',
#   'mont',
#   'david',
#   'pryor',
#   'd',
#   'ark',
#   'john',
#   'melcher',
#   'd',
#   'mont',
#   'and',
#   'thad',
#   'cochran',
#   'r',
#   'miss',
#   'also',
#   'may',
#   'fold',
#   'into',
#   'the',
#   'trade',
#   'bill',
#   'a',
#   'measure',
#   'to',
#   'shield',
#   'pork',
#   'producers',
#   'and',
#   'processors',
#   'from',
#   'canadian',
#   'imports',
#   'the',
#   'measure',
#   'sponsored',
#   'by',
#   'sen',
#   'charles',
#   'grassley',
#   'r',
#   'iowa',
#   'would',
#   'clarify',
#   'the',
#   'definition',
#   'of',
#   'industry',
#   'in',
#   'determining',
#   'whether',
#   'or',
#   'not',
#   'imports',
#   'were',
#   'causing',
#   'injury',
#   'to',
#   'u',
#   's',
#   'producers',
#   'grassley',
#   's',
#   'bill',
#   'stems',
#   'from',
#   'a',
#   'decision',
#   'by',
#   'the',
#   'international',
#   'trade',
#   'commission',
#   'that',
#   'imports',
#   'from',
#   'canada',
#   'of',
#   'live',
#   'swine',
#   'but',
#   'not',
#   'fresh',
#   'chilled',
#   'and',
#   'frozen',
#   'pork',
#   'were',
#   'harming',
#   'u',
#   's',
#   'producers',
#   'the',
#   'bill',
#   's',
#   'proponents',
#   'have',
#   'argued',
#   'canada',
#   'has',
#   'simply',
#   'replaced',
#   'shipments',
#   'of',
#   'live',
#   'hogs',
#   'with',
#   'fresh',
#   'pork'],
#  ['ccc',
#   'accepts',
#   'bonus',
#   'bid',
#   'on',
#   'cattle',
#   'for',
#   'egypt',
#   'usda',
#   'the',
#   'commodity',
#   'credit',
#   'corporation',
#   'has',
#   'accepted',
#   'a',
#   'bid',
#   'for',
#   'an',
#   'export',
#   'bonus',
#   'to',
#   'cover',
#   'the',
#   'sale',
#   'of',
#   'head',
#   'of',
#   'dairy',
#   'cattle',
#   'to',
#   'egypt',
#   'the',
#   'u',
#   's',
#   'agriculture',
#   'department',
#   'said',
#   'the',
#   'delivery',
#   'period',
#   'for',
#   'the',
#   'cattle',
#   'is',
#   'april',
#   'june',
#   'it',
#   'said',
#   'the',
#   'bonus',
#   'of',
#   'dlrs',
#   'per',
#   'head',
#   'was',
#   'made',
#   'to',
#   'esmah',
#   'nevada',
#   'inc',
#   'and',
#   'will',
#   'be',
#   'paid',
#   'in',
#   'the',
#   'form',
#   'of',
#   'commodities',
#   'from',
#   'the',
#   'ccc',
#   'inventory',
#   'an',
#   'additional',
#   'head',
#   'of',
#   'dairy',
#   'cattle',
#   'are',
#   'still',
#   'available',
#   'to',
#   'egypt',
#   'under',
#   'the',
#   'export',
#   'enhancement',
#   'program',
#   'initiative',
#   'announced',
#   'september',
#   'the',
#   'department',
#   'said'],
#  ['int',
#   'l',
#   'minerals',
#   'project',
#   'to',
#   'boost',
#   'hog',
#   'lean',
#   'weight',
#   'international',
#   'minerals',
#   'and',
#   'chemical',
#   'corp',
#   'said',
#   'its',
#   'board',
#   'approved',
#   'a',
#   'mln',
#   'dlrs',
#   'budget',
#   'over',
#   'the',
#   'next',
#   'several',
#   'years',
#   'to',
#   'build',
#   'production',
#   'facilities',
#   'for',
#   'a',
#   'newly',
#   'developed',
#   'product',
#   'to',
#   'be',
#   'used',
#   'to',
#   'improve',
#   'the',
#   'lean',
#   'weight',
#   'of',
#   'hogs',
#   'the',
#   'new',
#   'product',
#   'porcine',
#   'somatotropin',
#   'pst',
#   'is',
#   'described',
#   'as',
#   'a',
#   'natural',
#   'bio',
#   'synthetic',
#   'protein',
#   'that',
#   'improves',
#   'the',
#   'lean',
#   'weight',
#   'and',
#   'rate',
#   'of',
#   'weight',
#   'gain',
#   'as',
#   'well',
#   'as',
#   'reduces',
#   'the',
#   'cost',
#   'of',
#   'feed',
#   'for',
#   'market',
#   'hogs',
#   'the',
#   'company',
#   'said',
#   'specific',
#   'details',
#   'of',
#   'the',
#   'pst',
#   'production',
#   'project',
#   'including',
#   'sites',
#   'for',
#   'proposed',
#   'facilities',
#   'and',
#   'engineering',
#   'plans',
#   'were',
#   'not',
#   'disclosed',
#   'international',
#   'minerals',
#   'said',
#   'it',
#   'set',
#   'a',
#   'completion',
#   'target',
#   'for',
#   'the',
#   'spring',
#   'of',
#   'by',
#   'which',
#   'time',
#   'necessary',
#   'food',
#   'and',
#   'drug',
#   'administration',
#   'approvals',
#   'are',
#   'expected',
#   'to',
#   'be',
#   'obtained'],
#  ['japan',
#   'beef',
#   'price',
#   'support',
#   'cut',
#   'will',
#   'not',
#   'raise',
#   'demand',
#   'japan',
#   's',
#   'plan',
#   'to',
#   'cut',
#   'beef',
#   'intervention',
#   'prices',
#   'for',
#   'the',
#   'fiscal',
#   'year',
#   'starting',
#   'april',
#   'will',
#   'not',
#   'boost',
#   'demand',
#   'because',
#   'of',
#   'strict',
#   'supply',
#   'controls',
#   'and',
#   'a',
#   'complex',
#   'distribution',
#   'system',
#   'japanese',
#   'and',
#   'u',
#   's',
#   'industry',
#   'sources',
#   'said',
#   'government',
#   'beef',
#   'policy',
#   'protects',
#   'farmers',
#   'rather',
#   'than',
#   'meeting',
#   'consumers',
#   'demands',
#   'and',
#   'the',
#   'cutback',
#   'is',
#   'too',
#   'marginal',
#   'a',
#   'housewives',
#   'association',
#   'of',
#   'japan',
#   'official',
#   'said',
#   'despite',
#   'mounting',
#   'u',
#   's',
#   'pressure',
#   'on',
#   'japan',
#   'to',
#   'open',
#   'farm',
#   'markets',
#   'beef',
#   'is',
#   'strictly',
#   'controlled',
#   'by',
#   'the',
#   'government',
#   'which',
#   'maintains',
#   'a',
#   'price',
#   'stabilisation',
#   'zone',
#   'to',
#   'protect',
#   'farmers',
#   'under',
#   'the',
#   'plan',
#   'expected',
#   'to',
#   'be',
#   'announced',
#   'this',
#   'month',
#   'the',
#   'standard',
#   'or',
#   'bottom',
#   'price',
#   'of',
#   'castrated',
#   'wagyu',
#   'known',
#   'as',
#   'marbled',
#   'beef',
#   'will',
#   'be',
#   'set',
#   'at',
#   'yen',
#   'per',
#   'kilo',
#   'for',
#   'against',
#   'now',
#   'and',
#   'the',
#   'ceiling',
#   'at',
#   'yen',
#   'against',
#   'the',
#   'standard',
#   'price',
#   'of',
#   'other',
#   'beef',
#   'mainly',
#   'produced',
#   'from',
#   'dairy',
#   'steers',
#   'is',
#   'set',
#   'at',
#   'yen',
#   'against',
#   'and',
#   'the',
#   'ceiling',
#   'at',
#   'against',
#   'ministry',
#   'officials',
#   'said',
#   'the',
#   'semi',
#   'government',
#   'livestock',
#   'industry',
#   'promotion',
#   'corp',
#   'lipc',
#   'conducts',
#   'buffer',
#   'stock',
#   'operations',
#   'to',
#   'help',
#   'keep',
#   'wholesale',
#   'beef',
#   'prices',
#   'within',
#   'the',
#   'intervention',
#   'price',
#   'zone',
#   'the',
#   'lipc',
#   'is',
#   'allowed',
#   'to',
#   'import',
#   'most',
#   'beef',
#   'with',
#   'the',
#   'amount',
#   'set',
#   'by',
#   'the',
#   'government',
#   'under',
#   'a',
#   'quota',
#   'system',
#   'when',
#   'wholesale',
#   'prices',
#   'go',
#   'above',
#   'the',
#   'ceiling',
#   'the',
#   'lipc',
#   'releases',
#   'its',
#   'beef',
#   'stocks',
#   'both',
#   'domestic',
#   'and',
#   'imported',
#   'and',
#   'buys',
#   'locally',
#   'produced',
#   'beef',
#   'when',
#   'prices',
#   'are',
#   'below',
#   'but',
#   'the',
#   'lipc',
#   'has',
#   'often',
#   'been',
#   'criticised',
#   'for',
#   'releasing',
#   'beef',
#   'stocks',
#   'when',
#   'the',
#   'prices',
#   'are',
#   'higher',
#   'than',
#   'the',
#   'ceiling',
#   'phillip',
#   'seng',
#   'asian',
#   'director',
#   'of',
#   'the',
#   'u',
#   's',
#   'meat',
#   'export',
#   'federation',
#   'told',
#   'reuters',
#   'the',
#   'two',
#   'pct',
#   'cut',
#   'in',
#   'prices',
#   'is',
#   'a',
#   'step',
#   'toward',
#   'closing',
#   'the',
#   'gap',
#   'with',
#   'european',
#   'community',
#   'prices',
#   'about',
#   'half',
#   'those',
#   'in',
#   'japan',
#   'but',
#   'seng',
#   'said',
#   'the',
#   'cut',
#   'will',
#   'not',
#   'benefit',
#   'consumers',
#   'or',
#   'u',
#   's',
#   'meat',
#   'exporters',
#   'because',
#   'of',
#   'japan',
#   's',
#   'rigid',
#   'and',
#   'complicated',
#   'distribution',
#   'system',
#   'and',
#   'strict',
#   'supply',
#   'control',
#   'by',
#   'the',
#   'lipc',
#   'the',
#   'housewives',
#   'association',
#   'official',
#   'said',
#   'retail',
#   'beef',
#   'prices',
#   'are',
#   'high',
#   'mainly',
#   'because',
#   'of',
#   'distribution',
#   'problems',
#   'and',
#   'high',
#   'production',
#   'costs',
#   'as',
#   'well',
#   'as',
#   'poor',
#   'operations',
#   'by',
#   'the',
#   'lipc',
#   'american',
#   'meat',
#   'packers',
#   'see',
#   'japan',
#   'as',
#   'a',
#   'promising',
#   'market',
#   'f',
#   'c',
#   'beatty',
#   'of',
#   'u',
#   's',
#   'packer',
#   'john',
#   'morrell',
#   'and',
#   'co',
#   'told',
#   'the',
#   'japan',
#   'times',
#   'beef',
#   'cuts',
#   'which',
#   'sell',
#   'for',
#   'to',
#   'dlrs',
#   'a',
#   'pound',
#   'in',
#   'the',
#   'u',
#   's',
#   'are',
#   'sold',
#   'at',
#   'to',
#   'dlrs',
#   'in',
#   'japan',
#   'but',
#   'seng',
#   'said',
#   'the',
#   'cut',
#   'will',
#   'not',
#   'benefit',
#   'consumers',
#   'or',
#   'u',
#   's',
#   'meat',
#   'exporters',
#   'because',
#   'of',
#   'japan',
#   's',
#   'rigid',
#   'and',
#   'complicated',
#   'distribution',
#   'system',
#   'and',
#   'strict',
#   'supply',
#   'control',
#   'by',
#   'the',
#   'lipc',
#   'the',
#   'housewives',
#   'association',
#   'official',
#   'said',
#   'retail',
#   'beef',
#   'prices',
#   'are',
#   'high',
#   'mainly',
#   'because',
#   'of',
#   'distribution',
#   'problems',
#   'and',
#   'high',
#   'production',
#   'costs',
#   'as',
#   'well',
#   'as',
#   'poor',
#   'operations',
#   'by',
#   'the',
#   'lipc',
#   'american',
#   'meat',
#   'packers',
#   'see',
#   'japan',
#   'as',
#   'a',
#   'promising',
#   'market',
#   'f',
#   'c',
#   'beatty',
#   'of',
#   'u',
#   's',
#   'packer',
#   'john',
#   'morrell',
#   'and',
#   'co',
#   'told',
#   'the',
#   'japan',
#   'times',
#   'beef',
#   'cuts',
#   'which',
#   'sell',
#   'for',
#   'to',
#   'dlrs',
#   'a',
#   'pound',
#   'in',
#   'the',
#   'u',
#   's',
#   'are',
#   'sold',
#   'at',
#   'to',
#   'dlrs',
#   'in',
#   'japan',
#   'but',
#   'industry',
#   'sources',
#   'said',
#   'it',
#   'is',
#   'unclear',
#   'how',
#   'much',
#   'demand',
#   'will',
#   'pick',
#   'up',
#   'if',
#   'retail',
#   'beef',
#   'prices',
#   'drop',
#   'following',
#   'any',
#   'sharp',
#   'reduction',
#   'in',
#   'intervention',
#   'prices',
#   'u',
#   's',
#   'agriculture',
#   'secretary',
#   'richard',
#   'lyng',
#   'said',
#   'this',
#   'week',
#   'he',
#   'will',
#   'ask',
#   'japan',
#   'to',
#   'remove',
#   'all',
#   'beef',
#   'import',
#   'restrictions',
#   'when',
#   'he',
#   'visits',
#   'here',
#   'next',
#   'month',
#   'in',
#   'japan',
#   'decided',
#   'to',
#   'increase',
#   'its',
#   'beef',
#   'import',
#   'quota',
#   'by',
#   'tonnes',
#   'a',
#   'year',
#   'until',
#   'march',
#   'in',
#   'the',
#   'quota',
#   'will',
#   'rise',
#   'to',
#   'tonnes',
#   'from',
#   'in',
#   'ministry',
#   'officials',
#   'said',
#   'adding',
#   'japan',
#   'wants',
#   'to',
#   'keep',
#   'self',
#   'sufficiency',
#   'in',
#   'beef',
#   'at',
#   'around',
#   'pct']]

# %% [markdown]
# ## 2. Vocabulary Creation

# %%
# Flatten the corpus into a single list of words
flatten_corpus = [word for doc in corpus for word in doc]
# Create a set of unique words in the corpus
vocabs = list(set(flatten_corpus))
vocabs
# Out:
# ['lower',
#  'try',
#  'package',
#  'compound',
#  'agreements',
#  'favoured',
#  'be',
#  'difference',
#  'feeder',
#  'deteriorates',
#  'guillaume',
#  'voice',
#  'calm',
#  'participants',
#  'too',
#  'conjunction',
#  'shipping',
#  'after',
#  'rice',
#  'size',
#  'vt',
#  'exchange',
#  'tobacco',
#  'stems',
#  'feed',
#  'points',
#  'buyers',
#  'illegal',
#  'proportion',
#  'appropriate',
#  'and',
#  'credit',
#  'am',
#  'thought',
#  'congressman',
#  'md',
#  'administrative',
#  'three',
#  'continues',
#  'has',
#  'began',
#  'long',
#  'group',
#  'one',
#  'concessions',
#  'big',
#  'houses',
#  'elected',
#  'compared',
#  'instead',
#  'crops',
#  'catholic',
#  'auctioned',
#  'programs',
#  'kicks',
#  'ham',
#  'normally',
#  'baltic',
#  'distributive',
#  'causing',
#  'approval',
#  'asked',
#  'ruled',
#  'lead',
#  'spark',
#  'distortion',
#  'offset',
#  'season',
#  'have',
#  'bring',
#  'lines',
#  'underpinned',
#  'imported',
#  'cold',
#  'rebuilding',
#  'soviet',
#  'reasonable',
#  'actually',
#  'reform',
#  'licensing',
#  'conditioning',
#  'average',
#  'setting',
#  'disease',
#  'severe',
#  'turnover',
#  'little',
#  'cutbacks',
#  'lift',
#  'pressured',
#  'sector',
#  'ecus',
#  'significant',
#  'negative',
#  'newspaper',
#  'conducting',
#  'sponsored',
#  'tenderloins',
#  'thanks',
#  'expectations',
#  'senior',
#  'account',
#  'work',
#  'tax',
#  'jamaican',
#  'factors',
#  'barakat',
#  'organise',
#  'wine',
#  'around',
#  'conference',
#  'intervention',
#  'labelling',
#  'membership',
#  'erecting',
#  'takes',
#  'unrealistic',
#  'tabled',
#  'income',
#  'part',
#  'burdensome',
#  'effect',
#  'warehouse',
#  'examined',
#  'safely',
#  'markets',
#  'thursday',
#  'bulk',
#  'countercyclical',
#  'fear',
#  'needs',
#  'implement',
#  'sites',
#  'merged',
#  'want',
#  'it',
#  'effectiveness',
#  'brokerage',
#  'lost',
#  'medicines',
#  'infection',
#  'including',
#  'range',
#  'urging',
#  'grimes',
#  'member',
#  'east',
#  'loss',
#  'criticised',
#  'funded',
#  'special',
#  'use',
#  'tables',
#  'improve',
#  'news',
#  'end',
#  'recommend',
#  'deadly',
#  'declining',
#  'mediterranean',
#  'cutback',
#  'releasing',
#  'backfat',
#  'brazil',
#  'under',
#  'made',
#  'ports',
#  'purchase',
#  'elimination',
#  'portions',
#  'toward',
#  'practices',
#  'desperate',
#  'threatened',
#  'individual',
#  'permit',
#  'pigmeat',
#  'complete',
#  'forward',
#  'nebraska',
#  'simultaneous',
#  'operating',
#  'nutritious',
#  'whole',
#  'peanut',
#  'taiwan',
#  'omnibus',
#  'dollars',
#  'locate',
#  'packing',
#  'fallen',
#  'wanted',
#  'across',
#  'its',
#  'crowns',
#  'vs',
#  'foodstuffs',
#  'totalled',
#  'processing',
#  'says',
#  'retail',
#  'lee',
#  'right',
#  'similar',
#  'robust',
#  'friesian',
#  'hospitalized',
#  'pesticide',
#  'fears',
#  'involves',
#  'bought',
#  'shipments',
#  'head',
#  'large',
#  'workers',
#  'ecu',
#  'laboratory',
#  'abe',
#  'permanent',
#  'own',
#  'eligibility',
#  'greater',
#  'slaughterers',
#  'supply',
#  'lt',
#  'minnesota',
#  'unavailable',
#  'despite',
#  'health',
#  'guess',
#  'original',
#  'upper',
#  'sharply',
#  'port',
#  'poisoning',
#  'deficit',
#  'declared',
#  'floor',
#  'sent',
#  'ame',
#  'subsidiary',
#  'could',
#  'draft',
#  'rate',
#  'identify',
#  'confirms',
#  'receive',
#  'declined',
#  'nation',
#  'oversight',
#  'stenholm',
#  'chuck',
#  'gap',
#  'cover',
#  'refuses',
#  'followed',
#  'researchers',
#  'alone',
#  'advisories',
#  'principle',
#  'provides',
#  'plus',
#  'watches',
#  'fresh',
#  'gidel',
#  'cocoa',
#  'approvals',
#  'exists',
#  'helping',
#  'houston',
#  'completely',
#  'complaints',
#  'turkeys',
#  'early',
#  'overwhelming',
#  'methods',
#  'remaining',
#  'laying',
#  'allowed',
#  'arabia',
#  'successful',
#  'procedures',
#  'death',
#  'melcher',
#  'fixed',
#  'safe',
#  'francois',
#  'island',
#  'combined',
#  'cattlemen',
#  'unanimously',
#  'marketings',
#  'annually',
#  'later',
#  'imminent',
#  'hook',
#  'sectors',
#  'dispute',
#  'mackie',
#  'puts',
#  'movement',
#  'reduces',
#  'protected',
#  'timetable',
#  'affected',
#  'needy',
#  'owens',
#  'situation',
#  'zack',
#  'formation',
#  'purees',
#  'aim',
#  'affairs',
#  'argentina',
#  'doubled',
#  'compensation',
#  'fight',
#  'came',
#  'brands',
#  'fell',
#  'barrier',
#  'branding',
#  'ease',
#  'providing',
#  'risk',
#  'ia',
#  'amendments',
#  'establishing',
#  'noted',
#  'lawmakers',
#  'just',
#  'capitol',
#  'cuban',
#  'step',
#  'technology',
#  'rise',
#  'percentage',
#  'drifting',
#  'rodney',
#  'grazing',
#  'suppports',
#  'over',
#  'say',
#  'faulty',
#  'normal',
#  'leaders',
#  'weekly',
#  'relations',
#  'inedible',
#  'farming',
#  'fat',
#  'o',
#  'livestock',
#  'respond',
#  'puerto',
#  'matabeleland',
#  'nauman',
#  'proposed',
#  'pact',
#  'eradicate',
#  'technical',
#  'face',
#  'corp',
#  'spanish',
#  'new',
#  'allowing',
#  'positive',
#  'requirements',
#  'uffe',
#  'subsidies',
#  'wholesale',
#  'harvest',
#  'proposes',
#  'hatching',
#  'terms',
#  'haiti',
#  'steve',
#  'former',
#  'semi',
#  'wagyu',
#  'bull',
#  'limits',
#  'actual',
#  'recommendation',
#  'feet',
#  'forbid',
#  'outvoted',
#  'warnings',
#  'make',
#  'recognised',
#  'cut',
#  'disrupt',
#  'closed',
#  'raising',
#  'huron',
#  'discussion',
#  'bentsen',
#  'gatt',
#  'census',
#  'necessary',
#  'currency',
#  'glen',
#  'southeast',
#  'whatever',
#  'slaughtered',
#  'ohio',
#  'creole',
#  'aruba',
#  'push',
#  'implications',
#  'antibiotics',
#  'yen',
#  'meeting',
#  'flood',
#  'damp',
#  'exceeded',
#  'exotic',
#  'flexible',
#  'pigs',
#  'jaw',
#  'border',
#  'encouraged',
#  'status',
#  'ratios',
#  'percent',
#  'through',
#  'marketing',
#  'must',
#  'accept',
#  'bargaining',
#  'against',
#  'coast',
#  'transaction',
#  'dr',
#  'company',
#  'swift',
#  'pledged',
#  'lasted',
#  'increasingly',
#  'ciego',
#  'city',
#  'viruses',
#  'wheat',
#  'introduced',
#  'yeutter',
#  'vaccinate',
#  'ultimately',
#  'following',
#  'tightening',
#  'miller',
#  'glenn',
#  'beans',
#  'tomato',
#  'esmah',
#  'congressional',
#  'negotiated',
#  'easter',
#  'fish',
#  'benefit',
#  'hardship',
#  'bi',
#  'lyng',
#  'proessing',
#  'might',
#  'demonstrating',
#  'headquarters',
#  'charities',
#  'resistant',
#  'earmarked',
#  'state',
#  'abbenhaus',
#  'our',
#  'urged',
#  'hope',
#  'night',
#  'japanese',
#  'insists',
#  'history',
#  'key',
#  'expanded',
#  'contain',
#  'advisory',
#  'totaling',
#  'windy',
#  'busy',
#  'wholesalers',
#  'there',
#  'working',
#  'contaminated',
#  'majority',
#  'thirds',
#  'imposed',
#  'add',
#  'unable',
#  'mississippi',
#  'deal',
#  'havana',
#  'lean',
#  'given',
#  'buyer',
#  'iraq',
#  'frequent',
#  'maintain',
#  'conceded',
#  'continuing',
#  'appears',
#  'proposals',
#  'recommends',
#  'advanced',
#  'veal',
#  'intentions',
#  'ec',
#  'affecting',
#  'pushing',
#  'explained',
#  'minn',
#  'live',
#  'efforts',
#  'way',
#  'canning',
#  'legislative',
#  'remains',
#  'soymeal',
#  'debate',
#  'marginally',
#  'critics',
#  'survive',
#  'bean',
#  'residues',
#  'send',
#  'guesstimates',
#  'subject',
#  'bar',
#  'ratio',
#  'fix',
#  'tell',
#  'slide',
#  'reserve',
#  'environment',
#  'bacterium',
#  'is',
#  'andriessen',
#  'chloramphenicol',
#  'main',
#  'humans',
#  'speech',
#  'complex',
#  'eight',
#  'impact',
#  'possible',
#  'his',
#  'reduction',
#  'won',
#  'export',
#  'virus',
#  'promotion',
#  'ruling',
#  'labor',
#  'seven',
#  'l',
#  'congressmen',
#  'circles',
#  'hunt',
#  'faster',
#  'north',
#  'statistics',
#  'awarding',
#  'formally',
#  'showers',
#  'occurred',
#  'rep',
#  'resolutions',
#  'larger',
#  'flatly',
#  'comply',
#  'bird',
#  'contagious',
#  'broaden',
#  'harming',
#  'granma',
#  'placed',
#  'mills',
#  'remain',
#  'dragging',
#  'extreme',
#  'revised',
#  'continued',
#  'immediate',
#  'so',
#  'asks',
#  'pick',
#  'dairy',
#  'boneless',
#  'certain',
#  'saying',
#  'industrial',
#  'southwestern',
#  'calling',
#  'implemented',
#  'remove',
#  'amounts',
#  'monthly',
#  'alternative',
#  'entry',
#  'running',
#  'edible',
#  'immigration',
#  'mupawose',
#  'mean',
#  'social',
#  'pensions',
#  'constitute',
#  'buffer',
#  'refinance',
#  'detail',
#  'business',
#  'instability',
#  'here',
#  'legality',
#  'seen',
#  'felt',
#  'merge',
#  'california',
#  'received',
#  'suspicion',
#  'claimed',
#  'being',
#  'loin',
#  'released',
#  'relatively',
#  'expo',
#  'considerably',
#  'vice',
#  'showed',
#  'low',
#  'burden',
#  'effects',
#  'climate',
#  'gave',
#  'troy',
#  'few',
#  'debated',
#  'bullish',
#  'feb',
#  'slower',
#  'carries',
#  'brings',
#  'mostly',
#  'totaled',
#  'event',
#  'slaughterhouses',
#  'foot',
#  'flu',
#  'close',
#  'structural',
#  'guesstimated',
#  'originally',
#  'sugar',
#  'completes',
#  'does',
#  'not',
#  'shifted',
#  'issued',
#  'earnings',
#  'agreed',
#  'worker',
#  'deserts',
#  'per',
#  'least',
#  'reviewing',
#  'caused',
#  'moines',
#  'body',
#  'offal',
#  'announcing',
#  'finance',
#  'beasts',
#  'synthetic',
#  'open',
#  'moving',
#  'cuba',
#  'precious',
#  'time',
#  'hill',
#  'keep',
#  'poultry',
#  'voids',
#  'poor',
#  'postpone',
#  'entirely',
#  'bio',
#  'african',
#  'cargoes',
#  'cheap',
#  'inventory',
#  'protesting',
#  'david',
#  'rather',
#  'fundamentals',
#  'maintains',
#  'pay',
#  'wages',
#  'qualify',
#  'friday',
#  'office',
#  'auction',
#  'said',
#  'rumors',
#  'va',
#  'oilseeds',
#  'june',
#  'marginal',
#  'prevent',
#  'planning',
#  'planned',
#  'soybeans',
#  'seeks',
#  'demonstrations',
#  'between',
#  'jerry',
#  'threatens',
#  'advances',
#  'inclusion',
#  'periodically',
#  'welfare',
#  'ranging',
#  'employs',
#  'traded',
#  'mounting',
#  'high',
#  'hoped',
#  'dense',
#  'york',
#  'positions',
#  'vacuum',
#  'hours',
#  'origins',
#  'reluctant',
#  'america',
#  'feedgrain',
#  'retaliating',
#  'obtained',
#  'community',
#  'jensen',
#  'favour',
#  'canada',
#  'cme',
#  'compounding',
#  'expensive',
#  'past',
#  'apc',
#  'young',
#  'swiftly',
#  'cutting',
#  'opens',
#  'inside',
#  'injury',
#  'encourage',
#  'hens',
#  'islands',
#  'drifted',
#  'assurance',
#  'offers',
#  'include',
#  'maximun',
#  'embassy',
#  'awarded',
#  'understanding',
#  'susbsidiary',
#  'rico',
#  'heavy',
#  'ark',
#  'defended',
#  'putting',
#  'cows',
#  'reaffirmed',
#  'approve',
#  'lot',
#  'seemed',
#  'recorders',
#  'dietitian',
#  'currently',
#  'votes',
#  'direct',
#  'urge',
#  'urges',
#  'force',
#  'wood',
#  'foreign',
#  'represents',
#  'equivalent',
#  'petition',
#  'weeks',
#  'olin',
#  'sources',
#  'representatives',
#  'parched',
#  'earlier',
#  'epidemic',
#  'findings',
#  'idle',
#  'castrated',
#  'bangladesh',
#  'holstein',
#  'going',
#  'mouth',
#  'storage',
#  'de',
#  'retain',
#  'stabilisation',
#  'gusts',
#  'lowered',
#  'guarantee',
#  'place',
#  'external',
#  'hedging',
#  'accentuate',
#  'brackets',
#  'allow',
#  'averaged',
#  'helped',
#  'oilseed',
#  'about',
#  'diagnostic',
#  'ago',
#  'mainly',
#  'complicated',
#  'common',
#  'applied',
#  'fixing',
#  'reply',
#  'appointed',
#  'provisions',
#  'gains',
#  'disruptions',
#  'accompanied',
#  'really',
#  'panel',
#  'depending',
#  'another',
#  'cultivation',
#  'nevada',
#  'uncertain',
#  'classified',
#  'agri',
#  'precipitation',
#  'economies',
#  'period',
#  'the',
#  'prior',
#  'zero',
#  'development',
#  'for',
#  'decides',
#  'measures',
#  'deficiencies',
#  'assess',
#  'compensatory',
#  'elmer',
#  'put',
#  'less',
#  'both',
#  'recognized',
#  'eradication',
#  'rinderpest',
#  'indication',
#  'director',
#  'considerable',
#  'journal',
#  'calls',
#  'coffee',
#  'firms',
#  'occurs',
#  'interrupt',
#  'concepts',
#  'canadians',
#  'domestically',
#  'promising',
#  'team',
#  'proponents',
#  'facility',
#  'stangeland',
#  'exporters',
#  'hotly',
#  'farmers',
#  'pipeline',
#  'drafting',
#  'produces',
#  'usage',
#  'marty',
#  'ketchup',
#  'disruption',
#  'faith',
#  'journalists',
#  'problem',
#  'grease',
#  'according',
#  'us',
#  'plans',
#  'see',
#  'wants',
#  'largest',
#  'stimulate',
#  'content',
#  'dominate',
#  'distributed',
#  'sheep',
#  'rapeseed',
#  'basically',
#  'loans',
#  'resolving',
#  'imperfections',
#  'sara',
#  'producing',
#  'flown',
#  'extended',
#  'placing',
#  'reporters',
#  'hard',
#  'requesting',
#  'occidental',
#  'insert',
#  'leonard',
#  'robin',
#  'ambitous',
#  'seng',
#  'glutted',
#  'uniform',
#  'unpredictable',
#  'session',
#  'products',
#  'hedge',
#  'clear',
#  'able',
#  'phillip',
#  'shortage',
#  'lipc',
#  'committee',
#  'centers',
#  'shadow',
#  'aimed',
#  'moisture',
#  'farrowing',
#  'rcpts',
#  'overtime',
#  'ufcwu',
#  'carcases',
#  'money',
#  'rule',
#  'stops',
#  'now',
#  'brucellosis',
#  'ray',
#  'shows',
#  'smooth',
#  'cabinet',
#  'vigorously',
#  'second',
#  'lifts',
#  'practically',
#  'auctions',
#  'spread',
#  'tumbled',
#  'certainly',
#  'sense',
#  'outbreak',
#  'feedlots',
#  'call',
#  'allowable',
#  'managers',
#  'legal',
#  'purveyors',
#  'jeoparadising',
#  'west',
#  'presticide',
#  'wehler',
#  'viral',
#  'reeds',
#  'nearby',
#  'offered',
#  'wage',
#  'means',
#  'deals',
#  'barriers',
#  'endorse',
#  'stock',
#  'marbled',
#  'within',
#  'attributed',
#  'off',
#  'sides',
#  'plant',
#  'regulations',
#  'final',
#  'output',
#  'delivery',
#  'options',
#  'tuesday',
#  'values',
#  'suzanne',
#  ...]

# %%
# Add a special token for unknown words
vocabs.append('<UNK>')

# %%
# Create a mapping from words to their indices
word2index = {v: idx for idx, v in enumerate(vocabs)}
print(word2index['<UNK>'])  # Print the index of the <UNK> token
# Out:
# 2907

# %%
index2word = {v:k for k, v in word2index.items()}

# %% [markdown]
# ## 3. Batch Preparation for Training

# %%
# Count the frequency of each word in the corpus
from collections import Counter

X_i = Counter(flatten_corpus)
X_i
# Out:
# Counter({'the': 1145,
#          'to': 598,
#          'of': 478,
#          'and': 470,
#          'in': 354,
#          'a': 330,
#          'said': 314,
#          's': 257,
#          'for': 210,
#          'u': 167,
#          'on': 152,
#          'beef': 140,
#          'at': 133,
#          'that': 124,
#          'is': 119,
#          'from': 117,
#          'will': 103,
#          'by': 101,
#          'mln': 100,
#          'cattle': 99,
#          'meat': 97,
#          'it': 93,
#          'be': 92,
#          'are': 89,
#          'year': 88,
#          'ec': 88,
#          'with': 74,
#          'was': 73,
#          'trade': 71,
#          'an': 71,
#          'would': 69,
#          'tonnes': 69,
#          'as': 64,
#          'agriculture': 62,
#          'pork': 62,
#          'japan': 57,
#          'have': 57,
#          'has': 56,
#          'farm': 55,
#          'been': 54,
#          'head': 54,
#          'pct': 52,
#          'department': 51,
#          'he': 50,
#          'ago': 50,
#          'were': 49,
#          'this': 48,
#          'not': 48,
#          'which': 47,
#          'its': 46,
#          'dlrs': 46,
#          'prices': 45,
#          'they': 44,
#          'usda': 43,
#          'but': 42,
#          'also': 41,
#          'under': 41,
#          'about': 41,
#          'futures': 41,
#          'exports': 39,
#          'market': 37,
#          'program': 37,
#          'slaughter': 37,
#          'imports': 36,
#          'new': 36,
#          'plant': 36,
#          'april': 35,
#          'hog': 35,
#          'week': 35,
#          'lbs': 35,
#          'march': 34,
#          'markets': 33,
#          'production': 32,
#          'against': 32,
#          'products': 31,
#          'their': 31,
#          'last': 31,
#          'exchange': 31,
#          'officials': 30,
#          'dairy': 30,
#          'report': 30,
#          'export': 30,
#          'than': 29,
#          'livestock': 29,
#          'industry': 29,
#          'union': 29,
#          'producers': 29,
#          'farmers': 28,
#          'had': 27,
#          'other': 26,
#          'import': 26,
#          'if': 26,
#          'government': 26,
#          'united': 26,
#          'or': 26,
#          'commission': 26,
#          'traders': 25,
#          'food': 25,
#          'over': 25,
#          'community': 25,
#          'we': 25,
#          'there': 25,
#          'because': 25,
#          'expected': 24,
#          'states': 24,
#          'today': 24,
#          'all': 23,
#          'may': 23,
#          'price': 23,
#          'month': 22,
#          'up': 22,
#          'some': 22,
#          'national': 22,
#          'ccc': 22,
#          'iowa': 22,
#          'more': 21,
#          'offer': 21,
#          'december': 21,
#          'poultry': 21,
#          'bonus': 21,
#          'congress': 21,
#          'sales': 20,
#          'told': 20,
#          'american': 20,
#          'live': 20,
#          'two': 20,
#          'dakota': 20,
#          'february': 20,
#          'official': 19,
#          'into': 19,
#          'years': 19,
#          'disease': 19,
#          'european': 19,
#          'feed': 19,
#          'nppc': 19,
#          'increase': 18,
#          'house': 18,
#          'output': 18,
#          'sources': 18,
#          'credit': 18,
#          'january': 18,
#          'workers': 18,
#          'members': 18,
#          'ministry': 17,
#          'grain': 17,
#          'system': 17,
#          'no': 17,
#          'quota': 17,
#          'versus': 17,
#          'committee': 17,
#          'added': 17,
#          'high': 17,
#          'after': 17,
#          'use': 17,
#          'could': 16,
#          'one': 16,
#          'inspection': 16,
#          'chicago': 16,
#          'state': 16,
#          'operations': 16,
#          'period': 16,
#          'end': 15,
#          'while': 15,
#          'less': 15,
#          'cut': 15,
#          'commodity': 15,
#          'commodities': 15,
#          'through': 15,
#          'study': 15,
#          'due': 14,
#          'who': 14,
#          'demand': 14,
#          'australia': 14,
#          'south': 14,
#          'when': 14,
#          'same': 14,
#          'being': 14,
#          'company': 14,
#          'three': 14,
#          'mercantile': 14,
#          'major': 14,
#          'stocks': 14,
#          'hogs': 14,
#          'work': 14,
#          'cash': 14,
#          'approved': 14,
#          'city': 14,
#          'between': 13,
#          'corn': 13,
#          'proposal': 13,
#          'most': 13,
#          'estimated': 13,
#          'sell': 13,
#          'board': 13,
#          'earlier': 13,
#          'contract': 13,
#          'made': 13,
#          'announced': 13,
#          'australian': 13,
#          'sugar': 13,
#          'months': 13,
#          'figures': 13,
#          'vs': 13,
#          'contracts': 13,
#          'revised': 13,
#          'bill': 13,
#          'lipc': 13,
#          'lockout': 13,
#          'central': 13,
#          'minister': 12,
#          'secretary': 12,
#          'next': 12,
#          'since': 12,
#          'agricultural': 12,
#          'help': 12,
#          'product': 12,
#          'd': 12,
#          'association': 12,
#          'now': 12,
#          'floor': 12,
#          'continue': 12,
#          'value': 12,
#          'lower': 12,
#          'analysts': 12,
#          'inc': 12,
#          'canadian': 12,
#          'show': 12,
#          'during': 12,
#          'set': 12,
#          'processors': 12,
#          'spokesman': 12,
#          'local': 11,
#          'canada': 11,
#          'japanese': 11,
#          'out': 11,
#          'health': 11,
#          'salmonella': 11,
#          'time': 11,
#          'five': 11,
#          'number': 11,
#          'per': 11,
#          'included': 11,
#          'country': 11,
#          'still': 11,
#          'only': 11,
#          'islands': 11,
#          'effect': 11,
#          'administration': 11,
#          'plan': 11,
#          'cereals': 11,
#          'proposals': 11,
#          'corp': 11,
#          'delegates': 11,
#          'drug': 11,
#          'zack': 11,
#          'open': 10,
#          'wheat': 10,
#          'where': 10,
#          'controls': 10,
#          'require': 10,
#          'consumers': 10,
#          'world': 10,
#          'can': 10,
#          'reported': 10,
#          'council': 10,
#          'such': 10,
#          'representatives': 10,
#          'guesstimated': 10,
#          'noted': 10,
#          'outbreak': 10,
#          'york': 10,
#          'intervention': 10,
#          'trading': 10,
#          'analyst': 10,
#          'frozen': 10,
#          'weight': 10,
#          'previous': 10,
#          'delivery': 10,
#          'available': 10,
#          'agreed': 10,
#          'petition': 10,
#          'argentina': 10,
#          'eep': 10,
#          'gatt': 10,
#          'both': 10,
#          'tallow': 10,
#          'total': 10,
#          'meatpackers': 10,
#          'nebraska': 10,
#          'cold': 10,
#          'buy': 9,
#          'countries': 9,
#          'already': 9,
#          'increased': 9,
#          'including': 9,
#          'should': 9,
#          'these': 9,
#          'foreign': 9,
#          'change': 9,
#          'current': 9,
#          'used': 9,
#          'plants': 9,
#          'june': 9,
#          'before': 9,
#          'dollar': 9,
#          'brackets': 9,
#          'cuts': 9,
#          'main': 9,
#          'yesterday': 9,
#          'corporation': 9,
#          'support': 9,
#          'higher': 9,
#          'sale': 9,
#          'processing': 9,
#          'rose': 9,
#          'scheme': 9,
#          'deal': 9,
#          'ministers': 9,
#          'fiscal': 9,
#          'levitt': 9,
#          'first': 9,
#          'meeting': 9,
#          'mechanically': 9,
#          'separated': 9,
#          'storage': 9,
#          'largest': 8,
#          'lyng': 8,
#          'provide': 8,
#          'general': 8,
#          'proposed': 8,
#          'fat': 8,
#          'take': 8,
#          'much': 8,
#          'past': 8,
#          'rep': 8,
#          'chairman': 8,
#          'steers': 8,
#          'july': 8,
#          'guesstimates': 8,
#          'guesstimating': 8,
#          'good': 8,
#          'grade': 8,
#          'zimbabwe': 8,
#          'policy': 8,
#          'control': 8,
#          'rules': 8,
#          'gains': 8,
#          'posted': 8,
#          'nations': 8,
#          'co': 8,
#          'our': 8,
#          'canary': 8,
#          'enhancement': 8,
#          'so': 8,
#          'shipments': 8,
#          'danish': 8,
#          'response': 8,
#          'international': 8,
#          'aid': 8,
#          'negative': 8,
#          'shipped': 8,
#          'stg': 8,
#          'commercial': 8,
#          'ufcwu': 8,
#          'ibp': 8,
#          'decline': 8,
#          'strike': 8,
#          'latest': 8,
#          'ceiling': 8,
#          'marketings': 8,
#          'across': 8,
#          'drop': 7,
#          'declined': 7,
#          'then': 7,
#          'ask': 7,
#          'remain': 7,
#          'business': 7,
#          'tariffs': 7,
#          'group': 7,
#          'any': 7,
#          'pressure': 7,
#          'issues': 7,
#          'rule': 7,
#          'subcommittee': 7,
#          'requirement': 7,
#          'several': 7,
#          'called': 7,
#          'offered': 7,
#          'director': 7,
#          'law': 7,
#          'supply': 7,
#          'cost': 7,
#          'animals': 7,
#          'eastern': 7,
#          'few': 7,
#          'decision': 7,
#          'free': 7,
#          'iraq': 7,
#          'action': 7,
#          'line': 7,
#          'closed': 7,
#          'day': 7,
#          'seven': 7,
#          'long': 7,
#          'do': 7,
#          'i': 7,
#          'bellies': 7,
#          'paid': 7,
#          'form': 7,
#          'additional': 7,
#          'allow': 7,
#          'totalled': 7,
#          'yen': 7,
#          'consumption': 7,
#          'above': 7,
#          'samuels': 7,
#          'those': 7,
#          'reduce': 7,
#          'animal': 7,
#          'following': 7,
#          'france': 7,
#          'six': 7,
#          'guillaume': 7,
#          'package': 7,
#          'whether': 7,
#          'pig': 7,
#          'inedible': 7,
#          'edible': 7,
#          'marketing': 7,
#          'according': 7,
#          'amendments': 7,
#          'apply': 7,
#          'korea': 7,
#          'domestic': 7,
#          'half': 7,
#          'tender': 7,
#          'present': 7,
#          'k': 7,
#          'john': 7,
#          'occidental': 7,
#          'petroleum': 7,
#          'pigs': 7,
#          'comparative': 7,
#          'c': 7,
#          'egypt': 7,
#          'quotas': 6,
#          'four': 6,
#          'mainly': 6,
#          'billion': 6,
#          'agreement': 6,
#          'issue': 6,
#          'inspectors': 6,
#          'president': 6,
#          'little': 6,
#          'effective': 6,
#          'around': 6,
#          'see': 6,
#          'panel': 6,
#          'argentine': 6,
#          'wednesday': 6,
#          'equivalent': 6,
#          'however': 6,
#          'ban': 6,
#          'cents': 6,
#          'plans': 6,
#          'many': 6,
#          't': 6,
#          'accepted': 6,
#          'bid': 6,
#          'initiative': 6,
#          'swift': 6,
#          'huron': 6,
#          'subject': 6,
#          'seen': 6,
#          'go': 6,
#          'standards': 6,
#          'surplus': 6,
#          'ratio': 6,
#          'poor': 6,
#          'she': 6,
#          'levels': 6,
#          'pigmeat': 6,
#          'tax': 6,
#          'subsidies': 6,
#          'problems': 6,
#          'affected': 6,
#          'de': 6,
#          'eradication': 6,
#          'producer': 6,
#          'costs': 6,
#          'reducing': 6,
#          'farms': 6,
#          'late': 6,
#          'herd': 6,
#          'factory': 6,
#          'bureau': 6,
#          'feb': 6,
#          'them': 6,
#          'provision': 6,
#          'spread': 6,
#          'distribution': 6,
#          'amnesty': 6,
#          'strong': 6,
#          'resistant': 6,
#          'lmfe': 6,
#          'frawley': 6,
#          'file': 6,
#          'ame': 6,
#          'senate': 6,
#          'zone': 6,
#          'standard': 6,
#          'storm': 6,
#          'morning': 6,
#          'talks': 5,
#          'kato': 5,
#          'richard': 5,
#          'remove': 5,
#          'here': 5,
#          'rise': 5,
#          'urged': 5,
#          'restrictions': 5,
#          'houston': 5,
#          'avoid': 5,
#          'programs': 5,
#          'executive': 5,
#          'concerned': 5,
#          'project': 5,
#          'federal': 5,
#          'cases': 5,
#          'recommended': 5,
#          'certain': 5,
#          'letter': 5,
#          'must': 5,
#          'permanent': 5,
#          'way': 5,
#          'entry': 5,
#          'kilo': 5,
#          'round': 5,
#          'veterinary': 5,
#          'province': 5,
#          'producing': 5,
#          'least': 5,
#          'source': 5,
#          'areas': 5,
#          'low': 5,
#          'guarantees': 5,
#          'taken': 5,
#          'smith': 5,
#          'think': 5,
#          'soviet': 5,
#          'sharp': 5,
#          'feeder': 5,
#          'average': 5,
#          'accepts': 5,
#          'cover': 5,
#          'inventory': 5,
#          'terms': 5,
#          'lt': 5,
#          'directive': 5,
#          'expect': 5,
#          'beginning': 5,
#          'retaliate': 5,
#          'further': 5,
#          'representative': 5,
#          'growth': 5,
#          'fell': 5,
#          'issued': 5,
#          'parts': 5,
#          'very': 5,
#          'conference': 5,
#          'washington': 5,
#          'oilseeds': 5,
#          'oils': 5,
#          'fats': 5,
#          'reduction': 5,
#          'measures': 5,
#          'submitted': 5,
#          'say': 5,
#          'spain': 5,
#          'quality': 5,
#          'benefit': 5,
#          'well': 5,
#          'checkoff': 5,
#          'disrupt': 5,
#          'annual': 5,
#          'warning': 5,
#          'likely': 5,
#          'down': 5,
#          'jan': 5,
#          'follows': 5,
#          'slightly': 5,
#          'ending': 5,
#          'lamb': 5,
#          'amendment': 5,
#          'r': 5,
#          'voted': 5,
#          'birds': 5,
#          'september': 5,
#          'indianapolis': 5,
#          'immigration': 5,
#          'cane': 5,
#          'member': 5,
#          'early': 5,
#          'pay': 5,
#          'potato': 5,
#          'humans': 5,
#          'rejected': 5,
#          'allen': 5,
#          'expired': 5,
#          'wage': 5,
#          'hour': 5,
#          'london': 5,
#          'morrell': 5,
#          'gulf': 5,
#          'iran': 5,
#          'ufcw': 5,
#          'rally': 5,
#          'forecast': 5,
#          'intended': 5,
#          'kansas': 5,
#          'users': 4,
#          'share': 4,
#          'soybean': 4,
#          'brazil': 4,
#          'almost': 4,
#          'came': 4,
#          'asked': 4,
#          'become': 4,
#          'industrial': 4,
#          'sector': 4,
#          'propose': 4,
#          'fsis': 4,
#          'regulations': 4,
#          'another': 4,
#          'groups': 4,
#          'public': 4,
#          'risk': 4,
#          'federation': 4,
#          'consumer': 4,
#          'institute': 4,
#          'staff': 4,
#          'serious': 4,
#          'pace': 4,
#          'raw': 4,
#          'research': 4,
#          'too': 4,
#          'mexican': 4,
#          'imported': 4,
#          'improve': 4,
#          'tuberculosis': 4,
#          'affect': 4,
#          'season': 4,
#          'choice': 4,
#          'part': 4,
#          'worth': 4,
#          'considering': 4,
#          'meet': 4,
#          'projected': 4,
#          'result': 4,
#          'previously': 4,
#          'protein': 4,
#          'grains': 4,
#          'despite': 4,
#          'known': 4,
#          'term': 4,
#          'direction': 4,
#          'force': 4,
#          'measure': 4,
#          'believed': 4,
#          'falling': 4,
#          'settlement': 4,
#          'based': 4,
#          'direct': 4,
#          'october': 4,
#          'purchase': 4,
#          'operation': 4,
#          'off': 4,
#          'make': 4,
#          'changes': 4,
#          'without': 4,
#          'continued': 4,
#          'how': 4,
#          'regulation': 4,
#          'compound': 4,
#          'slight': 4,
#          'compounding': 4,
#          'meal': 4,
#          'exporters': 4,
#          'details': 4,
#          'offers': 4,
#          'place': 4,
#          'reuters': 4,
#          'daily': 4,
#          'discussions': 4,
#          'tough': 4,
#          'rights': 4,
#          'ahead': 4,
#          'oppose': 4,
#          'level': 4,
#          'extended': 4,
#          'emergency': 4,
#          'consider': 4,
#          'designed': 4,
#          'portugal': 4,
#          'west': 4,
#          'objections': 4,
#          'better': 4,
#          'diseases': 4,
#          'population': 4,
#          'university': 4,
#          'showed': 4,
#          'feeding': 4,
#          'funded': 4,
#          'researchers': 4,
#          'cooked': 4,
#          'reject': 4,
#          'give': 4,
#          'milk': 4,
#          'planned': 4,
#          'back': 4,
#          'drought': 4,
#          'spreading': 4,
#          'statement': 4,
#          'actual': 4,
#          'croo': 4,
#          'within': 4,
#          'congressional': 4,
#          'debate': 4,
#          'yeutter': 4,
#          'might': 4,
#          'banned': 4,
#          'compared': 4,
#          'nearby': 4,
#          'selling': 4,
#          'chuck': 4,
#          'fuller': 4,
#          'each': 4,
#          'mean': 4,
#          'numbers': 4,
#          'amounted': 4,
#          'usage': 4,
#          'containing': 4,
#          'tobacco': 4,
#          'facilities': 4,
#          'involved': 4,
#          'promotion': 4,
#          'started': 4,
#          'agency': 4,
#          'apc': 4,
#          'running': 4,
#          'provisions': 4,
#          'alternative': 4,
#          'enable': 4,
#          'strict': 4,
#          'gafta': 4,
#          'antibiotics': 4,
#          'pseudorabies': 4,
#          'safe': 4,
#          'prv': 4,
#          'rate': 4,
#          'allows': 4,
#          'labor': 4,
#          'survey': 4,
#          'avian': 4,
#          'influenza': 4,
#          'settled': 4,
#          'sunday': 4,
#          'horse': 4,
#          'offal': 4,
#          'destinations': 4,
#          'bone': 4,
#          'middle': 4,
#          'east': 4,
#          'arab': 4,
#          'kuwait': 4,
#          'stock': 4,
#          'fresh': 4,
#          'chilled': 4,
#          'amlc': 4,
#          'until': 4,
#          'molpus': 4,
#          'stabilisation': 4,
#          'placements': 4,
#          'belly': 4,
#          'oklahoma': 4,
#          'plains': 4,
#          'winter': 4,
#          'snow': 4,
#          'senators': 4,
#          'says': 3,
#          'demands': 3,
#          'later': 3,
#          'senior': 3,
#          'active': 3,
#          'protect': 3,
#          'competitive': 3,
#          'visit': 3,
#          'boost': 3,
#          'although': 3,
#          'position': 3,
#          'potential': 3,
#          'alone': 3,
#          'representing': 3,
#          'prepared': 3,
#          'top': 3,
#          'reaction': 3,
#          'safety': 3,
#          'service': 3,
#          'put': 3,
#          'economic': 3,
#          'contaminated': 3,
#          'whole': 3,
#          'constant': 3,
#          'confident': 3,
#          'him': 3,
#          'raising': 3,
#          'profits': 3,
#          'hearing': 3,
#          'residues': 3,
#          'eradicated': 3,
#          'found': 3,
#          'approximately': 3,
#          'develop': 3,
#          'procedures': 3,
#          'complicated': 3,
#          'real': 3,
#          'vice': 3,
#          'mexico': 3,
#          'nearly': 3,
#          'thursday': 3,
#          'supplies': 3,
#          'interest': 3,
#          'bottom': 3,
#          'zimbabwean': 3,
#          'mouth': 3,
#          'situation': 3,
#          'us': 3,
#          'identified': 3,
#          'fall': 3,
#          'transferred': 3,
#          'request': 3,
#          'organization': 3,
#          'guarantee': 3,
#          'gold': 3,
#          'cotton': 3,
#          'rates': 3,
#          'silver': 3,
#          'key': 3,
#          'chronowitz': 3,
#          'barney': 3,
#          'ability': 3,
#          'currency': 3,
#          'values': 3,
#          'correct': 3,
#          'going': 3,
#          'process': 3,
#          'makes': 3,
#          'cheaper': 3,
#          'holding': 3,
#          'close': 3,
#          'raised': 3,
#          'boosted': 3,
#          'normal': 3,
#          'steer': 3,
#          'cme': 3,
#          'fed': 3,
#          'packing': 3,
#          'completion': 3,
#          'deadline': 3,
#          'held': 3,
#          'controversial': 3,
#          'submit': 3,
#          'improvement': 3,
#          'comply': 3,
#          'fully': 3,
#          'reagan': 3,
#          'valued': 3,
#          'review': 3,
#          'remaining': 3,
#          'draft': 3,
#          'expectation': 3,
#          'bring': 3,
#          'marginal': 3,
#          'reduced': 3,
#          'indonesia': 3,
#          'turkey': 3,
#          'eligible': 3,
#          'future': 3,
#          'spokeswoman': 3,
#          'imposed': 3,
#          'residue': 3,
#          'threatened': 3,
#          'reach': 3,
#          'slaughterhouse': 3,
#          'special': 3,
#          'claims': 3,
#          'include': 3,
#          'aim': 3,
#          'substitutes': 3,
#          'calls': 3,
#          'opposed': 3,
#          'directly': 3,
#          'respond': 3,
#          'wants': 3,
#          'compensate': 3,
#          'fish': 3,
#          'agree': 3,
#          'again': 3,
#          'majority': 3,
#          'saying': 3,
#          'improved': 3,
#          'boneless': 3,
#          'duty': 3,
#          'unable': 3,
#          'membership': 3,
#          'virginia': 3,
#          'brucellosis': 3,
#          'case': 3,
#          'achieve': 3,
#          'virgin': 3,
#          'leaner': 3,
#          'statistics': 3,
#          'evaluated': 3,
#          'below': 3,
#          'handbook': 3,
#          'content': 3,
#          'robin': 3,
#          'practices': 3,
#          'reforms': 3,
#          'financial': 3,
#          'fnsea': 3,
#          'monday': 3,
#          'his': 3,
#          'push': 3,
#          'protests': 3,
#          'lacombe': 3,
#          'reporters': 3,
#          'adding': 3,
#          'act': 3,
#          'spring': 3,
#          'clear': 3,
#          'minn': 3,
#          'vegetable': 3,
#          'clayton': 3,
#          'meats': 3,
#          'toward': 3,
#          'shows': 3,
#          'resulting': 3,
#          'step': 3,
#          'limit': 3,
#          'missouri': 3,
#          'grimes': 3,
#          'shearson': 3,
#          'lehman': 3,
#          'even': 3,
#          'heavy': 3,
#          'actually': 3,
#          'get': 3,
#          'just': 3,
#          'lead': 3,
#          'starting': 3,
#          'revision': 3,
#          'expectations': 3,
#          'distant': 3,
#          'discount': 3,
#          'consideration': 3,
#          'crop': 3,
#          'jerry': 3,
#          'lard': 3,
#          'slaughtered': 3,
#          'cumulative': 3,
#          'addition': 3,
#          'extend': 3,
#          'restrict': 3,
#          'overall': 3,
#          'legislation': 3,
#          'rather': 3,
#          'glickman': 3,
#          'requiring': 3,
#          'aimed': 3,
#          'bulk': 3,
#          'primarily': 3,
#          'amount': 3,
#          'section': 3,
#          'conduct': 3,
#          'pet': 3,
#          'bird': 3,
#          'maryland': 3,
#          'valley': 3,
#          'southern': 3,
#          'california': 3,
#          'mostly': 3,
#          'listed': 3,
#          'carcass': 3,
#          'hand': 3,
#          'refunds': 3,
#          'nine': 3,
#          'packers': 3,
#          'dealers': 3,
#          'required': 3,
#          ...})

# %%
# Generate skip-grams: pairs of target and context words
skip_grams = []

for doc in corpus:
    for i in range(2, len(doc)-2):
        center = doc[i]
        outside = [doc[i-2], doc[i-1], doc[i+1], doc[i+2]]
        for each_out in outside:
            skip_grams.append((center, each_out))
skip_grams
# Out:
# [('says', 'japan'),
#  ('says', 'ministry'),
#  ('says', 'open'),
#  ('says', 'farm'),
#  ('open', 'ministry'),
#  ('open', 'says'),
#  ('open', 'farm'),
#  ('open', 'trade'),
#  ('farm', 'says'),
#  ('farm', 'open'),
#  ('farm', 'trade'),
#  ('farm', 'would'),
#  ('trade', 'open'),
#  ('trade', 'farm'),
#  ('trade', 'would'),
#  ('trade', 'hit'),
#  ('would', 'farm'),
#  ('would', 'trade'),
#  ('would', 'hit'),
#  ('would', 'u'),
#  ('hit', 'trade'),
#  ('hit', 'would'),
#  ('hit', 'u'),
#  ('hit', 's'),
#  ('u', 'would'),
#  ('u', 'hit'),
#  ('u', 's'),
#  ('u', 'japan'),
#  ('s', 'hit'),
#  ('s', 'u'),
#  ('s', 'japan'),
#  ('s', 's'),
#  ('japan', 'u'),
#  ('japan', 's'),
#  ('japan', 's'),
#  ('japan', 'agriculture'),
#  ('s', 's'),
#  ('s', 'japan'),
#  ('s', 'agriculture'),
#  ('s', 'ministry'),
#  ('agriculture', 'japan'),
#  ('agriculture', 's'),
#  ('agriculture', 'ministry'),
#  ('agriculture', 'angered'),
#  ('ministry', 's'),
#  ('ministry', 'agriculture'),
#  ('ministry', 'angered'),
#  ('ministry', 'by'),
#  ('angered', 'agriculture'),
#  ('angered', 'ministry'),
#  ('angered', 'by'),
#  ('angered', 'u'),
#  ('by', 'ministry'),
#  ('by', 'angered'),
#  ('by', 'u'),
#  ('by', 's'),
#  ('u', 'angered'),
#  ('u', 'by'),
#  ('u', 's'),
#  ('u', 'demands'),
#  ('s', 'by'),
#  ('s', 'u'),
#  ('s', 'demands'),
#  ('s', 'that'),
#  ('demands', 'u'),
#  ('demands', 's'),
#  ('demands', 'that'),
#  ('demands', 'japan'),
#  ('that', 's'),
#  ('that', 'demands'),
#  ('that', 'japan'),
#  ('that', 'open'),
#  ('japan', 'demands'),
#  ('japan', 'that'),
#  ('japan', 'open'),
#  ('japan', 'its'),
#  ('open', 'that'),
#  ('open', 'japan'),
#  ('open', 'its'),
#  ('open', 'farm'),
#  ('its', 'japan'),
#  ('its', 'open'),
#  ('its', 'farm'),
#  ('its', 'products'),
#  ('farm', 'open'),
#  ('farm', 'its'),
#  ('farm', 'products'),
#  ('farm', 'market'),
#  ('products', 'its'),
#  ('products', 'farm'),
#  ('products', 'market'),
#  ('products', 'will'),
#  ('market', 'farm'),
#  ('market', 'products'),
#  ('market', 'will'),
#  ('market', 'tell'),
#  ('will', 'products'),
#  ('will', 'market'),
#  ('will', 'tell'),
#  ('will', 'u'),
#  ('tell', 'market'),
#  ('tell', 'will'),
#  ('tell', 'u'),
#  ('tell', 's'),
#  ('u', 'will'),
#  ('u', 'tell'),
#  ('u', 's'),
#  ('u', 'officials'),
#  ('s', 'tell'),
#  ('s', 'u'),
#  ('s', 'officials'),
#  ('s', 'at'),
#  ('officials', 'u'),
#  ('officials', 's'),
#  ('officials', 'at'),
#  ('officials', 'talks'),
#  ('at', 's'),
#  ('at', 'officials'),
#  ('at', 'talks'),
#  ('at', 'later'),
#  ('talks', 'officials'),
#  ('talks', 'at'),
#  ('talks', 'later'),
#  ('talks', 'this'),
#  ('later', 'at'),
#  ('later', 'talks'),
#  ('later', 'this'),
#  ('later', 'month'),
#  ('this', 'talks'),
#  ('this', 'later'),
#  ('this', 'month'),
#  ('this', 'that'),
#  ('month', 'later'),
#  ('month', 'this'),
#  ('month', 'that'),
#  ('month', 'liberalisation'),
#  ('that', 'this'),
#  ('that', 'month'),
#  ('that', 'liberalisation'),
#  ('that', 'would'),
#  ('liberalisation', 'month'),
#  ('liberalisation', 'that'),
#  ('liberalisation', 'would'),
#  ('liberalisation', 'harm'),
#  ('would', 'that'),
#  ('would', 'liberalisation'),
#  ('would', 'harm'),
#  ('would', 'existing'),
#  ('harm', 'liberalisation'),
#  ('harm', 'would'),
#  ('harm', 'existing'),
#  ('harm', 'u'),
#  ('existing', 'would'),
#  ('existing', 'harm'),
#  ('existing', 'u'),
#  ('existing', 's'),
#  ('u', 'harm'),
#  ('u', 'existing'),
#  ('u', 's'),
#  ('u', 'farm'),
#  ('s', 'existing'),
#  ('s', 'u'),
#  ('s', 'farm'),
#  ('s', 'exports'),
#  ('farm', 'u'),
#  ('farm', 's'),
#  ('farm', 'exports'),
#  ('farm', 'to'),
#  ('exports', 's'),
#  ('exports', 'farm'),
#  ('exports', 'to'),
#  ('exports', 'japan'),
#  ('to', 'farm'),
#  ('to', 'exports'),
#  ('to', 'japan'),
#  ('to', 'a'),
#  ('japan', 'exports'),
#  ('japan', 'to'),
#  ('japan', 'a'),
#  ('japan', 'senior'),
#  ('a', 'to'),
#  ('a', 'japan'),
#  ('a', 'senior'),
#  ('a', 'ministry'),
#  ('senior', 'japan'),
#  ('senior', 'a'),
#  ('senior', 'ministry'),
#  ('senior', 'official'),
#  ('ministry', 'a'),
#  ('ministry', 'senior'),
#  ('ministry', 'official'),
#  ('ministry', 'said'),
#  ('official', 'senior'),
#  ('official', 'ministry'),
#  ('official', 'said'),
#  ('official', 'imports'),
#  ('said', 'ministry'),
#  ('said', 'official'),
#  ('said', 'imports'),
#  ('said', 'from'),
#  ('imports', 'official'),
#  ('imports', 'said'),
#  ('imports', 'from'),
#  ('imports', 'the'),
#  ('from', 'said'),
#  ('from', 'imports'),
#  ('from', 'the'),
#  ('from', 'u'),
#  ('the', 'imports'),
#  ('the', 'from'),
#  ('the', 'u'),
#  ('the', 's'),
#  ('u', 'from'),
#  ('u', 'the'),
#  ('u', 's'),
#  ('u', 'would'),
#  ('s', 'the'),
#  ('s', 'u'),
#  ('s', 'would'),
#  ('s', 'drop'),
#  ('would', 'u'),
#  ('would', 's'),
#  ('would', 'drop'),
#  ('would', 'due'),
#  ('drop', 's'),
#  ('drop', 'would'),
#  ('drop', 'due'),
#  ('drop', 'to'),
#  ('due', 'would'),
#  ('due', 'drop'),
#  ('due', 'to'),
#  ('due', 'active'),
#  ('to', 'drop'),
#  ('to', 'due'),
#  ('to', 'active'),
#  ('to', 'sales'),
#  ('active', 'due'),
#  ('active', 'to'),
#  ('active', 'sales'),
#  ('active', 'drives'),
#  ('sales', 'to'),
#  ('sales', 'active'),
#  ('sales', 'drives'),
#  ('sales', 'by'),
#  ('drives', 'active'),
#  ('drives', 'sales'),
#  ('drives', 'by'),
#  ('drives', 'other'),
#  ('by', 'sales'),
#  ('by', 'drives'),
#  ('by', 'other'),
#  ('by', 'suppliers'),
#  ('other', 'drives'),
#  ('other', 'by'),
#  ('other', 'suppliers'),
#  ('other', 'the'),
#  ('suppliers', 'by'),
#  ('suppliers', 'other'),
#  ('suppliers', 'the'),
#  ('suppliers', 'official'),
#  ('the', 'other'),
#  ('the', 'suppliers'),
#  ('the', 'official'),
#  ('the', 'who'),
#  ('official', 'suppliers'),
#  ('official', 'the'),
#  ('official', 'who'),
#  ('official', 'declined'),
#  ('who', 'the'),
#  ('who', 'official'),
#  ('who', 'declined'),
#  ('who', 'to'),
#  ('declined', 'official'),
#  ('declined', 'who'),
#  ('declined', 'to'),
#  ('declined', 'be'),
#  ('to', 'who'),
#  ('to', 'declined'),
#  ('to', 'be'),
#  ('to', 'named'),
#  ('be', 'declined'),
#  ('be', 'to'),
#  ('be', 'named'),
#  ('be', 'said'),
#  ('named', 'to'),
#  ('named', 'be'),
#  ('named', 'said'),
#  ('named', 'japan'),
#  ('said', 'be'),
#  ('said', 'named'),
#  ('said', 'japan'),
#  ('said', 'is'),
#  ('japan', 'named'),
#  ('japan', 'said'),
#  ('japan', 'is'),
#  ('japan', 'the'),
#  ('is', 'said'),
#  ('is', 'japan'),
#  ('is', 'the'),
#  ('is', 'largest'),
#  ('the', 'japan'),
#  ('the', 'is'),
#  ('the', 'largest'),
#  ('the', 'customer'),
#  ('largest', 'is'),
#  ('largest', 'the'),
#  ('largest', 'customer'),
#  ('largest', 'for'),
#  ('customer', 'the'),
#  ('customer', 'largest'),
#  ('customer', 'for'),
#  ('customer', 'u'),
#  ('for', 'largest'),
#  ('for', 'customer'),
#  ('for', 'u'),
#  ('for', 's'),
#  ('u', 'customer'),
#  ('u', 'for'),
#  ('u', 's'),
#  ('u', 'farm'),
#  ('s', 'for'),
#  ('s', 'u'),
#  ('s', 'farm'),
#  ('s', 'products'),
#  ('farm', 'u'),
#  ('farm', 's'),
#  ('farm', 'products'),
#  ('farm', 'and'),
#  ('products', 's'),
#  ('products', 'farm'),
#  ('products', 'and'),
#  ('products', 'it'),
#  ('and', 'farm'),
#  ('and', 'products'),
#  ('and', 'it'),
#  ('and', 'is'),
#  ('it', 'products'),
#  ('it', 'and'),
#  ('it', 'is'),
#  ('it', 'not'),
#  ('is', 'and'),
#  ('is', 'it'),
#  ('is', 'not'),
#  ('is', 'reasonable'),
#  ('not', 'it'),
#  ('not', 'is'),
#  ('not', 'reasonable'),
#  ('not', 'for'),
#  ('reasonable', 'is'),
#  ('reasonable', 'not'),
#  ('reasonable', 'for'),
#  ('reasonable', 'the'),
#  ('for', 'not'),
#  ('for', 'reasonable'),
#  ('for', 'the'),
#  ('for', 'u'),
#  ('the', 'reasonable'),
#  ('the', 'for'),
#  ('the', 'u'),
#  ('the', 's'),
#  ('u', 'for'),
#  ('u', 'the'),
#  ('u', 's'),
#  ('u', 'to'),
#  ('s', 'the'),
#  ('s', 'u'),
#  ('s', 'to'),
#  ('s', 'demand'),
#  ('to', 'u'),
#  ('to', 's'),
#  ('to', 'demand'),
#  ('to', 'japan'),
#  ('demand', 's'),
#  ('demand', 'to'),
#  ('demand', 'japan'),
#  ('demand', 'liberalise'),
#  ('japan', 'to'),
#  ('japan', 'demand'),
#  ('japan', 'liberalise'),
#  ('japan', 'its'),
#  ('liberalise', 'demand'),
#  ('liberalise', 'japan'),
#  ('liberalise', 'its'),
#  ('liberalise', 'farm'),
#  ('its', 'japan'),
#  ('its', 'liberalise'),
#  ('its', 'farm'),
#  ('its', 'import'),
#  ('farm', 'liberalise'),
#  ('farm', 'its'),
#  ('farm', 'import'),
#  ('farm', 'market'),
#  ('import', 'its'),
#  ('import', 'farm'),
#  ('import', 'market'),
#  ('import', 'he'),
#  ('market', 'farm'),
#  ('market', 'import'),
#  ('market', 'he'),
#  ('market', 'said'),
#  ('he', 'import'),
#  ('he', 'market'),
#  ('he', 'said'),
#  ('he', 'agriculture'),
#  ('said', 'market'),
#  ('said', 'he'),
#  ('said', 'agriculture'),
#  ('said', 'minister'),
#  ('agriculture', 'he'),
#  ('agriculture', 'said'),
#  ('agriculture', 'minister'),
#  ('agriculture', 'mutsuki'),
#  ('minister', 'said'),
#  ('minister', 'agriculture'),
#  ('minister', 'mutsuki'),
#  ('minister', 'kato'),
#  ('mutsuki', 'agriculture'),
#  ('mutsuki', 'minister'),
#  ('mutsuki', 'kato'),
#  ('mutsuki', 'has'),
#  ('kato', 'minister'),
#  ('kato', 'mutsuki'),
#  ('kato', 'has'),
#  ('kato', 'said'),
#  ('has', 'mutsuki'),
#  ('has', 'kato'),
#  ('has', 'said'),
#  ('has', 'if'),
#  ('said', 'kato'),
#  ('said', 'has'),
#  ('said', 'if'),
#  ('said', 'the'),
#  ('if', 'has'),
#  ('if', 'said'),
#  ('if', 'the'),
#  ('if', 'u'),
#  ('the', 'said'),
#  ('the', 'if'),
#  ('the', 'u'),
#  ('the', 's'),
#  ('u', 'if'),
#  ('u', 'the'),
#  ('u', 's'),
#  ('u', 'insists'),
#  ('s', 'the'),
#  ('s', 'u'),
#  ('s', 'insists'),
#  ('s', 'japan'),
#  ('insists', 'u'),
#  ('insists', 's'),
#  ('insists', 'japan'),
#  ('insists', 'open'),
#  ('japan', 's'),
#  ('japan', 'insists'),
#  ('japan', 'open'),
#  ('japan', 'its'),
#  ('open', 'insists'),
#  ('open', 'japan'),
#  ('open', 'its'),
#  ('open', 'protected'),
#  ('its', 'japan'),
#  ('its', 'open'),
#  ('its', 'protected'),
#  ('its', 'rice'),
#  ('protected', 'open'),
#  ('protected', 'its'),
#  ('protected', 'rice'),
#  ('protected', 'market'),
#  ('rice', 'its'),
#  ('rice', 'protected'),
#  ('rice', 'market'),
#  ('rice', 'it'),
#  ('market', 'protected'),
#  ('market', 'rice'),
#  ('market', 'it'),
#  ('market', 'will'),
#  ('it', 'rice'),
#  ('it', 'market'),
#  ('it', 'will'),
#  ('it', 'also'),
#  ('will', 'market'),
#  ('will', 'it'),
#  ('will', 'also'),
#  ('will', 'open'),
#  ('also', 'it'),
#  ('also', 'will'),
#  ('also', 'open'),
#  ('also', 'its'),
#  ('open', 'will'),
#  ('open', 'also'),
#  ('open', 'its'),
#  ('open', 'wheat'),
#  ('its', 'also'),
#  ('its', 'open'),
#  ('its', 'wheat'),
#  ('its', 'market'),
#  ('wheat', 'open'),
#  ('wheat', 'its'),
#  ('wheat', 'market'),
#  ('wheat', 'where'),
#  ('market', 'its'),
#  ('market', 'wheat'),
#  ('market', 'where'),
#  ('market', 'volume'),
#  ('where', 'wheat'),
#  ('where', 'market'),
#  ('where', 'volume'),
#  ('where', 'and'),
#  ('volume', 'market'),
#  ('volume', 'where'),
#  ('volume', 'and'),
#  ('volume', 'origin'),
#  ('and', 'where'),
#  ('and', 'volume'),
#  ('and', 'origin'),
#  ('and', 'are'),
#  ('origin', 'volume'),
#  ('origin', 'and'),
#  ('origin', 'are'),
#  ('origin', 'regulated'),
#  ('are', 'and'),
#  ('are', 'origin'),
#  ('are', 'regulated'),
#  ('are', 'to'),
#  ('regulated', 'origin'),
#  ('regulated', 'are'),
#  ('regulated', 'to'),
#  ('regulated', 'protect'),
#  ('to', 'are'),
#  ('to', 'regulated'),
#  ('to', 'protect'),
#  ('to', 'local'),
#  ('protect', 'regulated'),
#  ('protect', 'to'),
#  ('protect', 'local'),
#  ('protect', 'farmers'),
#  ('local', 'to'),
#  ('local', 'protect'),
#  ('local', 'farmers'),
#  ('local', 'australia'),
#  ('farmers', 'protect'),
#  ('farmers', 'local'),
#  ('farmers', 'australia'),
#  ('farmers', 'and'),
#  ('australia', 'local'),
#  ('australia', 'farmers'),
#  ('australia', 'and'),
#  ('australia', 'canada'),
#  ('and', 'farmers'),
#  ('and', 'australia'),
#  ('and', 'canada'),
#  ('and', 'could'),
#  ('canada', 'australia'),
#  ('canada', 'and'),
#  ('canada', 'could'),
#  ('canada', 'then'),
#  ('could', 'and'),
#  ('could', 'canada'),
#  ('could', 'then'),
#  ('could', 'increase'),
#  ('then', 'canada'),
#  ('then', 'could'),
#  ('then', 'increase'),
#  ('then', 'their'),
#  ('increase', 'could'),
#  ('increase', 'then'),
#  ('increase', 'their'),
#  ('increase', 'wheat'),
#  ('their', 'then'),
#  ('their', 'increase'),
#  ('their', 'wheat'),
#  ('their', 'exports'),
#  ('wheat', 'increase'),
#  ('wheat', 'their'),
#  ('wheat', 'exports'),
#  ('wheat', 'as'),
#  ('exports', 'their'),
#  ('exports', 'wheat'),
#  ('exports', 'as'),
#  ('exports', 'they'),
#  ('as', 'wheat'),
#  ('as', 'exports'),
#  ('as', 'they'),
#  ('as', 'are'),
#  ('they', 'exports'),
#  ('they', 'as'),
#  ('they', 'are'),
#  ('they', 'more'),
#  ('are', 'as'),
#  ('are', 'they'),
#  ('are', 'more'),
#  ('are', 'competitive'),
#  ('more', 'they'),
#  ('more', 'are'),
#  ('more', 'competitive'),
#  ('more', 'than'),
#  ('competitive', 'are'),
#  ('competitive', 'more'),
#  ('competitive', 'than'),
#  ('competitive', 'the'),
#  ('than', 'more'),
#  ('than', 'competitive'),
#  ('than', 'the'),
#  ('than', 'u'),
#  ('the', 'competitive'),
#  ('the', 'than'),
#  ('the', 'u'),
#  ('the', 's'),
#  ('u', 'than'),
#  ('u', 'the'),
#  ('u', 's'),
#  ('u', 'he'),
#  ('s', 'the'),
#  ('s', 'u'),
#  ('s', 'he'),
#  ('s', 'said'),
#  ('he', 'u'),
#  ('he', 's'),
#  ('he', 'said'),
#  ('he', 'end'),
#  ('said', 's'),
#  ('said', 'he'),
#  ('said', 'end'),
#  ('said', 'users'),
#  ('end', 'he'),
#  ('end', 'said'),
#  ('end', 'users'),
#  ('end', 'would'),
#  ('users', 'said'),
#  ('users', 'end'),
#  ('users', 'would'),
#  ('users', 'also'),
#  ('would', 'end'),
#  ('would', 'users'),
#  ('would', 'also'),
#  ('would', 'buy'),
#  ('also', 'users'),
#  ('also', 'would'),
#  ('also', 'buy'),
#  ('also', 'other'),
#  ('buy', 'would'),
#  ('buy', 'also'),
#  ('buy', 'other'),
#  ('buy', 'origins'),
#  ('other', 'also'),
#  ('other', 'buy'),
#  ('other', 'origins'),
#  ('other', 'grain'),
#  ('origins', 'buy'),
#  ('origins', 'other'),
#  ('origins', 'grain'),
#  ('origins', 'traders'),
#  ('grain', 'other'),
#  ('grain', 'origins'),
#  ('grain', 'traders'),
#  ('grain', 'said'),
#  ('traders', 'origins'),
#  ('traders', 'grain'),
#  ('traders', 'said'),
#  ('traders', 'u'),
#  ('said', 'grain'),
#  ('said', 'traders'),
#  ('said', 'u'),
#  ('said', 's'),
#  ('u', 'traders'),
#  ('u', 'said'),
#  ('u', 's'),
#  ('u', 'agriculture'),
#  ('s', 'said'),
#  ('s', 'u'),
#  ('s', 'agriculture'),
#  ('s', 'secretary'),
#  ('agriculture', 'u'),
#  ('agriculture', 's'),
#  ('agriculture', 'secretary'),
#  ('agriculture', 'richard'),
#  ('secretary', 's'),
#  ('secretary', 'agriculture'),
#  ('secretary', 'richard'),
#  ('secretary', 'lyng'),
#  ('richard', 'agriculture'),
#  ('richard', 'secretary'),
#  ('richard', 'lyng'),
#  ('richard', 'who'),
#  ('lyng', 'secretary'),
#  ('lyng', 'richard'),
#  ('lyng', 'who'),
#  ('lyng', 'is'),
#  ('who', 'richard'),
#  ('who', 'lyng'),
#  ('who', 'is'),
#  ('who', 'due'),
#  ('is', 'lyng'),
#  ('is', 'who'),
#  ('is', 'due'),
#  ('is', 'to'),
#  ('due', 'who'),
#  ('due', 'is'),
#  ('due', 'to'),
#  ('due', 'visit'),
#  ('to', 'is'),
#  ('to', 'due'),
#  ('to', 'visit'),
#  ('to', 'japan'),
#  ('visit', 'due'),
#  ('visit', 'to'),
#  ('visit', 'japan'),
#  ('visit', 'for'),
#  ('japan', 'to'),
#  ('japan', 'visit'),
#  ('japan', 'for'),
#  ('japan', 'talks'),
#  ('for', 'visit'),
#  ('for', 'japan'),
#  ('for', 'talks'),
#  ('for', 'between'),
#  ('talks', 'japan'),
#  ('talks', 'for'),
#  ('talks', 'between'),
#  ('talks', 'april'),
#  ('between', 'for'),
#  ('between', 'talks'),
#  ('between', 'april'),
#  ('between', 'has'),
#  ('april', 'talks'),
#  ('april', 'between'),
#  ('april', 'has'),
#  ('april', 'said'),
#  ('has', 'between'),
#  ('has', 'april'),
#  ('has', 'said'),
#  ('has', 'he'),
#  ('said', 'april'),
#  ('said', 'has'),
#  ('said', 'he'),
#  ('said', 'will'),
#  ('he', 'has'),
#  ('he', 'said'),
#  ('he', 'will'),
#  ('he', 'ask'),
#  ('will', 'said'),
#  ('will', 'he'),
#  ('will', 'ask'),
#  ('will', 'japan'),
#  ('ask', 'he'),
#  ('ask', 'will'),
#  ('ask', 'japan'),
#  ('ask', 'to'),
#  ('japan', 'will'),
#  ('japan', 'ask'),
#  ('japan', 'to'),
#  ('japan', 'offer'),
#  ('to', 'ask'),
#  ('to', 'japan'),
#  ('to', 'offer'),
#  ('to', 'a'),
#  ('offer', 'japan'),
#  ('offer', 'to'),
#  ('offer', 'a'),
#  ('offer', 'share'),
#  ('a', 'to'),
#  ('a', 'offer'),
#  ('a', 'share'),
#  ('a', 'of'),
#  ('share', 'offer'),
#  ('share', 'a'),
#  ('share', 'of'),
#  ('share', 'its'),
#  ('of', 'a'),
#  ('of', 'share'),
#  ('of', 'its'),
#  ('of', 'rice'),
#  ('its', 'share'),
#  ('its', 'of'),
#  ('its', 'rice'),
#  ('its', 'market'),
#  ('rice', 'of'),
#  ('rice', 'its'),
#  ('rice', 'market'),
#  ('rice', 'to'),
#  ('market', 'its'),
#  ('market', 'rice'),
#  ('market', 'to'),
#  ('market', 'u'),
#  ('to', 'rice'),
#  ('to', 'market'),
#  ('to', 'u'),
#  ('to', 's'),
#  ('u', 'market'),
#  ('u', 'to'),
#  ('u', 's'),
#  ('u', 'suppliers'),
#  ('s', 'to'),
#  ('s', 'u'),
#  ('s', 'suppliers'),
#  ('s', 'and'),
#  ('suppliers', 'u'),
#  ('suppliers', 's'),
#  ('suppliers', 'and'),
#  ('suppliers', 'remove'),
#  ('and', 's'),
#  ('and', 'suppliers'),
#  ('and', 'remove'),
#  ('and', 'quotas'),
#  ('remove', 'suppliers'),
#  ('remove', 'and'),
#  ('remove', 'quotas'),
#  ('remove', 'on'),
#  ('quotas', 'and'),
#  ('quotas', 'remove'),
#  ('quotas', 'on'),
#  ('quotas', 'u'),
#  ('on', 'remove'),
#  ('on', 'quotas'),
#  ('on', 'u'),
#  ('on', 's'),
#  ('u', 'quotas'),
#  ('u', 'on'),
#  ('u', 's'),
#  ('u', 'beef'),
#  ('s', 'on'),
#  ('s', 'u'),
#  ('s', 'beef'),
#  ('s', 'and'),
#  ('beef', 'u'),
#  ('beef', 's'),
#  ('beef', 'and'),
#  ('beef', 'citrus'),
#  ('and', 's'),
#  ('and', 'beef'),
#  ('and', 'citrus'),
#  ('and', 'imports'),
#  ('citrus', 'beef'),
#  ('citrus', 'and'),
#  ('citrus', 'imports'),
#  ('citrus', 'other'),
#  ('imports', 'and'),
#  ('imports', 'citrus'),
#  ('imports', 'other'),
#  ('imports', 'countries'),
#  ('other', 'citrus'),
#  ('other', 'imports'),
#  ('other', 'countries'),
#  ('other', 'are'),
#  ('countries', 'imports'),
#  ('countries', 'other'),
#  ('countries', 'are'),
#  ('countries', 'already'),
#  ('are', 'other'),
#  ('are', 'countries'),
#  ('are', 'already'),
#  ('are', 'cutting'),
#  ('already', 'countries'),
#  ('already', 'are'),
#  ('already', 'cutting'),
#  ('already', 'into'),
#  ('cutting', 'are'),
#  ('cutting', 'already'),
#  ('cutting', 'into'),
#  ('cutting', 'the'),
#  ('into', 'already'),
#  ('into', 'cutting'),
#  ('into', 'the'),
#  ('into', 'u'),
#  ('the', 'cutting'),
#  ('the', 'into'),
#  ('the', 'u'),
#  ('the', 's'),
#  ('u', 'into'),
#  ('u', 'the'),
#  ('u', 's'),
#  ('u', 'market'),
#  ('s', 'the'),
#  ('s', 'u'),
#  ('s', 'market'),
#  ('s', 'share'),
#  ('market', 'u'),
#  ('market', 's'),
#  ('market', 'share'),
#  ('market', 'here'),
#  ('share', 's'),
#  ('share', 'market'),
#  ('share', 'here'),
#  ('share', 'australia'),
#  ('here', 'market'),
#  ('here', 'share'),
#  ('here', 'australia'),
#  ('here', 'the'),
#  ('australia', 'share'),
#  ('australia', 'here'),
#  ('australia', 'the'),
#  ('australia', 'largest'),
#  ('the', 'here'),
#  ('the', 'australia'),
#  ('the', 'largest'),
#  ('the', 'beef'),
#  ('largest', 'australia'),
#  ('largest', 'the'),
#  ('largest', 'beef'),
#  ('largest', 'supplier'),
#  ('beef', 'the'),
#  ('beef', 'largest'),
#  ('beef', 'supplier'),
#  ('beef', 'to'),
#  ('supplier', 'largest'),
#  ('supplier', 'beef'),
#  ('supplier', 'to'),
#  ('supplier', 'japan'),
#  ('to', 'beef'),
#  ('to', 'supplier'),
#  ('to', 'japan'),
#  ('to', 'has'),
#  ('japan', 'supplier'),
#  ('japan', 'to'),
#  ('japan', 'has'),
#  ('japan', 'been'),
#  ('has', 'to'),
#  ('has', 'japan'),
#  ('has', 'been'),
#  ('has', 'trying'),
#  ('been', 'japan'),
#  ('been', 'has'),
#  ('been', 'trying'),
#  ('been', 'to'),
#  ('trying', 'has'),
#  ('trying', 'been'),
#  ('trying', 'to'),
#  ('trying', 'boost'),
#  ('to', 'been'),
#  ('to', 'trying'),
#  ('to', 'boost'),
#  ('to', 'exports'),
#  ('boost', 'trying'),
#  ('boost', 'to'),
#  ('boost', 'exports'),
#  ('boost', 'prior'),
#  ('exports', 'to'),
#  ('exports', 'boost'),
#  ('exports', 'prior'),
#  ('exports', 'to'),
#  ('prior', 'boost'),
#  ('prior', 'exports'),
#  ('prior', 'to'),
#  ('prior', 'the'),
#  ('to', 'exports'),
#  ('to', 'prior'),
#  ('to', 'the'),
#  ('to', 'expiry'),
#  ('the', 'prior'),
#  ('the', 'to'),
#  ('the', 'expiry'),
#  ('the', 'of'),
#  ('expiry', 'to'),
#  ('expiry', 'the'),
#  ('expiry', 'of'),
#  ('expiry', 'a'),
#  ('of', 'the'),
#  ('of', 'expiry'),
#  ('of', 'a'),
#  ('of', 'four'),
#  ('a', 'expiry'),
#  ('a', 'of'),
#  ('a', 'four'),
#  ('a', 'year'),
#  ('four', 'of'),
#  ('four', 'a'),
#  ('four', 'year'),
#  ('four', 'beef'),
#  ('year', 'a'),
#  ('year', 'four'),
#  ('year', 'beef'),
#  ('year', 'accord'),
#  ('beef', 'four'),
#  ('beef', 'year'),
#  ('beef', 'accord'),
#  ('beef', 'next'),
#  ('accord', 'year'),
#  ('accord', 'beef'),
#  ('accord', 'next'),
#  ('accord', 'march'),
#  ('next', 'beef'),
#  ('next', 'accord'),
#  ('next', 'march'),
#  ('next', 'imports'),
#  ('march', 'accord'),
#  ('march', 'next'),
#  ('march', 'imports'),
#  ('march', 'of'),
#  ('imports', 'next'),
#  ('imports', 'march'),
#  ('imports', 'of'),
#  ('imports', 'u'),
#  ('of', 'march'),
#  ('of', 'imports'),
#  ('of', 'u'),
#  ('of', 's'),
#  ('u', 'imports'),
#  ('u', 'of'),
#  ('u', 's'),
#  ('u', 'corn'),
#  ...]

# %%
# Count the co-occurrence of each skip-gram pair
X_ik_skipgrams = Counter(skip_grams)
X_ik_skipgrams
# Out:
# Counter({('the', 'of'): 222,
#          ('of', 'the'): 220,
#          ('the', 'to'): 151,
#          ('to', 'the'): 150,
#          ('the', 'said'): 149,
#          ('s', 'u'): 145,
#          ('u', 's'): 144,
#          ('said', 'the'): 143,
#          ('the', 'in'): 110,
#          ('in', 'the'): 109,
#          ('the', 's'): 87,
#          ('s', 'the'): 87,
#          ('and', 'the'): 85,
#          ('the', 'and'): 85,
#          ('the', 'u'): 68,
#          ('u', 'the'): 68,
#          ('a', 'of'): 52,
#          ('of', 'a'): 52,
#          ('the', 'ec'): 51,
#          ('ec', 'the'): 51,
#          ('for', 'the'): 49,
#          ('the', 'for'): 49,
#          ('on', 'the'): 47,
#          ('the', 'on'): 47,
#          ('the', 'department'): 45,
#          ('to', 'a'): 44,
#          ('a', 'to'): 44,
#          ('to', 'be'): 43,
#          ('be', 'to'): 42,
#          ('a', 'year'): 42,
#          ('of', 'and'): 42,
#          ('and', 'of'): 42,
#          ('at', 'the'): 41,
#          ('the', 'at'): 41,
#          ('department', 'the'): 41,
#          ('a', 'ago'): 40,
#          ('by', 'the'): 38,
#          ('the', 'by'): 38,
#          ('that', 'the'): 36,
#          ('the', 'that'): 36,
#          ('department', 'said'): 36,
#          ('said', 'department'): 36,
#          ('and', 'a'): 36,
#          ('a', 'and'): 36,
#          ('said', 'it'): 36,
#          ('it', 'said'): 36,
#          ('is', 'the'): 35,
#          ('the', 'is'): 35,
#          ('s', 'agriculture'): 34,
#          ('agriculture', 's'): 34,
#          ('year', 'a'): 34,
#          ('the', 'the'): 34,
#          ('will', 'be'): 33,
#          ('be', 'will'): 32,
#          ('ago', 'a'): 32,
#          ('from', 'the'): 31,
#          ('the', 'from'): 31,
#          ('mln', 'lbs'): 31,
#          ('lbs', 'mln'): 31,
#          ('with', 'the'): 30,
#          ('the', 'with'): 30,
#          ('agriculture', 'u'): 29,
#          ('year', 'the'): 29,
#          ('the', 'year'): 29,
#          ('u', 'agriculture'): 28,
#          ('agriculture', 'department'): 28,
#          ('department', 'agriculture'): 28,
#          ('mln', 'dlrs'): 28,
#          ('dlrs', 'mln'): 28,
#          ('mln', 'in'): 28,
#          ('in', 'mln'): 28,
#          ('of', 's'): 27,
#          ('s', 'of'): 27,
#          ('will', 'the'): 27,
#          ('the', 'will'): 27,
#          ('and', 'to'): 27,
#          ('to', 'and'): 27,
#          ('s', 'department'): 27,
#          ('department', 's'): 27,
#          ('head', 'of'): 27,
#          ('of', 'head'): 27,
#          ('mln', 'to'): 27,
#          ('to', 'mln'): 27,
#          ('is', 'to'): 26,
#          ('to', 'is'): 26,
#          ('in', 'and'): 26,
#          ('and', 'in'): 26,
#          ('in', 'to'): 26,
#          ('to', 'in'): 26,
#          ('to', 's'): 25,
#          ('meat', 'and'): 25,
#          ('and', 'meat'): 25,
#          ('of', 'cattle'): 25,
#          ('cattle', 'of'): 25,
#          ('the', 'meat'): 25,
#          ('meat', 'the'): 25,
#          ('and', 'year'): 25,
#          ('at', 'to'): 24,
#          ('tonnes', 'of'): 24,
#          ('tonnes', 'in'): 24,
#          ('in', 'tonnes'): 24,
#          ('he', 'said'): 23,
#          ('said', 'he'): 23,
#          ('to', 'at'): 23,
#          ('of', 'tonnes'): 23,
#          ('under', 'the'): 23,
#          ('to', 'tonnes'): 23,
#          ('tonnes', 'to'): 23,
#          ('s', 'to'): 22,
#          ('in', 'a'): 22,
#          ('a', 'in'): 22,
#          ('year', 'ago'): 22,
#          ('of', 'of'): 22,
#          ('have', 'been'): 22,
#          ('been', 'have'): 22,
#          ('the', 'under'): 22,
#          ('the', 'pork'): 22,
#          ('pork', 'the'): 22,
#          ('in', 'in'): 22,
#          ('beef', 'and'): 21,
#          ('and', 'beef'): 21,
#          ('has', 'been'): 21,
#          ('been', 'has'): 21,
#          ('meat', 's'): 21,
#          ('to', 'head'): 21,
#          ('head', 'to'): 21,
#          ('ago', 'year'): 21,
#          ('and', 'mln'): 21,
#          ('mln', 'and'): 21,
#          ('mln', 'from'): 21,
#          ('to', 'of'): 21,
#          ('of', 'to'): 21,
#          ('trade', 'the'): 20,
#          ('the', 'trade'): 20,
#          ('cattle', 'slaughter'): 20,
#          ('slaughter', 'cattle'): 20,
#          ('about', 'to'): 20,
#          ('from', 'mln'): 20,
#          ('dairy', 'cattle'): 20,
#          ('cattle', 'dairy'): 20,
#          ('said', 'agriculture'): 19,
#          ('agriculture', 'said'): 19,
#          ('of', 'u'): 19,
#          ('u', 'of'): 19,
#          ('officials', 'said'): 19,
#          ('said', 'officials'): 19,
#          ('the', 'market'): 19,
#          ('market', 'the'): 19,
#          ('the', 'united'): 19,
#          ('of', 'beef'): 19,
#          ('beef', 'of'): 19,
#          ('about', 'head'): 19,
#          ('to', 'about'): 19,
#          ('week', 'and'): 19,
#          ('ago', 'and'): 19,
#          ('and', 'week'): 19,
#          ('and', 'ago'): 19,
#          ('dlrs', 'to'): 19,
#          ('to', 'dlrs'): 19,
#          ('a', 'for'): 18,
#          ('for', 'a'): 18,
#          ('united', 'the'): 18,
#          ('the', 'would'): 18,
#          ('would', 'the'): 18,
#          ('meat', 'u'): 18,
#          ('of', 'for'): 18,
#          ('for', 'of'): 18,
#          ('pct', 'of'): 18,
#          ('of', 'pct'): 18,
#          ('and', 'and'): 18,
#          ('to', 'cattle'): 18,
#          ('report', 'the'): 18,
#          ('the', 'report'): 18,
#          ('cattle', 'the'): 18,
#          ('the', 'cattle'): 18,
#          ('head', 'about'): 18,
#          ('at', 'about'): 18,
#          ('about', 'at'): 18,
#          ('week', 'ago'): 18,
#          ('ago', 'week'): 18,
#          ('said', 'said'): 18,
#          ('program', 'the'): 18,
#          ('the', 'program'): 18,
#          ('the', 'government'): 17,
#          ('government', 'the'): 17,
#          ('is', 'a'): 17,
#          ('a', 'is'): 17,
#          ('s', 'meat'): 17,
#          ('the', 'community'): 17,
#          ('community', 'the'): 17,
#          ('cattle', 'for'): 17,
#          ('for', 'cattle'): 17,
#          ('at', 'a'): 17,
#          ('a', 'at'): 17,
#          ('cattle', 'to'): 17,
#          ('s', 'japan'): 16,
#          ('the', 'beef'): 16,
#          ('beef', 'the'): 16,
#          ('beef', 'to'): 16,
#          ('to', 'beef'): 16,
#          ('the', 'same'): 16,
#          ('same', 'the'): 16,
#          ('the', 'states'): 16,
#          ('the', 'national'): 16,
#          ('national', 'the'): 16,
#          ('a', 'on'): 16,
#          ('on', 'a'): 16,
#          ('to', 'versus'): 16,
#          ('head', 'versus'): 16,
#          ('head', 'week'): 16,
#          ('versus', 'to'): 16,
#          ('versus', 'head'): 16,
#          ('versus', 'week'): 16,
#          ('versus', 'ago'): 16,
#          ('week', 'head'): 16,
#          ('week', 'versus'): 16,
#          ('ago', 'versus'): 16,
#          ('year', 'and'): 16,
#          ('european', 'community'): 16,
#          ('community', 'european'): 16,
#          ('to', 'to'): 16,
#          ('in', 'from'): 16,
#          ('from', 'in'): 16,
#          ('japan', 's'): 15,
#          ('s', 'and'): 15,
#          ('and', 's'): 15,
#          ('states', 'the'): 15,
#          ('the', 'american'): 15,
#          ('american', 'the'): 15,
#          ('was', 'the'): 15,
#          ('the', 'was'): 15,
#          ('in', 'for'): 15,
#          ('for', 'in'): 15,
#          ('the', 'markets'): 15,
#          ('markets', 'the'): 15,
#          ('the', 'union'): 15,
#          ('union', 'the'): 15,
#          ('cattle', 'are'): 15,
#          ('are', 'cattle'): 15,
#          ('the', 'plant'): 15,
#          ('plant', 'the'): 15,
#          ('in', 'february'): 15,
#          ('february', 'in'): 15,
#          ('expected', 'to'): 14,
#          ('to', 'expected'): 14,
#          ('new', 'the'): 14,
#          ('the', 'new'): 14,
#          ('on', 'and'): 14,
#          ('and', 'on'): 14,
#          ('a', 'that'): 14,
#          ('that', 'a'): 14,
#          ('u', 'meat'): 14,
#          ('agriculture', 'the'): 14,
#          ('the', 'agriculture'): 14,
#          ('mln', 'of'): 14,
#          ('cattle', 'and'): 14,
#          ('said', 'in'): 14,
#          ('in', 'said'): 14,
#          ('sources', 'said'): 14,
#          ('said', 'sources'): 14,
#          ('mercantile', 'exchange'): 14,
#          ('exchange', 'mercantile'): 14,
#          ('a', 'from'): 14,
#          ('from', 'a'): 14,
#          ('to', 'from'): 14,
#          ('officials', 'the'): 14,
#          ('the', 'officials'): 14,
#          ('mln', 'tonnes'): 14,
#          ('tonnes', 'mln'): 14,
#          ('on', 'to'): 14,
#          ('of', 'dairy'): 14,
#          ('dairy', 'of'): 14,
#          ('pct', 'the'): 14,
#          ('the', 'pct'): 14,
#          ('to', 'it'): 14,
#          ('it', 'to'): 14,
#          ('with', 'in'): 14,
#          ('in', 'with'): 14,
#          ('iowa', 'beef'): 14,
#          ('beef', 'iowa'): 14,
#          ('to', 'japan'): 13,
#          ('japan', 'to'): 13,
#          ('due', 'to'): 13,
#          ('to', 'due'): 13,
#          ('to', 'u'): 13,
#          ('s', 'beef'): 13,
#          ('beef', 's'): 13,
#          ('and', 'trade'): 13,
#          ('trade', 'and'): 13,
#          ('the', 'farm'): 13,
#          ('farm', 'the'): 13,
#          ('meat', 'to'): 13,
#          ('to', 'meat'): 13,
#          ('food', 'and'): 13,
#          ('and', 'food'): 13,
#          ('is', 'at'): 13,
#          ('at', 'is'): 13,
#          ('of', 'mln'): 13,
#          ('chicago', 'mercantile'): 13,
#          ('chicago', 'exchange'): 13,
#          ('mercantile', 'chicago'): 13,
#          ('exchange', 'chicago'): 13,
#          ('the', 'industry'): 13,
#          ('industry', 'the'): 13,
#          ('prices', 'the'): 13,
#          ('the', 'prices'): 13,
#          ('usda', 'the'): 13,
#          ('the', 'usda'): 13,
#          ('mln', 'the'): 13,
#          ('the', 'mln'): 13,
#          ('tonnes', 'from'): 13,
#          ('from', 'tonnes'): 13,
#          ('to', 'on'): 13,
#          ('head', 'dairy'): 13,
#          ('dairy', 'head'): 13,
#          ('was', 'to'): 13,
#          ('to', 'was'): 13,
#          ('beef', 'for'): 13,
#          ('for', 'beef'): 13,
#          ('mln', 'a'): 13,
#          ('a', 'mln'): 13,
#          ('in', 'was'): 13,
#          ('was', 'in'): 13,
#          ('the', 'period'): 13,
#          ('farmers', 'to'): 13,
#          ('to', 'farmers'): 13,
#          ('exports', 'to'): 12,
#          ('to', 'exports'): 12,
#          ('u', 'to'): 12,
#          ('are', 'to'): 12,
#          ('to', 'are'): 12,
#          ('this', 'year'): 12,
#          ('year', 'this'): 12,
#          ('united', 'states'): 12,
#          ('be', 'in'): 12,
#          ('in', 'be'): 12,
#          ('and', 'poultry'): 12,
#          ('poultry', 'and'): 12,
#          ('livestock', 'and'): 12,
#          ('and', 'livestock'): 12,
#          ('pork', 'and'): 12,
#          ('and', 'pork'): 12,
#          ('but', 'the'): 12,
#          ('the', 'but'): 12,
#          ('and', 'for'): 12,
#          ('for', 'and'): 12,
#          ('not', 'to'): 12,
#          ('to', 'not'): 12,
#          ('cattle', 'is'): 12,
#          ('is', 'cattle'): 12,
#          ('the', 'european'): 12,
#          ('european', 'the'): 12,
#          ('sources', 'the'): 12,
#          ('the', 'sources'): 12,
#          ('to', 'ec'): 12,
#          ('ec', 'to'): 12,
#          ('to', 'its'): 12,
#          ('its', 'to'): 12,
#          ('as', 'a'): 12,
#          ('a', 'as'): 12,
#          ('from', 'to'): 12,
#          ('the', 'month'): 12,
#          ('month', 'the'): 12,
#          ('they', 'said'): 12,
#          ('said', 'they'): 12,
#          ('tonnes', 'against'): 12,
#          ('against', 'tonnes'): 12,
#          ('as', 'as'): 12,
#          ('for', 'to'): 12,
#          ('to', 'for'): 12,
#          ('in', 'january'): 12,
#          ('january', 'in'): 12,
#          ('dakota', 'city'): 12,
#          ('city', 'dakota'): 12,
#          ('been', 'to'): 11,
#          ('to', 'been'): 11,
#          ('of', 'in'): 11,
#          ('in', 'of'): 11,
#          ('states', 'united'): 11,
#          ('would', 'be'): 11,
#          ('be', 'would'): 11,
#          ('of', 'meat'): 11,
#          ('meat', 'of'): 11,
#          ('would', 'a'): 11,
#          ('a', 'would'): 11,
#          ('united', 'and'): 11,
#          ('and', 'united'): 11,
#          ('slaughter', 'and'): 11,
#          ('floor', 'traders'): 11,
#          ('traders', 'floor'): 11,
#          ('s', 'slaughter'): 11,
#          ('slaughter', 's'): 11,
#          ('beef', 'in'): 11,
#          ('in', 'beef'): 11,
#          ('because', 'of'): 11,
#          ('of', 'because'): 11,
#          ('export', 'the'): 11,
#          ('the', 'export'): 11,
#          ('s', 'trade'): 11,
#          ('trade', 's'): 11,
#          ('the', 'administration'): 11,
#          ('administration', 'the'): 11,
#          ('have', 'to'): 11,
#          ('to', 'have'): 11,
#          ('the', 'commission'): 11,
#          ('commission', 'the'): 11,
#          ('by', 'a'): 11,
#          ('a', 'by'): 11,
#          ('that', 'and'): 11,
#          ('and', 'that'): 11,
#          ('period', 'the'): 11,
#          ('lbs', 'in'): 11,
#          ('in', 'lbs'): 11,
#          ('beef', 'import'): 11,
#          ('import', 'beef'): 11,
#          ('agriculture', 'ministry'): 10,
#          ('ministry', 'agriculture'): 10,
#          ('traders', 'said'): 10,
#          ('said', 'traders'): 10,
#          ('from', 'and'): 10,
#          ('and', 'from'): 10,
#          ('an', 'of'): 10,
#          ('of', 'an'): 10,
#          ('usda', 'said'): 10,
#          ('said', 'usda'): 10,
#          ('end', 'the'): 10,
#          ('the', 'end'): 10,
#          ('to', 'pct'): 10,
#          ('pct', 'to'): 10,
#          ('said', 'a'): 10,
#          ('a', 'said'): 10,
#          ('mercantile', 'floor'): 10,
#          ('exchange', 'floor'): 10,
#          ('exchange', 'traders'): 10,
#          ('floor', 'mercantile'): 10,
#          ('floor', 'exchange'): 10,
#          ('traders', 'exchange'): 10,
#          ('traders', 'and'): 10,
#          ('and', 'traders'): 10,
#          ('hog', 'at'): 10,
#          ('at', 'hog'): 10,
#          ('slaughter', 'is'): 10,
#          ('slaughter', 'guesstimated'): 10,
#          ('is', 'slaughter'): 10,
#          ('is', 'guesstimated'): 10,
#          ('guesstimated', 'slaughter'): 10,
#          ('guesstimated', 'is'): 10,
#          ('guesstimated', 'at'): 10,
#          ('guesstimated', 'about'): 10,
#          ('at', 'guesstimated'): 10,
#          ('about', 'guesstimated'): 10,
#          ('beef', 'exports'): 10,
#          ('exports', 'beef'): 10,
#          ('the', 'country'): 10,
#          ('country', 'the'): 10,
#          ('to', 'continue'): 10,
#          ('continue', 'to'): 10,
#          ('sell', 'to'): 10,
#          ('the', 'commodity'): 10,
#          ('commodity', 'the'): 10,
#          ('sales', 'of'): 10,
#          ('of', 'sales'): 10,
#          ('new', 'york'): 10,
#          ('york', 'new'): 10,
#          ('as', 'the'): 10,
#          ('the', 'as'): 10,
#          ('price', 'the'): 10,
#          ('the', 'price'): 10,
#          ('islands', 'the'): 10,
#          ('the', 'islands'): 10,
#          ('dairy', 'to'): 10,
#          ('to', 'dairy'): 10,
#          ('and', 'will'): 10,
#          ('will', 'and'): 10,
#          ('of', 'from'): 10,
#          ('from', 'of'): 10,
#          ('a', 'earlier'): 10,
#          ('earlier', 'a'): 10,
#          ('ec', 'and'): 10,
#          ('and', 'ec'): 10,
#          ('tonnes', 'tonnes'): 10,
#          ('pork', 'producers'): 10,
#          ('producers', 'pork'): 10,
#          ('a', 'revised'): 10,
#          ('revised', 'a'): 10,
#          ('workers', 'and'): 10,
#          ('and', 'workers'): 10,
#          ('zack', 'said'): 10,
#          ('said', 'zack'): 10,
#          ('the', 'company'): 10,
#          ('company', 'the'): 10,
#          ('that', 'would'): 9,
#          ('would', 'that'): 9,
#          ('the', 'official'): 9,
#          ('if', 'the'): 9,
#          ('the', 'if'): 9,
#          ('it', 'will'): 9,
#          ('will', 'it'): 9,
#          ('s', 'said'): 9,
#          ('said', 's'): 9,
#          ('agriculture', 'secretary'): 9,
#          ('secretary', 'agriculture'): 9,
#          ('into', 'the'): 9,
#          ('the', 'into'): 9,
#          ('imports', 'of'): 9,
#          ('of', 'imports'): 9,
#          ('exports', 'the'): 9,
#          ('the', 'exports'): 9,
#          ('an', 'to'): 9,
#          ('to', 'an'): 9,
#          ('of', 'this'): 9,
#          ('this', 'of'): 9,
#          ('prices', 'said'): 9,
#          ('in', 'brackets'): 9,
#          ('brackets', 'in'): 9,
#          ('cattle', 'hog'): 9,
#          ('floor', 'and'): 9,
#          ('and', 'floor'): 9,
#          ('and', 'commission'): 9,
#          ('and', 'house'): 9,
#          ('commission', 'and'): 9,
#          ('house', 'and'): 9,
#          ('today', 's'): 9,
#          ('today', 'hog'): 9,
#          ('s', 'today'): 9,
#          ('s', 'hog'): 9,
#          ('hog', 'today'): 9,
#          ('hog', 's'): 9,
#          ('hog', 'slaughter'): 9,
#          ('slaughter', 'hog'): 9,
#          ('industry', 'said'): 9,
#          ('said', 'industry'): 9,
#          ('to', 'sell'): 9,
#          ('the', 'credit'): 9,
#          ('commodity', 'credit'): 9,
#          ('commodity', 'corporation'): 9,
#          ('credit', 'the'): 9,
#          ('credit', 'commodity'): 9,
#          ('credit', 'corporation'): 9,
#          ('credit', 'ccc'): 9,
#          ('corporation', 'commodity'): 9,
#          ('corporation', 'credit'): 9,
#          ('the', 'exchange'): 9,
#          ('he', 'the'): 9,
#          ('the', 'he'): 9,
#          ('work', 'to'): 9,
#          ('to', 'work'): 9,
#          ('and', 'lbs'): 9,
#          ('lbs', 'and'): 9,
#          ('the', 'are'): 9,
#          ('are', 'the'): 9,
#          ('export', 'program'): 9,
#          ('program', 'export'): 9,
#          ('they', 'the'): 9,
#          ('the', 'they'): 9,
#          ('exports', 'meat'): 9,
#          ('would', 'to'): 9,
#          ('to', 'would'): 9,
#          ('year', 'earlier'): 9,
#          ('earlier', 'year'): 9,
#          ('last', 'year'): 9,
#          ('year', 'last'): 9,
#          ('to', 'up'): 9,
#          ('up', 'to'): 9,
#          ('had', 'been'): 9,
#          ('been', 'had'): 9,
#          ('national', 'pork'): 9,
#          ('pork', 'national'): 9,
#          ('the', 'nppc'): 9,
#          ('to', 'union'): 9,
#          ('the', 'march'): 9,
#          ('march', 'the'): 9,
#          ('in', 'december'): 9,
#          ('december', 'in'): 9,
#          ('vs', 'a'): 9,
#          ('vs', 'revised'): 9,
#          ('a', 'vs'): 9,
#          ('revised', 'vs'): 9,
#          ('lbs', 'the'): 9,
#          ('the', 'lbs'): 9,
#          ('lbs', 'vs'): 9,
#          ('vs', 'lbs'): 9,
#          ('mechanically', 'separated'): 9,
#          ('separated', 'mechanically'): 9,
#          ('congress', 'american'): 9,
#          ('congress', 'pork'): 9,
#          ('workers', 'union'): 9,
#          ('union', 'workers'): 9,
#          ('a', 'lockout'): 9,
#          ('lockout', 'a'): 9,
#          ('prices', 'beef'): 9,
#          ('beef', 'prices'): 9,
#          ('the', 'lipc'): 9,
#          ('lipc', 'the'): 9,
#          ('farm', 'products'): 8,
#          ('products', 'farm'): 8,
#          ('s', 'farm'): 8,
#          ('farm', 's'): 8,
#          ('ministry', 'said'): 8,
#          ('official', 'said'): 8,
#          ('said', 'ministry'): 8,
#          ('said', 'official'): 8,
#          ('other', 'the'): 8,
#          ('the', 'other'): 8,
#          ('japan', 'the'): 8,
#          ('the', 'japan'): 8,
#          ('the', 'largest'): 8,
#          ('largest', 'the'): 8,
#          ('and', 'are'): 8,
#          ('are', 'and'): 8,
#          ('more', 'than'): 8,
#          ('than', 'more'): 8,
#          ('than', 'the'): 8,
#          ('the', 'than'): 8,
#          ('on', 's'): 8,
#          ('s', 'on'): 8,
#          ('has', 'the'): 8,
#          ('the', 'has'): 8,
#          ('dlrs', 'in'): 8,
#          ('in', 'dlrs'): 8,
#          ('in', 'new'): 8,
#          ('new', 'in'): 8,
#          ('also', 'the'): 8,
#          ('the', 'also'): 8,
#          ('the', 'ministry'): 8,
#          ('ministry', 'the'): 8,
#          ('meat', 'poultry'): 8,
#          ('poultry', 'meat'): 8,
#          ('to', 'their'): 8,
#          ('of', 'most'): 8,
#          ('most', 'of'): 8,
#          ('it', 'be'): 8,
#          ('the', 'number'): 8,
#          ('number', 'the'): 8,
#          ('number', 'of'): 8,
#          ('of', 'number'): 8,
#          ('the', 'past'): 8,
#          ('past', 'the'): 8,
#          ('on', 'of'): 8,
#          ('of', 'on'): 8,
#          ('there', 'be'): 8,
#          ('be', 'there'): 8,
#          ('is', 'expected'): 8,
#          ('expected', 'is'): 8,
#          ('were', 'in'): 8,
#          ('in', 'were'): 8,
#          ('in', 'cattle'): 8,
#          ('cattle', 'in'): 8,
#          ('said', 'prices'): 8,
#          ('cattle', 'guesstimates'): 8,
#          ('slaughter', 'guesstimates'): 8,
#          ('slaughter', 'chicago'): 8,
#          ('guesstimates', 'cattle'): 8,
#          ('guesstimates', 'slaughter'): 8,
#          ('guesstimates', 'chicago'): 8,
#          ('guesstimates', 'mercantile'): 8,
#          ('chicago', 'slaughter'): 8,
#          ('chicago', 'guesstimates'): 8,
#          ('mercantile', 'guesstimates'): 8,
#          ('traders', 'commission'): 8,
#          ('commission', 'traders'): 8,
#          ('commission', 'house'): 8,
#          ('commission', 'representatives'): 8,
#          ('house', 'commission'): 8,
#          ('house', 'representatives'): 8,
#          ('house', 'are'): 8,
#          ('representatives', 'commission'): 8,
#          ('representatives', 'house'): 8,
#          ('representatives', 'are'): 8,
#          ('representatives', 'guesstimating'): 8,
#          ('are', 'house'): 8,
#          ('are', 'representatives'): 8,
#          ('are', 'guesstimating'): 8,
#          ('are', 'today'): 8,
#          ('guesstimating', 'representatives'): 8,
#          ('guesstimating', 'are'): 8,
#          ('guesstimating', 'today'): 8,
#          ('guesstimating', 's'): 8,
#          ('today', 'are'): 8,
#          ('today', 'guesstimating'): 8,
#          ('s', 'guesstimating'): 8,
#          ('slaughter', 'at'): 8,
#          ('slaughter', 'about'): 8,
#          ('at', 'slaughter'): 8,
#          ('about', 'slaughter'): 8,
#          ('the', 'outbreak'): 8,
#          ('outbreak', 'the'): 8,
#          ('the', 'committee'): 8,
#          ('committee', 'the'): 8,
#          ('corporation', 'ccc'): 8,
#          ('corporation', 'has'): 8,
#          ('ccc', 'credit'): 8,
#          ('ccc', 'corporation'): 8,
#          ('has', 'corporation'): 8,
#          ('commodities', 'from'): 8,
#          ('from', 'commodities'): 8,
#          ('as', 'in'): 8,
#          ('in', 'as'): 8,
#          ('exchange', 'the'): 8,
#          ('the', 'value'): 8,
#          ('value', 'the'): 8,
#          ('analysts', 'said'): 8,
#          ('said', 'analysts'): 8,
#          ('of', 'year'): 8,
#          ('year', 'of'): 8,
#          ('on', 'cattle'): 8,
#          ('cattle', 'on'): 8,
#          ('canary', 'islands'): 8,
#          ('canary', 'the'): 8,
#          ('islands', 'canary'): 8,
#          ('the', 'canary'): 8,
#          ('has', 'a'): 8,
#          ('a', 'has'): 8,
#          ('bonus', 'export'): 8,
#          ('the', 'sale'): 8,
#          ('sale', 'the'): 8,
#          ('it', 'the'): 8,
#          ('the', 'it'): 8,
#          ('made', 'to'): 8,
#          ('to', 'made'): 8,
#          ('the', 'enhancement'): 8,
#          ('export', 'enhancement'): 8,
#          ('enhancement', 'the'): 8,
#          ('enhancement', 'export'): 8,
#          ('enhancement', 'program'): 8,
#          ('program', 'enhancement'): 8,
#          ('south', 'dakota'): 8,
#          ('dakota', 'south'): 8,
#          ('dakota', 'plant'): 8,
#          ('plant', 'dakota'): 8,
#          ('and', 'u'): 8,
#          ('u', 'and'): 8,
#          ('through', 'the'): 8,
#          ('the', 'through'): 8,
#          ('april', 'the'): 8,
#          ('the', 'april'): 8,
#          ('against', 'the'): 8,
#          ('the', 'against'): 8,
#          ('will', 'to'): 8,
#          ('to', 'will'): 8,
#          ('rose', 'to'): 8,
#          ('to', 'rose'): 8,
#          ('pct', 'from'): 8,
#          ('year', 'in'): 8,
#          ('in', 'year'): 8,
#          ('of', 'two'): 8,
#          ('two', 'of'): 8,
#          ('in', 'an'): 8,
#          ('an', 'in'): 8,
#          ('and', 'japan'): 8,
#          ('japan', 'and'): 8,
#          ('by', 'to'): 8,
#          ('to', 'by'): 8,
#          ('the', 'previous'): 8,
#          ('previous', 'the'): 8,
#          ('the', 'study'): 8,
#          ('study', 'the'): 8,
#          ('nppc', 'the'): 8,
#          ('futures', 'the'): 8,
#          ('the', 'futures'): 8,
#          ('operations', 'to'): 8,
#          ('to', 'operations'): 8,
#          ('as', 'well'): 8,
#          ('well', 'as'): 8,
#          ('of', 'tallow'): 8,
#          ('tallow', 'of'): 8,
#          ('revised', 'mln'): 8,
#          ('mln', 'revised'): 8,
#          ('the', 'ago'): 8,
#          ('lbs', 'a'): 8,
#          ('a', 'lbs'): 8,
#          ('pork', 'in'): 8,
#          ('in', 'pork'): 8,
#          ('to', 'apply'): 8,
#          ('apply', 'to'): 8,
#          ('united', 'food'): 8,
#          ('food', 'united'): 8,
#          ('food', 'commercial'): 8,
#          ('and', 'commercial'): 8,
#          ('commercial', 'food'): 8,
#          ('commercial', 'and'): 8,
#          ('commercial', 'workers'): 8,
#          ('workers', 'commercial'): 8,
#          ('plant', 'at'): 8,
#          ('at', 'plant'): 8,
#          ('city', 'plant'): 8,
#          ('plant', 'city'): 8,
#          ('tonnes', 'with'): 8,
#          ('with', 'tonnes'): 8,
#          ('with', 'figures'): 8,
#          ('figures', 'with'): 8,
#          ('figures', 'for'): 8,
#          ('for', 'figures'): 8,
#          ('beef', 'meat'): 8,
#          ('meat', 'beef'): 8,
#          ('the', 'ceiling'): 8,
#          ('ceiling', 'the'): 8,
#          ('s', 'that'): 7,
#          ('that', 's'): 7,
#          ('s', 'exports'): 7,
#          ('exports', 's'): 7,
#          ('imports', 'from'): 7,
#          ('from', 'imports'): 7,
#          ('official', 'the'): 7,
#          ('declined', 'to'): 7,
#          ('to', 'declined'): 7,
#          ('said', 'is'): 7,
#          ('is', 'said'): 7,
#          ('farm', 'and'): 7,
#          ('and', 'farm'): 7,
#          ('it', 'is'): 7,
#          ('is', 'it'): 7,
#          ('will', 'also'): 7,
#          ('also', 'will'): 7,
#          ('beef', 'imports'): 7,
#          ('imports', 'beef'): 7,
#          ('said', 'an'): 7,
#          ('an', 'said'): 7,
#          ('of', 'agriculture'): 7,
#          ('agriculture', 'of'): 7,
#          ('one', 'the'): 7,
#          ('the', 'one'): 7,
#          ('to', 'help'): 7,
#          ('help', 'to'): 7,
#          ('meat', 'products'): 7,
#          ('products', 'meat'): 7,
#          ('the', 'current'): 7,
#          ('current', 'the'): 7,
#          ('are', 'of'): 7,
#          ('of', 'are'): 7,
#          ('the', 'years'): 7,
#          ('years', 'the'): 7,
#          ('their', 'to'): 7,
#          ('also', 'said'): 7,
#          ('said', 'also'): 7,
#          ('said', 'that'): 7,
#          ('that', 'said'): 7,
#          ('be', 'it'): 7,
#          ('in', 'pct'): 7,
#          ('pct', 'in'): 7,
#          ('over', 'the'): 7,
#          ('the', 'over'): 7,
#          ('will', 'not'): 7,
#          ('not', 'will'): 7,
#          ('of', 'national'): 7,
#          ('national', 'of'): 7,
#          ('meat', 'said'): 7,
#          ('said', 'meat'): 7,
#          ('and', 'be'): 7,
#          ('be', 'and'): 7,
#          ('imports', 'to'): 7,
#          ('to', 'imports'): 7,
#          ('production', 'and'): 7,
#          ('and', 'production'): 7,
#          ('live', 'cattle'): 7,
#          ('cattle', 'live'): 7,
#          ('equivalent', 'in'): 7,
#          ('in', 'equivalent'): 7,
#          ('year', 'cattle'): 7,
#          ('ago', 'cattle'): 7,
#          ('ago', 'slaughter'): 7,
#          ('cattle', 'year'): 7,
#          ('cattle', 'ago'): 7,
#          ('slaughter', 'ago'): 7,
#          ('demand', 'for'): 7,
#          ('for', 'demand'): 7,
#          ('community', 'ec'): 7,
#          ('ec', 'community'): 7,
#          ('be', 'by'): 7,
#          ('outbreak', 'of'): 7,
#          ('of', 'outbreak'): 7,
#          ('of', 'exports'): 7,
#          ('exports', 'of'): 7,
#          ('beef', 'from'): 7,
#          ('from', 'beef'): 7,
#          ('the', 'had'): 7,
#          ('had', 'the'): 7,
#          ('beef', 'on'): 7,
#          ('on', 'beef'): 7,
#          ('ccc', 'has'): 7,
#          ('has', 'ccc'): 7,
#          ('for', 'sales'): 7,
#          ('sales', 'for'): 7,
#          ('to', 'increase'): 7,
#          ('increase', 'to'): 7,
#          ('the', 'line'): 7,
#          ('line', 'the'): 7,
#          ('be', 'a'): 7,
#          ('a', 'be'): 7,
#          ('the', 'commodities'): 7,
#          ('commodities', 'the'): 7,
#          ('are', 'at'): 7,
#          ('at', 'are'): 7,
#          ('contract', 'the'): 7,
#          ('the', 'contract'): 7,
#          ('for', 'an'): 7,
#          ('an', 'for'): 7,
#          ('export', 'bonus'): 7,
#          ('sale', 'of'): 7,
#          ('of', 'sale'): 7,
#          ('for', 'delivery'): 7,
#          ('delivery', 'for'): 7,
#          ('the', 'bonus'): 7,
#          ('bonus', 'the'): 7,
#          ('head', 'and'): 7,
#          ('and', 'head'): 7,
#          ('and', 'was'): 7,
#          ('was', 'and'): 7,
#          ('was', 'made'): 7,
#          ('made', 'was'): 7,
#          ('of', 'commodities'): 7,
#          ('commodities', 'of'): 7,
#          ('the', 'ccc'): 7,
#          ('ccc', 'the'): 7,
#          ('available', 'to'): 7,
#          ('to', 'available'): 7,
#          ('under', 'export'): 7,
#          ('export', 'under'): 7,
#          ('meat', 'exports'): 7,
#          ('at', 'mln'): 7,
#          ('mln', 'at'): 7,
#          ('of', 'that'): 7,
#          ('that', 'of'): 7,
#          ('against', 'a'): 7,
#          ('a', 'against'): 7,
#          ('from', 'pct'): 7,
#          ('the', 'australian'): 7,
#          ('australian', 'the'): 7,
#          ('other', 'of'): 7,
#          ('of', 'other'): 7,
#          ('response', 'to'): 7,
#          ('to', 'response'): 7,
#          ('the', 'added'): 7,
#          ('of', 'products'): 7,
#          ('products', 'of'): 7,
#          ('the', 'disease'): 7,
#          ('disease', 'the'): 7,
#          ('the', 'months'): 7,
#          ('months', 'the'): 7,
#          ('national', 'producers'): 7,
#          ('pork', 'council'): 7,
#          ('producers', 'national'): 7,
#          ('producers', 'council'): 7,
#          ('council', 'pork'): 7,
#          ('council', 'producers'): 7,
#          ('nppc', 'said'): 7,
#          ('said', 'nppc'): 7,
#          ('of', 'all'): 7,
#          ('all', 'of'): 7,
#          ('it', 'was'): 7,
#          ('was', 'it'): 7,
#          ('union', 'to'): 7,
#          ('and', 'against'): 7,
#          ('against', 'and'): 7,
#          ('lbs', 'of'): 7,
#          ('of', 'lbs'): 7,
#          ('production', 'of'): 7,
#          ('of', 'production'): 7,
#          ('ago', 'the'): 7,
#          ('mln', 'vs'): 7,
#          ('vs', 'mln'): 7,
#          ('according', 'to'): 7,
#          ('to', 'according'): 7,
#          ('and', 'other'): 7,
#          ('other', 'and'): 7,
#          ('and', 'new'): 7,
#          ('import', 'quota'): 7,
#          ('quota', 'import'): 7,
#          ('on', 'april'): 7,
#          ('april', 'on'): 7,
#          ('the', 'half'): 7,
#          ('half', 'the'): 7,
#          ('beef', 'quota'): 7,
#          ('quota', 'beef'): 7,
#          ('at', 'against'): 7,
#          ('against', 'at'): 7,
#          ('american', 'pork'): 7,
#          ('american', 'congress'): 7,
#          ('pork', 'american'): 7,
#          ('pork', 'congress'): 7,
#          ('and', 'distribution'): 7,
#          ('distribution', 'and'): 7,
#          ('members', 'the'): 7,
#          ('the', 'members'): 7,
#          ('the', 'food'): 7,
#          ('food', 'the'): 7,
#          ('commercial', 'union'): 7,
#          ('union', 'commercial'): 7,
#          ('iowa', 'processors'): 7,
#          ('beef', 'processors'): 7,
#          ('processors', 'iowa'): 7,
#          ('processors', 'beef'): 7,
#          ('at', 'dakota'): 7,
#          ('dakota', 'at'): 7,
#          ('members', 'of'): 7,
#          ('of', 'members'): 7,
#          ('tonnes', 'comparative'): 7,
#          ('with', 'comparative'): 7,
#          ('comparative', 'tonnes'): 7,
#          ('comparative', 'with'): 7,
#          ...})

# %%
# Weighting function for co-occurrences
def weighting(w_i, w_j, X_ik):
    
    #check whether the co-occurences between w_i and w_j is available
    try:
        x_ij = X_ik[(w_i, w_j)]
        #if not exist, then set to 1 "laplace smoothing"
    except:
        x_ij = 1
        
    #set xmax
    x_max = 100
    #set alpha
    alpha = 0.75
    
    #if co-ocurrence does not exceeed xmax, then just multiply with some alpha
    if x_ij < x_max:
        result = (x_ij / x_max)**alpha
    #otherwise, set to 1
    else:
        result = 1
    
    return result

# %%
# Create co-occurrence dictionary and apply weighting
from itertools import combinations_with_replacement

X_ik = {} #keeping the co-occurences
weighting_dic = {} #already scale the co-occurences using the weighting function

for bigram in combinations_with_replacement(vocabs, 2):
    if X_ik_skipgrams.get(bigram):  #if the pair exists in our corpus
        co = X_ik_skipgrams[bigram]
        X_ik[bigram] = co + 1 #for stability
        X_ik[(bigram[1], bigram[0])] = co + 1
    else:
        pass
    
    weighting_dic[bigram] = weighting(bigram[0], bigram[1], X_ik)
    weighting_dic[(bigram[1], bigram[0])] = weighting(bigram[1], bigram[0], X_ik)

# %%
# Function to generate random batches for training
import math

def random_batch(batch_size, word_sequence, skip_grams, X_ik, weighting_dic):
    
    random_inputs, random_labels, random_coocs, random_weightings = [], [], [], []
    
    #convert our skipgrams to id
    skip_grams_id = [(word2index[skip_gram[0]], word2index[skip_gram[1]]) for skip_gram in skip_grams]
    
    #randomly choose indexes based on batch size
    random_index = np.random.choice(range(len(skip_grams_id)), batch_size, replace=False)
    
    #get the random input and labels
    for index in random_index:
        random_inputs.append([skip_grams_id[index][0]])
        random_labels.append([skip_grams_id[index][1]])
        #coocs
        pair = skip_grams[index] #e.g., ('banana', 'fruit')
        try:
            cooc = X_ik[pair]
        except:
            cooc = 1
        random_coocs.append([math.log(cooc)])
    
        #weightings
        weighting = weighting_dic[pair]
        random_weightings.append([weighting])
        
    return np.array(random_inputs), np.array(random_labels), np.array(random_coocs), np.array(random_weightings)

# %% [markdown]
# ## 4. Testing method

# %%
# Model and Training Parameters
batch_size = 32
voc_size = len(vocabs)
emb_size = 10
x, y, cooc, weighting = random_batch(batch_size, corpus, skip_grams, X_ik, weighting_dic)

# %%
x
# Out:
# array([[1438],
#        [2533],
#        [1580],
#        [1632],
#        [2705],
#        [ 819],
#        [1048],
#        [  90],
#        [1865],
#        [ 349],
#        [1232],
#        [1630],
#        [ 584],
#        [ 982],
#        [ 874],
#        [ 249],
#        [2112],
#        [ 194],
#        [1588],
#        [ 342],
#        [ 634],
#        [1048],
#        [2895],
#        [ 222],
#        [ 680],
#        [ 350],
#        [1520],
#        [ 982],
#        [ 811],
#        [1418],
#        [1539],
#        [1580]])

# %%
y
# Out:
# array([[2041],
#        [2592],
#        [2895],
#        [ 982],
#        [1060],
#        [1416],
#        [1937],
#        [ 697],
#        [  16],
#        [1494],
#        [1354],
#        [ 222],
#        [2605],
#        [1028],
#        [ 342],
#        [2753],
#        [1723],
#        [1609],
#        [1048],
#        [1632],
#        [ 557],
#        [2112],
#        [2891],
#        [ 899],
#        [ 636],
#        [  16],
#        [2817],
#        [ 325],
#        [1789],
#        [1587],
#        [ 725],
#        [ 342]])

# %%
cooc
# Out:
# array([[0.69314718],
#        [1.09861229],
#        [3.49650756],
#        [0.69314718],
#        [0.69314718],
#        [1.60943791],
#        [0.69314718],
#        [0.69314718],
#        [2.07944154],
#        [1.38629436],
#        [0.69314718],
#        [0.69314718],
#        [0.69314718],
#        [3.29583687],
#        [0.69314718],
#        [0.69314718],
#        [0.69314718],
#        [0.69314718],
#        [0.69314718],
#        [1.38629436],
#        [0.69314718],
#        [3.17805383],
#        [2.30258509],
#        [0.69314718],
#        [0.69314718],
#        [1.38629436],
#        [0.69314718],
#        [1.60943791],
#        [0.69314718],
#        [1.60943791],
#        [0.69314718],
#        [1.79175947]])

# %%
weighting
# Out:
# array([[0.05318296],
#        [0.07208434],
#        [0.43539702],
#        [0.05318296],
#        [0.05318296],
#        [0.10573713],
#        [0.05318296],
#        [0.05318296],
#        [0.15042412],
#        [0.08944272],
#        [0.05318296],
#        [0.05318296],
#        [0.05318296],
#        [0.37456123],
#        [0.05318296],
#        [0.05318296],
#        [0.05318296],
#        [0.05318296],
#        [0.05318296],
#        [0.08944272],
#        [0.05318296],
#        [0.34289285],
#        [0.17782794],
#        [0.05318296],
#        [0.05318296],
#        [0.08944272],
#        [0.05318296],
#        [0.10573713],
#        [0.05318296],
#        [0.10573713],
#        [0.05318296],
#        [0.12123093]])

# %% [markdown]
# ## 5. GloVe Model Definition

# %%
class Glove(nn.Module):
    
    def __init__(self, voc_size, emb_size):
        super(Glove, self).__init__()
        self.center_embedding  = nn.Embedding(voc_size, emb_size)
        self.outside_embedding = nn.Embedding(voc_size, emb_size)
        
        self.center_bias       = nn.Embedding(voc_size, 1) 
        self.outside_bias      = nn.Embedding(voc_size, 1)
    
    def forward(self, center, outside, coocs, weighting):
        center_embeds  = self.center_embedding(center) #(batch_size, 1, emb_size)
        outside_embeds = self.outside_embedding(outside) #(batch_size, 1, emb_size)
        
        center_bias    = self.center_bias(center).squeeze(1)
        target_bias    = self.outside_bias(outside).squeeze(1)
        
        inner_product  = outside_embeds.bmm(center_embeds.transpose(1, 2)).squeeze(2)
        #(batch_size, 1, emb_size) @ (batch_size, emb_size, 1) = (batch_size, 1, 1) = (batch_size, 1)
        
        loss = weighting * torch.pow(inner_product + center_bias + target_bias - coocs, 2)
        
        return torch.sum(loss)

# %% [markdown]
# ## 6. Model Initialization and Loss Calculation

# %%
model = Glove(voc_size, emb_size)
model
# Out:
# Glove(
#   (center_embedding): Embedding(2908, 10)
#   (outside_embedding): Embedding(2908, 10)
#   (center_bias): Embedding(2908, 1)
#   (outside_bias): Embedding(2908, 1)
# )

# %%
x_tensor = torch.LongTensor(x)
y_tensor = torch.LongTensor(y)
cooc_tensor = torch.FloatTensor(cooc)
weighting_tensor = torch.FloatTensor(weighting)

# %%
loss = model(x_tensor, y_tensor, cooc_tensor, weighting_tensor)

# %% [markdown]
# ## 7. Training Epoch

# %%
import time

# Function to calculate time taken per epoch
def epoch_time(start_time, end_time):
  elapsed_time = end_time - start_time
  elapsed_mins = int(elapsed_time / 60)
  elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
  return elapsed_mins, elapsed_secs

# %%
# Initialize model and optimizer
model          = Glove(voc_size, emb_size)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
import time
start_time = time.time()

# Training
num_epochs = 10000
for epoch in range(num_epochs):      
    input_batch, target_batch, cooc_batch, weighting_batch = random_batch(batch_size, corpus, skip_grams, X_ik, weighting_dic)
    input_batch  = torch.LongTensor(input_batch)         #[batch_size, 1]
    target_batch = torch.LongTensor(target_batch)        #[batch_size, 1]
    cooc_batch   = torch.FloatTensor(cooc_batch)         #[batch_size, 1]
    weighting_batch = torch.FloatTensor(weighting_batch) #[batch_size, 1]
    
    optimizer.zero_grad()
    loss = model(input_batch, target_batch, cooc_batch, weighting_batch)
    
    loss.backward()
    optimizer.step()
    
    end = time.time()
    
    if (epoch + 1) % 1000 == 0:
        print(f"Epoch: {epoch + 1} | cost: {loss:.6f}")

end_time = time.time()
min, sec = epoch_time(start_time, end_time)
print(f"Epoch time: {min}:{sec}")
# Out:
# Epoch: 1000 | cost: 57.152378
# Epoch: 2000 | cost: 40.790550
# Epoch: 3000 | cost: 17.099533
# Epoch: 4000 | cost: 13.615710
# Epoch: 5000 | cost: 13.479882
# Epoch: 6000 | cost: 8.286769
# Epoch: 7000 | cost: 7.457489
# Epoch: 8000 | cost: 7.251559
# Epoch: 9000 | cost: 6.842691
# Epoch: 10000 | cost: 3.628716
# Epoch time: 3:26

# %%
# Save the trained model
torch.save(model, 'GloVe_model.pth')

# %% [markdown]
# ## 8. Model Loading and Evaluation on Analogy Tasks

# %%
# Load the trained model
model = torch.load('GloVe_model.pth')
model.eval()
# Out:
# Glove(
#   (center_embedding): Embedding(2907, 10)
#   (outside_embedding): Embedding(2907, 10)
#   (center_bias): Embedding(2907, 1)
#   (outside_bias): Embedding(2907, 1)
# )

# %%
# Load analogy data and separate into syntactic and semantic analogies
syntactic_analogies = []
semantic_analogies = []
current_category = None

with open('word-test.txt', 'r') as file:
    for line in file:
        if line.startswith(':'):
            if 'gram' in line:  # Assumption: syntactic questions contain 'gram'
                current_category = syntactic_analogies
            else:
                current_category = semantic_analogies
        elif current_category is not None:
            current_category.append(line.strip().split())

# %%
# Function to solve an analogy given words a, b, c
def solve_analogy(a, b, c, word_to_index, index_to_word, model):
    # Convert words to embeddings
    a_emb = model.center_embedding(torch.tensor([word_to_index.get(a, word_to_index["<UNK>"])]))
    b_emb = model.center_embedding(torch.tensor([word_to_index.get(b, word_to_index["<UNK>"])]))
    c_emb = model.center_embedding(torch.tensor([word_to_index.get(c, word_to_index["<UNK>"])]))

    # Calculate the expected embedding for d
    expected_d_emb = b_emb - a_emb + c_emb

    # Find the closest word to the expected embedding
    closest_word, closest_dist = None, float('inf')
    for word, idx in word_to_index.items():
        if word not in [a, b, c]:
            word_emb = model.center_embedding(torch.tensor([idx]))
            dist = torch.norm(expected_d_emb - word_emb)
            if dist < closest_dist:
                closest_word, closest_dist = word, dist
    return closest_word

# %%
# Function to calculate accuracy of the model on analogy tasks
def calculate_accuracy(analogies, word_to_index, index_to_word, model):
    correct = 0
    for analogy in analogies:
        a, b, c, expected_d = analogy
        predicted_d = solve_analogy(a, b, c, word_to_index, index_to_word, model)
        if predicted_d == expected_d:
            correct += 1
    return correct / len(analogies) if analogies else 0

# %%
# Calculate and print syntactic and semantic accuracies
syntactic_accuracy = calculate_accuracy(syntactic_analogies, word2index, index2word, model)
semantic_accuracy = calculate_accuracy(semantic_analogies, word2index, index2word, model)

print(f"Syntactic Accuracy: {syntactic_accuracy}")
print(f"Semantic Accuracy: {semantic_accuracy}")
# Out:
# Syntactic Accuracy: 0.0
# Semantic Accuracy: 0.0

# %% [markdown]
# # 9. Search engine

# %%
import torch
# load saved glove model
model = torch.load('GloVe_model.pth')
model.eval()
# Out:
# Glove(
#   (center_embedding): Embedding(2907, 10)
#   (outside_embedding): Embedding(2907, 10)
#   (center_bias): Embedding(2907, 1)
#   (outside_bias): Embedding(2907, 1)
# )

# %%
# Load data once outside the function
with open('Data/AIT_wiki.txt') as file:
    hp_data = file.read().split()
